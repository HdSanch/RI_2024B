# %% [markdown]
# <a href="https://colab.research.google.com/github/HdSanch/RI_2024B/blob/main/Examen1BIM_SH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Examen Bimestral – Diseño de un Sistema Básico de Recuperación de Información
#
# ### Nombre: Hernán Sánchez

# %% [markdown]
# # Librerias usadas:
#
# 1. **Pandas**: Usa para manipulación de DataFrames y Series, estructuras de datos que pandas ofrece.
#
# 2. **Numpy**: Se usa para realizar cálculos numéricos, crear matrices o manejar valores numéricos dentro del análisis.
#
# 3. **sklearn.feature_extraction.text**: Se utiliza para convertir texto en una representación numérica, mediante TF-IDF.
#
# 4. **sklearn.metrics.pairwise**: Ayuda a calcular la similitud entre vectores utilizando la métrica del coseno.
#
# 5. **nltk**: Se usa para tareas como tokenización, lematización y análisis gramatical.
#
# 6. **nltk.corpus**: Ayuda a cargar una lista con stopwords.
#
# 7. **nltk.tokenize**: Se usa para tokenizar texto.
#
# 8. **nltk.stem**: Se utiliza para convertir palabras a su forma raíz.
#
# 9. **re**: Se utiliza para buscar, reemplazar, dividir o validar patrones de texto utilizando expresiones regulares.
#
# n_results: Variable que establece cuantos resultados quieres visualizar en la búsqueda.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
import re

# Variables globales
movies_df = None
reviews_df = None
vectorizer = None
tfidf_matrix = None
tokenizer = None
stop_words = None
stemmer = None
n_results = 35

# %% [markdown]
# # Obtencion y preprocesamiento de la data
#
# Primero se descarga la data de:
# https://www.kaggle.com/datasets/stefanoleone992/rotten-tomatoes-movies-and-critic-reviews-dataset
#
# Aqui se descarga un zip con dos archivos los cuales pasarana a ser preprocesados, una vez descomprimidos pasamos a cargarlos.
#
# - load_data(movies_path, reviews_path): Cargar los datos de películas y reseñas desde los archivos CSV y los convierte en dataframes.

# %%
def load_data(movies_path, reviews_path):
    """Cargar y preparar los datos de películas y reseñas"""
    global movies_df, reviews_df

    try:
        movies_df = pd.read_csv(movies_path)
        reviews_df = pd.read_csv(reviews_path)

        # Mostrar totales
        total_movies = len(movies_df)
        total_reviews = len(reviews_df)
        print("\n=== Estadísticas generales ===")
        print(f"Total de películas: {total_movies:,}")
        print(f"Total de reseñas: {total_reviews:,}")
        print(f"Promedio de reseñas por película: {total_reviews/total_movies:.2f}")

        # Mostrar primeras 5 filas de cada DataFrame
        print("\n=== Primeras 5 películas ===")
        print(movies_df.head())

        print("\n=== Primeras 5 reseñas ===")
        print(reviews_df.head())

        # Limpieza de datos
        text_columns = ['movie_title', 'movie_info', 'critics_consensus']
        for col in text_columns:
            if col in movies_df.columns:
                movies_df[col] = movies_df[col].fillna('')

        rating_columns = ['tomatometer_rating', 'audience_rating']
        for col in rating_columns:
            if col in movies_df.columns:
                movies_df[col] = movies_df[col].fillna('No disponible')

        # Combinar información para búsqueda (solo si existen las columnas)
        text_cols = [col for col in text_columns if col in movies_df.columns]
        if text_cols:
            movies_df['combined_text'] = movies_df[text_cols].fillna('').agg(' '.join, axis=1)

        print("\nDatos cargados exitosamente!")
        return True

    except FileNotFoundError:
        print("\nError: No se encontraron los archivos de datos.")
        print("Archivos necesarios:")
        print(f"- {movies_path}")
        print(f"- {reviews_path}")
        return False

    except Exception as e:
        print(f"\nError al cargar los datos: {str(e)}")
        import traceback
        print("\nDetalles del error:")
        print(traceback.format_exc())
        return False

# %% [markdown]
# 1. initialize_nlp_components(): Inicializar los componentes necesarios para el procesamiento de texto, como el tokenizador, las palabras de parada y el stemmer.
# 2. clean_query(text): Convierte el texto a minúsculas.Elimina caracteres especiales o puntuación, reemplazándolos con espacios. Reduce múltiples espacios consecutivos a uno solo. Devuelve el texto limpio y sin espacios al inicio o al final.
# 3. preprocess_text(text): Limpia el texto utilizando clean_query.Tokeniza el texto con el tokenizer configurado y elimina stop words.Aplica el stemming a cada palabra. Combina las palabras procesadas en una sola cadena.

# %%
def initialize_nlp_components():
    """Inicializar componentes de procesamiento de lenguaje natural"""
    global tokenizer, stop_words, stemmer

    try:
        nltk.download('stopwords', quiet=True)
        stop_words = set(stopwords.words('english'))
        stemmer = PorterStemmer()
        tokenizer = RegexpTokenizer(r'\w+')
        return True
    except Exception as e:
        print(f"Error al inicializar componentes NLP: {str(e)}")
        return False

def clean_query(text):
    """Limpieza básica de la query"""
    if not isinstance(text, str) or pd.isna(text):
        return ""

    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def preprocess_text(text):
    """Preprocesamiento completo del texto para búsqueda"""
    if pd.isna(text) or not isinstance(text, str):
        return ""

    # Limpieza básica
    text = clean_query(text)

    # Tokenización y procesamiento avanzado
    tokens = tokenizer.tokenize(text)
    tokens = [stemmer.stem(token) for token in tokens
             if token not in stop_words and len(token) > 2]

    return ' '.join(tokens)

# %% [markdown]
# # Vectorización
# - build_search_index(): Usa un TfidfVectorizer para convertir el texto procesado en una matriz TF-IDF. Maneja errores durante el proceso de construcción.

# %%
def build_search_index():
    """Construir el índice de búsqueda usando TF-IDF"""
    global vectorizer, tfidf_matrix

    print("Construyendo índice de búsqueda...")
    try:
        # Preprocesar textos
        movies_df['processed_text'] = movies_df['combined_text'].apply(
            preprocess_text
        )

        # Crear y entrenar vectorizador TF-IDF
        vectorizer = TfidfVectorizer(max_features=5000)
        tfidf_matrix = vectorizer.fit_transform(
            movies_df['processed_text']
        )
        print("Índice de búsqueda construido exitosamente!")
        return True

    except Exception as e:
        print(f"Error al construir el índice: {str(e)}")
        return False

# %% [markdown]
# # Preprocesamiento, vectorización y búsqueda de la query
#
# - search_movies(query): Preprocesa la consulta ingresada usando preprocess_text.Vectoriza la consulta utilizando el vectorizer entrenado.
# Calcula la similitud coseno entre el vector de la consulta y la matriz TF-IDF.
# Identifica las películas más relevantes, las ordena por relevancia y selecciona las principales según n_results.
# Devuelve una lista de resultados con título, puntajes de relevancia, información, y calificaciones.
#
# - format_movie_info(info_text, max_length=200): Formatear la información de una película para mostrarla.
#
# - display_results(query, results) Mostrar los resultados de la búsqueda en la consola. Imprime el encabezado con la consulta.
# Si no hay resultados, informa al usuario.

# %%
def search_movies(query):
    """Realizar búsqueda de películas"""
    global n_results

    try:
        # Preprocesar la consulta
        processed_query = preprocess_text(query)

        if not processed_query:
            return []

        # Vectorizar la consulta
        query_vector = vectorizer.transform([processed_query])

        # Calcular similitudes
        similarities = cosine_similarity(query_vector, tfidf_matrix)[0]

        # Filtrar y ordenar resultados
        relevant_indices = np.where(similarities > 0)[0]

        if len(relevant_indices) == 0:
            return []

        top_indices = relevant_indices[
            np.argsort(similarities[relevant_indices])[-n_results:][::-1]
        ]

        # Preparar resultados
        results = []
        for idx in top_indices:
            movie = movies_df.iloc[idx]
            result = {
                'title': movie['movie_title'],
                'score': similarities[idx],
                'info': movie['movie_info'],
                'tomatometer_rating': movie['tomatometer_rating'],
                'audience_rating': movie['audience_rating']
            }
            results.append(result)

        return results

    except Exception as e:
        print(f"Error en la búsqueda: {str(e)}")
        return []

def format_movie_info(info_text, max_length=200):
    """Formatear información de la película"""
    if pd.isna(info_text) or not isinstance(info_text, str):
        return "Información no disponible"

    if len(info_text) > max_length:
        return f"{info_text[:max_length]}..."
    return info_text

def display_results(query, results):
    """Mostrar resultados de la búsqueda"""
    print(f"\nResultados para: '{query}'")
    print("-" * 50)

    if not results:
        print("No se encontraron resultados.")
        return

    for i, result in enumerate(results, 1):
        print(f"\n{i}. {result['title']}")
        print(f"   Relevancia: {result['score']:.3f}")
        print(f"   Calificación críticos: {result['tomatometer_rating']}")
        print(f"   Calificación audiencia: {result['audience_rating']}")
        print(f"   Info: {format_movie_info(result['info'])}")

# %% [markdown]
# # Ejecución
#
# - initialize_search(): Inicializa los componentes de NLP, carga los datos y construye el índice de búsqueda. Ofrece un menú interactivo para realizar búsquedas, cambiar el número de resultados (resultados N) o salir (salir/exit). Procesa las entradas, ejecuta búsquedas, y muestra los resultados en tiempo real.
# - main(): Llama a initialize_search para iniciar el sistema.

# %%
sdef initialize_search():
    """Ejecutar el sistema en modo interactivo"""
    global n_results

    print("\nInicializando sistema de búsqueda de películas...")

    # Inicializar componentes
    if not initialize_nlp_components():
        return

    # Cargar datos
    if not load_data('rotten_tomatoes_movies.csv',
                     'rotten_tomatoes_critic_reviews.csv'):
        return

    # Construir índice
    if not build_search_index():
        return

    print("\n¡Sistema listo!")
    print("\nInstrucciones:")
    print("- Escribe tu búsqueda y presiona Enter")
    print("- Para salir: 'salir' o 'exit'")

    while True:
        print("\n" + "="*50)
        query = input("\nBúsqueda (o 'salir'): ").strip()

        # Verificar comando de salida
        if query.lower() in ['salir', 'exit']:
            print("\n¡Gracias por usar el sistema!")
            break

        # Verificar cambio de número de resultados
        if query.lower().startswith('resultados '):
            try:
                n_results = int(query.split()[1])
                print(f"\nNúmero de resultados cambiado a: {n_results}")
                continue
            except:
                print("Formato inválido. Uso: 'resultados N'")
                continue

        # Realizar búsqueda
        if query:
            results = search_movies(query)
            display_results(query, results)
        else:
            print("Por favor ingresa una búsqueda válida")

def main():
    """Función principal"""
    initialize_search()

if __name__ == "__main__":
    main()
# Out:
# Inicializando sistema de búsqueda de películas...
#
# === Estadísticas generales ===
# Total de películas: 17,712
# Total de reseñas: 1,130,017
# Promedio de reseñas por película: 63.80
#
# === Primeras 5 películas ===
#                     rotten_tomatoes_link                                         movie_title  \
# 0                              m/0814255  Percy Jackson & the Olympians: The Lightning Thief
# 1                              m/0878835                                         Please Give
# 2                                   m/10                                                  10
# 3                 m/1000013-12_angry_men                     12 Angry Men (Twelve Angry Men)
# 4  m/1000079-20000_leagues_under_the_sea                        20,000 Leagues Under The Sea
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   movie_info  \
# 0                                     Always trouble-prone, the life of teenager Percy Jackson (Logan Lerman) gets a lot more complicated when he learns he's the son of the Greek god Poseidon. At a training ground for the children of deities, Percy learns to harness his divine powers and prepare for the adventure of a lifetime: he must prevent a feud among the Olympians from erupting into a devastating war on Earth, and rescue his mother from the clutches of Hades, god of the underworld.
# 1     Kate (Catherine Keener) and her husband Alex (Oliver Platt) are wealthy New Yorkers who prowl estate sales and make a tidy profit reselling items they bought cheaply. They buy the apartment next door and plan to remodel just as soon as its current occupant, a cranky old woman, dies. Kate is troubled by the way she and her husband earn a living, and tries to assuage her guilt by befriending her tenant and the woman's granddaughters, but her overtures lead to unexpected consequences.
# 2                                                                                                                                                                                                                    A successful, middle-aged Hollywood songwriter falls hopelessly in love with the woman of his dreams, and even follows the girl and her new husband to their Mexican honeymoon resort. While his behavior seems sure to land him in trouble, out of the blue fate plays into his hands.
# 3                                         Following the closing arguments in a murder trial, the 12 members of the jury must deliberate, with a guilty verdict meaning death for the accused, an inner-city teen. As the dozen men try to reach a unanimous decision while sequestered in a room, one juror (Henry Fonda) casts considerable doubt on elements of the case. Personal issues soon rise to the surface, and conflict threatens to derail the delicate process that will decide one boy's fate.
# 4  In 1866, Professor Pierre M. Aronnax (Paul Lukas) and his assistant Conseil (Peter Lorre), stranded in San Francisco by reports of a giant sea monster attacking ships in the Pacific Ocean, are invited to join an expedition to search for the creature. During the search, they and harpooner Ned Land (Kirk Douglas) are thrown overboard during an attack, eventually discovering that the supposed monster is actually a submarine piloted by the brilliant but haunted Captain Nemo (James Mason).
#
#                                                                                                                                                                    critics_consensus  \
# 0           Though it may seem like just another Harry Potter knockoff, Percy Jackson benefits from a strong supporting cast, a speedy plot, and plenty of fun with Greek mythology.
# 1  Nicole Holofcener's newest might seem slight in places, but its rendering of complex characters in a conflicted economic landscape is varied, natural, and touching all the same.
# 2                              Blake Edwards' bawdy comedy may not score a perfect 10, but Dudley Moore's self-deprecating performance makes this midlife crisis persistently funny.
# 3                                          Sidney Lumet's feature debut is a superbly written, dramatically effective courtroom thriller that rightfully stands as a modern classic.
# 4           One of Disney's finest live-action adventures, 20,000 Leagues Under the Sea brings Jules Verne's classic sci-fi tale to vivid life, and features an awesome giant squid.
#
#   content_rating                                                        genres          directors  \
# 0             PG  Action & Adventure, Comedy, Drama, Science Fiction & Fantasy     Chris Columbus
# 1              R                                                        Comedy  Nicole Holofcener
# 2              R                                               Comedy, Romance      Blake Edwards
# 3             NR                                               Classics, Drama       Sidney Lumet
# 4              G                      Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  actors  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Daddario, Jake Abel, Sean Bean, Pierce Brosnan, Steve Coogan, Rosario Dawson, Melina Kanakaredes, Catherine Keener, Kevin Mckidd, Joe Pantoliano, Uma Thurman, Ray Winstone, Julian Richings, Bonita Friedericy, Annie Ilonzeh, Tania Saulnier, Marie Avgeropoulos, Luisa D'Oliveira, Christie Laing, Marielle Jaffe, Elisa King, Chrystal Tisiga, Alexis Knapp, Charlie Gallant, Chelan Simmons, Andrea Brooks, Natassia Malthe, Max Van Ville, Serinda Swan, Dimitri Lekkos, Ona Grauer, Stefanie von Pfetten, Conrad Coates, Erica Cerra, Dylan Neal, Luke Camilleri, Holly Hougham, Ina Geraldine, Raquel Riskin, Yusleidis Oquendo, Janine Edwards, Valerie Tian, Violet Columbus, Sarah Smyth, Merritt Patterson, Julie Luck, Andrea Day, John Stewart, Suzanne Ristic, Deejay Jackson, Matthew Garrick, Stan Carp, Suzanna Ristic, Richard Harmon, Maria Olsen, Robin Lemon, Doyle Devereux, Tom Pickett, VJ Delos-Reyes, Tim Aas, Keith Dallas, Spencer Atkinson, Maya Washington, Loyd Bateman, Victor Ayala, Zane Holtz, Eli Zagoudakis, Matt Reimer, Rob Hayter, Lloyd Bateman, Shawn Beaton, Jarod Joseph, Reilly Dolman, Paul Cummings, Julie Brar, Dejan Loyola, Damian Arman, Mario Casoria, Dorla Bell, Carolyn Adair (II), Jade Pawluk, G. Patrick Currie, Darian Arman, Mariela Zapata, David L. Smith
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Catherine Keener, Amanda Peet, Oliver Platt, Rebecca Hall, Sarah Steele, Ann Morgan Guilbert, Kevin Corrigan, Lois Smith
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Dudley Moore, Bo Derek, Julie Andrews, Robert Webber, Dee Wallace, Sam Jones III, Sam J. Jones, Brian Dennehy, Max Showalter, Rad Daly, Nedra Volz, James Noble, Virginia Kiser, John Hawker, Deborah Rush, Don Calfa, Walter George Alton, Annette Martin, John Hancock, Lorry Goldman, Arthur Rosenberg, Mari Gorman, Marcy Hanson, Julia Jennings, Senilo Tanney, Kitty DeCarlo, William Lucking, Owen Sullivan, Debbie White, Laurence Carr, Camila Ashland, Adrian Aron, Gail Bowman, Burke Byrnes, Michael Champion, Doug Sheehan, J. Victor Lopez, Gregory Chase, Jon Linton, Ellen Clark, Antonia Ellis, John Chappell, Lynn Farrell, Art Kassul, Denise Crosby, Jeanetta Arnette
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Martin Balsam, John Fiedler, Lee J. Cobb, E.G. Marshall, Jack Klugman, Edward Binns, Jack Warden, Henry Fonda, Joseph Sweeney, Ed Begley Sr., George Voskovec, Robert Webber, Rudy Bond, James A. Kelly, Billy Nelson, John Savoca
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 James Mason, Kirk Douglas, Paul Lukas, Peter Lorre, Robert J. Wilke, Carleton Young, Bob Wilke, Ted de Corsia, Percy Helton, Ted Cooper, Eddie Marr, Fred Graham, Esmeralda, J.M. Kerrigan, Harry Harvey, Herb Vigran
#
#   original_release_date streaming_release_date  runtime      production_company  \
# 0            2010-02-12             2015-11-25    119.0        20th Century Fox
# 1            2010-04-30             2012-09-04     90.0  Sony Pictures Classics
# 2            1979-10-05             2014-07-24    122.0             Waner Bros.
# 3            1957-04-13             2017-01-13     95.0    Criterion Collection
# 4            1954-01-01             2016-06-10    127.0                  Disney
#
#   tomatometer_status  tomatometer_rating  tomatometer_count audience_status  audience_rating  \
# 0             Rotten                49.0              149.0         Spilled             53.0
# 1    Certified-Fresh                87.0              142.0         Upright             64.0
# 2              Fresh                67.0               24.0         Spilled             53.0
# 3    Certified-Fresh               100.0               54.0         Upright             97.0
# 4              Fresh                89.0               27.0         Upright             74.0
#
#    audience_count  tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0        254421.0                             43                               73
# 1         11574.0                             44                              123
# 2         14684.0                              2                               16
# 3        105386.0                              6                               54
# 4         68918.0                              5                               24
#
#    tomatometer_rotten_critics_count
# 0                                76
# 1                                19
# 2                                 8
# 3                                 0
# 4                                 3
#
# === Primeras 5 reseñas ===
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name review_type  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile       Fresh
# 1            m/0814255    Louise Keller       False           Urban Cinefile       Fresh
# 2            m/0814255              NaN       False      FILMINK (Australia)       Fresh
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)       Fresh
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter      Rotten
#
#   review_score review_date  \
# 0          NaN  2010-02-06
# 1          NaN  2010-02-06
# 2          NaN  2010-02-09
# 3        3.5/5  2010-02-09
# 4          NaN  2010-02-10
#
#                                                                                                                                                                                                           review_content
# 0                                       A fantasy adventure that fuses Greek mythology to contemporary American places and values. Anyone around 15 (give or take a couple of years) will thrill to the visual spectacle
# 1                                                              Uma Thurman as Medusa, the gorgon with a coiffure of writhing snakes and stone-inducing hypnotic gaze is one of the highlights of this bewitching fantasy
# 2                                                                                              With a top-notch cast and dazzling special effects, this will tide the teens over until the next Harry Potter instalment.
# 3  Whether audiences will get behind The Lightning Thief is hard to predict. Overall, it's an entertaining introduction to a promising new world -- but will the consuming shadow of Potter be too big to break free of?
# 4                                                                    What's really lacking in The Lightning Thief is a genuine sense of wonder, the same thing that brings viewers back to Hogwarts over and over again.
#
# Datos cargados exitosamente!
# Construyendo índice de búsqueda...
# Índice de búsqueda construido exitosamente!
#
# ¡Sistema listo!
#
# Instrucciones:
# - Escribe tu búsqueda y presiona Enter
# - Para salir: 'salir' o 'exit'
#
# ==================================================
#
# Búsqueda (o 'salir'):
# Por favor ingresa una búsqueda válida
#
# ==================================================
#
# Búsqueda (o 'salir'): SpAcE TraVeL
#
# Resultados para: 'SpAcE TraVeL'
# --------------------------------------------------
#
# 1. Space Chimps
#    Relevancia: 0.481
#    Calificación críticos: 33.0
#    Calificación audiencia: 33.0
#    Info: Ham III (Andy Samberg) is the grandson of the first chimpanzee who first blasted into outer space. He and two other chimp astronauts go on a dangerous mission through a black hole. Landing on an inhab...
#
# 2. Lost in Space
#    Relevancia: 0.464
#    Calificación críticos: 28.0
#    Calificación audiencia: 24.0
#    Info: The space family Robinson is on a journey to Alpha Prime in the hopes of establishing a colony there and thereby saving humanity from extinction. Their plans are foiled by the evil Dr. Smith (Gary Old...
#
# 3. A Space Program
#    Relevancia: 0.428
#    Calificación críticos: 87.0
#    Calificación audiencia: 80.0
#    Info: Artist Tom Sachs and his team build an entire space program from scratch for a handmade journey to Mars.
#
# 4. Elvis from Outer Space
#    Relevancia: 0.392
#    Calificación críticos: 0.0
#    Calificación audiencia: No disponible
#    Info:
#
# 5. Conquest of Space
#    Relevancia: 0.390
#    Calificación críticos: 60.0
#    Calificación audiencia: 26.0
#    Info: A captain (Walter Brooke), his son (Eric Fleming), a sergeant (Mickey Shaughnessy) and crew take off from a space station in a rocketship for Mars.
#
# 6. Infini
#    Relevancia: 0.367
#    Calificación críticos: 31.0
#    Calificación audiencia: 34.0
#    Info: Members of a search-and-rescue team uncover a global threat after traveling to a mining colony in outer space.
#
# 7. Muppets From Space
#    Relevancia: 0.355
#    Calificación críticos: 63.0
#    Calificación audiencia: 58.0
#    Info: With enormous enthusiasm and unsinkable optimism, daredevil Gonzo steps into his first starring role in "Muppets From Space," a hilarious extraterrestrial adventure about the search for Gonzo's past. ...
#
# 8. Ôritsu uchûgun Oneamisu no tsubasa (Royal Space Force - Wings of Honneamise)
#    Relevancia: 0.349
#    Calificación críticos: 100.0
#    Calificación audiencia: 80.0
#    Info: In this animated film, Shiro (Leo Morimoto) fails to become a navy pilot for the mythical kingdom of Honneamise but is accepted into the Royal Space Force. To keep their funding from being cut off, th...
#
# 9. Starcrash
#    Relevancia: 0.348
#    Calificación críticos: 29.0
#    Calificación audiencia: 36.0
#    Info: A space explorer and his girlfriend try to protect Earth from devastation.
#
# 10. Godzilla vs. Space Godzilla (Gojira vs. Supesugojira)
#    Relevancia: 0.329
#    Calificación críticos: 57.0
#    Calificación audiencia: 81.0
#    Info: Godzilla prepares for battle with an extraterrestrial creature that was formed from his own particles in space.
#
# 11. Suburban Commando
#    Relevancia: 0.327
#    Calificación críticos: 15.0
#    Calificación audiencia: 32.0
#    Info: Problems with his rocket compel space-traveling vigilante Shep Ramsey (Hulk Hogan) to spend some time on Earth. Plunking himself down in the middle of suburbia, he rents a room from Charlie (Christoph...
#
# 12. The Jetsons
#    Relevancia: 0.327
#    Calificación críticos: 27.0
#    Calificación audiencia: 44.0
#    Info: Based on the popular cartoon series, this animated movie, set in a time filled with family-sized spacecrafts and intergalactic travel, begins with hardworking family man George Jetson (George O'Hanlon...
#
# 13. Space Cowboys
#    Relevancia: 0.315
#    Calificación críticos: 78.0
#    Calificación audiencia: 53.0
#    Info: Clint Eastwood, Tommy Lee Jones, Donald Sutherland and James Garner star as a group of pilots whose time has come to serve their country and fulfill their dream of going to space. In 1958, the members...
#
# 14. Gravity
#    Relevancia: 0.314
#    Calificación críticos: 96.0
#    Calificación audiencia: 80.0
#    Info: Dr. Ryan Stone (Sandra Bullock) is a medical engineer on her first shuttle mission. Her commander is veteran astronaut Matt Kowalsky (George Clooney), helming his last flight before retirement. Then, ...
#
# 15. Space Station 76
#    Relevancia: 0.307
#    Calificación críticos: 68.0
#    Calificación audiencia: 30.0
#    Info: Heartbroken after his lover dumps him, a space station's closeted gay commander (Patrick Wilson) clashes with his new second-in-command (Liv Tyler), who happens to be female.
#
# 16. Zathura: A Space Adventure
#    Relevancia: 0.303
#    Calificación críticos: 76.0
#    Calificación audiencia: 51.0
#    Info: After their father (Tim Robbins) is called into work, two young boys, Walter (Josh Hutcherson) and Danny (Jonah Bobo), are left in the care of their teenage sister, Lisa (Kristen Stewart), and told th...
#
# 17. Space Chimps 2: Zartog Strikes Back
#    Relevancia: 0.289
#    Calificación críticos: 0.0
#    Calificación audiencia: 34.0
#    Info: A chimp and his pals must overthrow a tyrannical extraterrestrial on the Planet Malgor.
#
# 18. Pokémon 4Ever
#    Relevancia: 0.286
#    Calificación críticos: 16.0
#    Calificación audiencia: 54.0
#    Info: Ash and his friends travel to an island to search for a rare species of Pokemon that has the power to travel through time.
#
# 19. Plan 9 from Outer Space
#    Relevancia: 0.280
#    Calificación críticos: 67.0
#    Calificación audiencia: 46.0
#    Info: Residents of California's San Fernando Valley are under attack by flying saucers from outer space. The aliens, led by Eros (Dudley Manlove) and his assistant, Tanna (Joanna Lee), intend to conquer the...
#
# 20. Serenity
#    Relevancia: 0.279
#    Calificación críticos: 82.0
#    Calificación audiencia: 91.0
#    Info: In this continuation of the television series "Firefly," a group of rebels travels the outskirts of space aboard their ship, Serenity, outside the reach of the Alliance, a sinister regime that control...
#
# 21. Gattaca
#    Relevancia: 0.278
#    Calificación críticos: 82.0
#    Calificación audiencia: 87.0
#    Info: Vincent Freeman (Ethan Hawke) has always fantasized about traveling into outer space, but is grounded by his status as a genetically inferior "in-valid." He decides to fight his fate by purchasing the...
#
# 22. 400 Days
#    Relevancia: 0.275
#    Calificación críticos: 22.0
#    Calificación audiencia: 41.0
#    Info: Isolated astronauts in outer space begin to lose their grip on reality.
#
# 23. Hubble 3D
#    Relevancia: 0.271
#    Calificación críticos: 88.0
#    Calificación audiencia: 86.0
#    Info: In May 2009, NASA astronauts embark on a mission to perform maintenance and repairs to the Hubble Space Telescope. As they go about their tasks, danger and beauty are never far away. The nature of spa...
#
# 24. Ad Astra
#    Relevancia: 0.265
#    Calificación críticos: 83.0
#    Calificación audiencia: 40.0
#    Info: Thirty years ago, Clifford McBride led a voyage into deep space, but the ship and crew were never heard from again. Now his son -- a fearless astronaut -- must embark on a daring mission to Neptune to...
#
# 25. Fortress 2: Re-Entry
#    Relevancia: 0.259
#    Calificación críticos: 0.0
#    Calificación audiencia: 22.0
#    Info: In this sci-fi sequel, John Brennick (Christopher Lambert) is still on the run from the nefarious Men-Tel Corporation. After getting separated from his wife, Karen (Beth Toussaint), and son, Danny (Ai...
#
# 26. The Green Slime
#    Relevancia: 0.250
#    Calificación críticos: 17.0
#    Calificación audiencia: 41.0
#    Info: Two space-station astronauts (Robert Horton, Richard Jaeckel) destroy an asteroid, then face monsters formed from viscous cells.
#
# 27. Color Out of Space
#    Relevancia: 0.248
#    Calificación críticos: 86.0
#    Calificación audiencia: 82.0
#    Info: After a meteorite lands in the front yard of their farm, Nathan Gardner and his family find themselves battling a mutant extraterrestrial organism that infects their minds and bodies, transforming the...
#
# 28. Battlestar Galactica
#    Relevancia: 0.246
#    Calificación críticos: 32.0
#    Calificación audiencia: 61.0
#    Info: Space-colony ambush survivors (Richard Hatch, Dirk Benedict, Lorne Greene) head for unknown Earth, followed by the robot Cylons.
#
# 29. Countdown
#    Relevancia: 0.243
#    Calificación críticos: 67.0
#    Calificación audiencia: 27.0
#    Info: A scientist (James Caan) replaces a military officer (Robert Duvall) as an astronaut on a space-race moonshot.
#
# 30. Moonraker
#    Relevancia: 0.241
#    Calificación críticos: 60.0
#    Calificación audiencia: 43.0
#    Info: Agent 007 (Roger Moore) blasts into orbit in this action-packed adventure that takes him to Venice, Rio De Janeiro and outer space. When Bond investigates the hijacking of an American space shuttle, h...
#
# 31. Battle Beyond the Stars
#    Relevancia: 0.236
#    Calificación críticos: 45.0
#    Calificación audiencia: 42.0
#    Info: Shad of Akir (Richard Thomas) recruits a space cowboy (George Peppard) and other warriors to defend his planet from a barbarian's army.
#
# 32. Space Truckers
#    Relevancia: 0.235
#    Calificación críticos: 15.0
#    Calificación audiencia: 29.0
#    Info: A freight pilot (Dennis Hopper), his girlfriend (Debi Mazar) and an apprentice (Stephen Dorff) try to deliver cargo to Earth in 2197.
#
# 33. Treasure Planet
#    Relevancia: 0.235
#    Calificación críticos: 69.0
#    Calificación audiencia: 72.0
#    Info: The legendary "loot of a thousand worlds" inspires an intergalactic treasure hunt when 15-year-old Jim Hawkins stumbles upon a map to the greatest pirate trove in the universe in Walt Disney Pictures'...
#
# 34. Just Before I Go
#    Relevancia: 0.233
#    Calificación críticos: 10.0
#    Calificación audiencia: 59.0
#    Info: A man travels back to his hometown to make amends before he gives up on life.
#
# 35. Spark: A Space Tail
#    Relevancia: 0.232
#    Calificación críticos: 14.0
#    Calificación audiencia: 35.0
#    Info: Spark (Jace Norman) is a wisecracking teenage monkey who lives on an abandoned planet with his friends Chunk (Rob deLeeuw) and Vix (Jessica Biel). Thirteen years ago, power-hungry Zhong (Alan C. Peter...
#
# ==================================================
#
# Búsqueda (o 'salir'): *family*
#
# Resultados para: '*family*'
# --------------------------------------------------
#
# 1. The Jetsons
#    Relevancia: 0.366
#    Calificación críticos: 27.0
#    Calificación audiencia: 44.0
#    Info: Based on the popular cartoon series, this animated movie, set in a time filled with family-sized spacecrafts and intergalactic travel, begins with hardworking family man George Jetson (George O'Hanlon...
#
# 2. Kind Hearts and Coronets
#    Relevancia: 0.363
#    Calificación críticos: 100.0
#    Calificación audiencia: 94.0
#    Info: When his mother eloped with an Italian opera singer, Louis Mazzini (Dennis Price) was cut off from her aristocratic family. After the family refuses to let her be buried in the family mausoleum, Louis...
#
# 3. Kal Ho Naa Ho
#    Relevancia: 0.354
#    Calificación críticos: 70.0
#    Calificación audiencia: 92.0
#    Info: Naina is bogged down by the conflict in her family. She falls in love with Aman, who unites her family and teaches her how to enjoy life, but he encourages her to fall in love with her best friend, Ro...
#
# 4. Just 45 Minutes From Broadway
#    Relevancia: 0.345
#    Calificación críticos: 18.0
#    Calificación audiencia: 71.0
#    Info: Old family secrets come to light during a family gathering to meet the fiance of the older of two sisters.
#
# 5. Sordid Lives
#    Relevancia: 0.343
#    Calificación críticos: 37.0
#    Calificación audiencia: 85.0
#    Info: Sometimes it takes a death to bring a family together. The all-star casts puts a comedic twist on a story of unconditional love, acceptance and "coming out" in a Texas family. The eccentric cast of ch...
#
# 6. In the Family
#    Relevancia: 0.340
#    Calificación críticos: 97.0
#    Calificación audiencia: 75.0
#    Info: After his partner dies in a car accident, a gay man (Patrick Wang) must fight for custody of the boy (Sebastian Brodziak) he's come to love as his own son.
#
# 7. The Family Tree
#    Relevancia: 0.337
#    Calificación críticos: 10.0
#    Calificación audiencia: 24.0
#    Info: An unusual accident leaves an Ohio woman (Hope Davis) with amnesia, leading to a second chance at happiness for herself and her family.
#
# 8. Monsoon Wedding
#    Relevancia: 0.337
#    Calificación críticos: 95.0
#    Calificación audiencia: 87.0
#    Info: The exuberant ensemble comedy unites a Punjabi family for the wedding of a family member. Relatives from all over the world descend on Delhi for the wedding ceremony. Universal in theme, the film expl...
#
# 9. The Fitzgerald Family Christmas
#    Relevancia: 0.330
#    Calificación críticos: 64.0
#    Calificación audiencia: 49.0
#    Info: Rifts emerge among family members when their long-estranged patriarch decides to come home for the holidays.
#
# 10. Baarìa
#    Relevancia: 0.326
#    Calificación críticos: 55.0
#    Calificación audiencia: 50.0
#    Info: Three generations of a Sicilian family tell their history.
#
# 11. The Family
#    Relevancia: 0.319
#    Calificación críticos: 28.0
#    Calificación audiencia: 41.0
#    Info: After ratting out his Mafia cohorts, Giovanni Manzioni (Robert De Niro) and his family enter the Witness Protection Program and relocate to a French town. Despite the best efforts of their handler (To...
#
# 12. The Covenant
#    Relevancia: 0.318
#    Calificación críticos: 4.0
#    Calificación audiencia: 62.0
#    Info: In the 17th century, five families with supernatural powers make a pact of silence. Eventually one power-hungry family is banished. The descendants of those four remaining families are heirs to tremen...
#
# 13. The Addams Family
#    Relevancia: 0.316
#    Calificación críticos: 44.0
#    Calificación audiencia: 69.0
#    Info: Members of the mysterious and spooky Addams family -- Gomez, Morticia, Pugsley, Wednesday, Uncle Fester and Grandma -- are readily preparing for a visit from their even creepier relatives. But trouble...
#
# 14. American Fable
#    Relevancia: 0.312
#    Calificación críticos: 75.0
#    Calificación audiencia: 40.0
#    Info: With her family's livelihood imperiled by the farm crisis during the 1980s, 11-year-old Gitty loses herself in a world of fantasy and make believe. But she stumbles into her own fairy tale when she ma...
#
# 15. Chroniques sexuelles d'une famille d'aujourd'hui (Sexual Chronicles of a French Family)
#    Relevancia: 0.312
#    Calificación críticos: 0.0
#    Calificación audiencia: 27.0
#    Info: A family begins to discuss the subject of sex among themselves for the first time after their teenage son is caught in a provocative situation in school.
#
# 16. Nicky's Family
#    Relevancia: 0.306
#    Calificación críticos: 64.0
#    Calificación audiencia: 86.0
#    Info: In 1939, Nicholas Winton successfully organizes and carries out the relocation of 669 endangered Jewish children from Czechoslovakia and places them with British host families.
#
# 17. Under The Sun
#    Relevancia: 0.301
#    Calificación críticos: 94.0
#    Calificación audiencia: 69.0
#    Info: An ordinary family in Pyongyang is followed for a year.
#
# 18. Coco
#    Relevancia: 0.299
#    Calificación críticos: 97.0
#    Calificación audiencia: 94.0
#    Info: Despite his family's generations-old ban on music, young Miguel dreams of becoming an accomplished musician like his idol Ernesto de la Cruz. Desperate to prove his talent, Miguel finds himself in the...
#
# 19. Early Summer
#    Relevancia: 0.298
#    Calificación críticos: 100.0
#    Calificación audiencia: 93.0
#    Info: Noriko (Setsuko Hara) lives in postwar Tokyo with her extended family. Although she enjoys her career and her friends, her more traditionally minded family worries about the fact that she's still sing...
#
# 20. In America
#    Relevancia: 0.298
#    Calificación críticos: 89.0
#    Calificación audiencia: 91.0
#    Info: The Sullivan family emigrates from Ireland to New York City as father Johnny (Paddy Considine) chases his dream of being an actor. Living in a small Hell's Kitchen apartment, the family settles into A...
#
# 21. The Godfather, Part III
#    Relevancia: 0.296
#    Calificación críticos: 68.0
#    Calificación audiencia: 78.0
#    Info: As Michael Corleone (Al Pacino) ages, he finds that being the head of the Corleone crime family isn't getting any easier. He wants his family out of the Mafia, but the mob kingpin (Eli Wallach) isn't ...
#
# 22. Midnight Family
#    Relevancia: 0.295
#    Calificación críticos: 97.0
#    Calificación audiencia: 82.0
#    Info: In Mexico City's wealthiest neighborhoods, the Ochoa family runs a private ambulance. As they try to make a living in this cutthroat industry, they struggle to keep their financial needs from compromi...
#
# 23. The Family That Preys
#    Relevancia: 0.294
#    Calificación críticos: 53.0
#    Calificación audiencia: 61.0
#    Info: Despite their differences in social class, Charlotte (Kathy Bates) and Alice (Alfre Woodard) are good friends for many years. Then secrets, greed and scandal surrounding both their families throw the ...
#
# 24. The Cold Light of Day
#    Relevancia: 0.291
#    Calificación críticos: 4.0
#    Calificación audiencia: 29.0
#    Info: Young business consultant Will Shaw (Henry Cavill) flies to Spain for a vacation aboard his family's sailboat. When Will returns from some on-shore shopping, his family is gone and will be killed if h...
#
# 25. Tig Notaro: Happy to Be Here
#    Relevancia: 0.291
#    Calificación críticos: 100.0
#    Calificación audiencia: 71.0
#    Info: Dorian embarks on a journey to make peace with his family.
#
# 26. Stuart Saves His Family
#    Relevancia: 0.290
#    Calificación críticos: 30.0
#    Calificación audiencia: 52.0
#    Info: New Age therapist Stuart Smalley (Al Franken) tries to rid his family of substance abuse and co-dependency.
#
# 27. My Neighbors the Yamadas
#    Relevancia: 0.290
#    Calificación críticos: 78.0
#    Calificación audiencia: 76.0
#    Info: The adventures of a modern family in Japan.
#
# 28. Disneynature Chimpanzee
#    Relevancia: 0.289
#    Calificación críticos: 76.0
#    Calificación audiencia: 75.0
#    Info: Deep in an African forest lives a family of chimpanzees, including a baby named Oscar. Displaying the playful curiosity and ingenuity of fellow primates, Oscar and his family navigate the forest's com...
#
# 29. The Manson Family
#    Relevancia: 0.284
#    Calificación críticos: 69.0
#    Calificación audiencia: 50.0
#    Info: Members of Charles Manson's cult tell their story.
#
# 30. Trouble Is My Business
#    Relevancia: 0.284
#    Calificación críticos: 100.0
#    Calificación audiencia: 95.0
#    Info: A detective falls in love with two sisters from the Montemar family.
#
# 31. Arven (The Inheritance)
#    Relevancia: 0.281
#    Calificación críticos: 75.0
#    Calificación audiencia: 84.0
#    Info: Christoffer (Ulrich Thomsen) is a Danish man who stands to inherit a huge fortune, but he has abandoned his family's industrial business to live with his beautiful wife, Maria (Lisa Werlinder). When h...
#
# 32. Monster Family
#    Relevancia: 0.273
#    Calificación críticos: 10.0
#    Calificación audiencia: 22.0
#    Info: Dracula's spell turns a woman and her loved ones into a vampire, a mummy, a werewolf and Frankenstein's monster.
#
# 33. A Boy Called Sailboat
#    Relevancia: 0.271
#    Calificación críticos: 80.0
#    Calificación audiencia: 77.0
#    Info: A Hispanic family find hope in their extraordinary son named Sailboat.
#
# 34. Glorious 39
#    Relevancia: 0.271
#    Calificación críticos: 46.0
#    Calificación audiencia: 42.0
#    Info: A mystery surrounds a British family on the eve of World War II.
#
# 35. A Thread of Deceit: The Hart Family Tragedy
#    Relevancia: 0.270
#    Calificación críticos: 83.0
#    Calificación audiencia: No disponible
#    Info:
#
# ==================================================
#
# Búsqueda (o 'salir'): HORROR
#
# Resultados para: 'HORROR'
# --------------------------------------------------
#
# 1. The Horror of H.P. Lovecraft (LovecraCked! The Movie)
#    Relevancia: 0.771
#    Calificación críticos: 40.0
#    Calificación audiencia: 31.0
#    Info:
#
# 2. My Amityville Horror
#    Relevancia: 0.672
#    Calificación críticos: 70.0
#    Calificación audiencia: 39.0
#    Info: Daniel Lutz, who was a child when the events recounted in Jay Anson's "The Amityville Horror" occurred, tells his side of the story.
#
# 3. Verotika
#    Relevancia: 0.466
#    Calificación críticos: 24.0
#    Calificación audiencia: 21.0
#    Info: An anthology of horror tales.
#
# 4. Abbott and Costello Meet Frankenstein
#    Relevancia: 0.397
#    Calificación críticos: 89.0
#    Calificación audiencia: 85.0
#    Info: In the first of Bud Abbott and Lou Costello's horror vehicles for Universal Pictures, the inimitable comic duo star as railway baggage handlers in northern Florida. When a pair of crates belonging to ...
#
# 5. Poison
#    Relevancia: 0.385
#    Calificación críticos: 77.0
#    Calificación audiencia: 68.0
#    Info: Three stories: "Hero," about a boy who kills his father; "Horror," black-and-white sci-fi; and "Homo," set in prison.
#
# 6. Slaughterhouse Rulez
#    Relevancia: 0.384
#    Calificación críticos: 39.0
#    Calificación audiencia: 55.0
#    Info: A British boarding school turns into a battleground when unspeakable horrors emerge from the ground.
#
# 7. Evil Little Things
#    Relevancia: 0.368
#    Calificación críticos: 50.0
#    Calificación audiencia: 0.0
#    Info: An anthology of horror tales.
#
# 8. Velvet Buzzsaw
#    Relevancia: 0.368
#    Calificación críticos: 62.0
#    Calificación audiencia: 35.0
#    Info:
#
# 9. Baskin
#    Relevancia: 0.362
#    Calificación críticos: 79.0
#    Calificación audiencia: 46.0
#    Info: Policemen (Gorkem Kasal, Ergun Kuyucu) face a night of horror in a subterranean labyrinth after answering a distress call.
#
# 10. Found Footage 3D
#    Relevancia: 0.361
#    Calificación críticos: 100.0
#    Calificación audiencia: 47.0
#    Info: A film crew making a found footage horror movie find themselves in a horror movie when an evil entity escapes into their footage.
#
# 11. Ways To Live Forever
#    Relevancia: 0.349
#    Calificación críticos: 83.0
#    Calificación audiencia: 78.0
#    Info: Sam needs to learn about UFOs, horror movies and airships before he dies of leukemia.
#
# 12. Blood Fest
#    Relevancia: 0.307
#    Calificación críticos: 50.0
#    Calificación audiencia: 43.0
#    Info: Fans flock to a festival celebrating the most iconic horror movies, only to discover that the charismatic showman behind the event has a diabolical agenda. As festival attendees start dying, three tee...
#
# 13. #Horror
#    Relevancia: 0.282
#    Calificación críticos: 46.0
#    Calificación audiencia: 9.0
#    Info: Preteen girls face a night of terror when their obsession with a disturbing online game goes too far.
#
# 14. The Amityville Horror
#    Relevancia: 0.280
#    Calificación críticos: 27.0
#    Calificación audiencia: 52.0
#    Info: Chiller about a family who is terrorized by supernatural forces when they move into a new house in New York State which was the scene of a recent mass killing and the home of an 18th-century satanist....
#
# 15. Holiday Hell
#    Relevancia: 0.280
#    Calificación críticos: 20.0
#    Calificación audiencia: 17.0
#    Info: Four horror tales, each set during a different holiday.
#
# 16. The Hills Run Red
#    Relevancia: 0.272
#    Calificación críticos: 57.0
#    Calificación audiencia: 33.0
#    Info: Terror strikes a group of friends who visit the location of a horror-movie shoot.
#
# 17. Nosferatu, a Symphony of Horror (Nosferatu, eine Symphonie des Grauens) (Nosferatu the Vampire)
#    Relevancia: 0.272
#    Calificación críticos: 97.0
#    Calificación audiencia: 87.0
#    Info: In this highly influential silent horror film, the mysterious Count Orlok (Max Schreck) summons Thomas Hutter (Gustav von Wangenheim) to his remote Transylvanian castle in the mountains. The eerie Orl...
#
# 18. Howling III: The Marsupials
#    Relevancia: 0.271
#    Calificación críticos: 17.0
#    Calificación audiencia: 16.0
#    Info: An Australian scientist (Barry Otto) finds marsupial werewolves, one of whom (Imogen Annesley) finds work in a horror movie.
#
# 19. Stay Alive
#    Relevancia: 0.268
#    Calificación críticos: 10.0
#    Calificación audiencia: 55.0
#    Info: Teenagers decide to pass idle time by playing an online game that has a horror theme. But the action taking place on their computer screens becomes a terrifying reality when they realize that each tim...
#
# 20. Three...Extremes (Saam gaang yi)
#    Relevancia: 0.264
#    Calificación críticos: 84.0
#    Calificación audiencia: 77.0
#    Info:
#
# 21. Scooby-Doo and the Witch's Ghost
#    Relevancia: 0.263
#    Calificación críticos: 50.0
#    Calificación audiencia: 73.0
#    Info: Scooby and friends investigate creepy goings-on and a mystery involving a famous horror writer in a small Massachusetts town.
#
# 22. Reality (Réalité)
#    Relevancia: 0.263
#    Calificación críticos: 64.0
#    Calificación audiencia: 66.0
#    Info: Bob agrees to finance Jason's horror film, and asks him to find the best groan in the history of cinema.
#
# 23. Life Is Beautiful (La Vita è bella)
#    Relevancia: 0.262
#    Calificación críticos: 80.0
#    Calificación audiencia: 96.0
#    Info: A gentle Jewish-Italian waiter, Guido Orefice (Roberto Benigni), meets Dora (Nicoletta Braschi), a pretty schoolteacher, and wins her over with his charm and humor. Eventually they marry and have a so...
#
# 24. Trapped Ashes
#    Relevancia: 0.260
#    Calificación críticos: 33.0
#    Calificación audiencia: 14.0
#    Info: Seven strangers on a tour of a Hollywood horror set must tell their scariest stories in order to escape.
#
# 25. The Final Girls
#    Relevancia: 0.257
#    Calificación críticos: 72.0
#    Calificación audiencia: 70.0
#    Info: Max, recently orphaned, goes to see a screening of a B-horror movie that her mother made 20 years earlier. When Max and her friends find themselves in the world of the film itself, they must apply the...
#
# 26. The Horror Show
#    Relevancia: 0.255
#    Calificación críticos: 0.0
#    Calificación audiencia: 27.0
#    Info: An executed killer (Brion James) haunts the house where a policeman (Lance Henriksen) lives with his wife (Rita Taggart) and children.
#
# 27. You Might Be the Killer
#    Relevancia: 0.253
#    Calificación críticos: 60.0
#    Calificación audiencia: 48.0
#    Info: A camp counselor suffering from memory loss finds himself in the middle of a horror movie massacre.
#
# 28. Pulse
#    Relevancia: 0.251
#    Calificación críticos: 11.0
#    Calificación audiencia: 27.0
#    Info: After her boyfriend commits suicide, a psychology student (Kristen Bell) and her friends begin receiving unsettling e-mails and video messages. After a number of disappearances across campus, she team...
#
# 29. The Houses October Built
#    Relevancia: 0.249
#    Calificación críticos: 60.0
#    Calificación audiencia: 30.0
#    Info: Friends (Brandy Schaefer, Mikey Roe, Jeff Larson) encounter genuine horror during a road trip to visit haunted houses.
#
# 30. Desert Flower
#    Relevancia: 0.249
#    Calificación críticos: 50.0
#    Calificación audiencia: 72.0
#    Info: Waris Dirie (Liya Kebede) escapes from the horrors of Somalia to work in London, where a photographer (Timothy Spall) and an agent (Juliet Stevenson) turn her into a top supermodel.
#
# 31. Vivarium
#    Relevancia: 0.248
#    Calificación críticos: 72.0
#    Calificación audiencia: 38.0
#    Info:
#
# 32. Lightning Bug
#    Relevancia: 0.244
#    Calificación críticos: 38.0
#    Calificación audiencia: 64.0
#    Info: A romantic relationship may prevent a young man (Bret Harrison) from realizing his dream of working with makeup effects for horror films.
#
# 33. The Hills Have Eyes
#    Relevancia: 0.243
#    Calificación críticos: 52.0
#    Calificación audiencia: 58.0
#    Info: A family road trip takes a terrifying turn when the travelers become stranded in a barren atomic zone established by the U.S. government. However, the unlucky travelers discover to their horror that t...
#
# 34. Ghost Stories
#    Relevancia: 0.237
#    Calificación críticos: 33.0
#    Calificación audiencia: 17.0
#    Info: From the directors of "Lust Stories" and "Bombay Talkies" comes four short films that take a twisted turn into the spine-chilling realm of horror.
#
# 35. Hell Fest
#    Relevancia: 0.233
#    Calificación críticos: 40.0
#    Calificación audiencia: 41.0
#    Info: On Halloween night, three young women and their respective boyfriends head to Hell Fest -- a ghoulish traveling carnival that features a labyrinth of rides, games and mazes. They soon face a bloody ni...
#
# ==================================================
#
# Búsqueda (o 'salir'): salir
#
# ¡Gracias por usar el sistema!
