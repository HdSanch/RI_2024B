# %% [markdown]
# <a href="https://colab.research.google.com/github/HdSanch/RI_2024B/blob/main/02tfidfmatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 02: Cálculo de la Matriz TF-IDF y Búsqueda de Consultas en un Corpus
#
# ##### Integrantes: Dilan Andrade, Hernán Sánchez y Galo Tarapués

# %% [markdown]
# ### 1. Preprocesamiento del texto:

# %% [markdown]
# - Lectura del corpus desde el archivo TXT.

# %%
import re
import math
datos = []
with open('/content/02tfidfmatrix_corpus.txt', mode='r', encoding='utf-8') as file:
    datos = file.readlines()

datos = [line.strip() for line in datos]

# %% [markdown]
# - Normalización del texto (conversión a minúsculas, eliminación de signos de puntuación).

# %%
vocab = []
for line in datos:
    line = re.sub(r'^Documento \d+: ', '', line)

    vocab.extend(line.lower().replace(',', '').replace('.', '').split())

vocab = set(vocab)
print("Número de palabras únicas en el vocabulario:", len(vocab))
print("Vocabulario:", vocab)
# Out:
# Número de palabras únicas en el vocabulario: 230
# Vocabulario: {'realidad', 'recomendaciones', 'las', 'contexto', 'importar', 'creciente', 'distancia', 'humanidad', 'una', 'competencias', 'cómo', 'diagnostican', 'mercado', 'mejores', 'populares', 'alcanzado', 'interactuar', 'sin', 'comercio', 'avances', 'público', 'donde', 'acceder', 'realistas', 'sectores', 'aquellos', 'sino', 'ética', 'trabajos', 'videojuegos', 'e-sports', 'automático', 'escenas', 'digitales', 'películas', 'principal', 'solo', 'ofrecer', 'cuándo', 'bienestar', 'ficción', 'facilitando', 'a', 'hábitos', 'flexibilidad', 'medicina', 'género', 'aprendizaje', 'para', 'algoritmos', 'futuro', 'diarias', 'cursos', 'se', 'sean', 'vida', 'datos', 'que', 'dispositivos', 'tecnologías', 'forma', 'compras', 'promueven', 'eficaces', 'artificial', 'continúa', 'cuidados', 'transacciones', 'vez', 'mundo', 'en', 'atraen', 'desafío', 'evolucionado', 'siguen', 'estudiantes', 'crear', 'avanzadas', 'su', 'cada', 'cambiando', 'además', 'ha', 'desafían', 'series', 'espectadores', 'educativa', 'siendo', 'tratan', 'aumentada', 'enfermedades', 'aunque', 'adopción', 'viaje', 'consume', 'nivel', 'jugadores', 'de', 'calidad', 'un', 'justas', 'cine', 'implicaciones', 'convertido', 'sigue', 'finanzas', 'reto', 'literarios', 'los', 'tecnología', 'mundos', 'hasta', 'utilizan', 'compramos', 'desde', 'libros', 'garantizar', 'enfoque', 'transformado', 'línea', 'salud', 'pagos', 'géneros', 'ciencia', 'reflexionar', 'integral', 'está', 'la', 'permitiendo', 'educación', 'efectos', 'portátiles', 'accesibles', 'temas', 'optimizando', 'nuevas', 'saludables', 'aumento', 'beneficios', 'completo', 'inteligencia', 'crecimiento', 'experiencia', 'plataformas', 'están', 'personalizadas', 'electrónico', 'producciones', 'con', 'demanda', 'personal', 'aplicaciones', 'personalizados', 'fundamental', 'perpetúen', 'planetas', 'es', 'pueden', 'rápidamente', 'presencial', 'interacción', 'personas', 'experiencias', 'más', 'falta', 'streaming', 'mejorando', 'usuario', 'explorando', 'cinematográficas', 'individual', 'sesgos', 'ubicación', 'no', 'otros', 'adoptando', 'uno', 'invita', 'el', 'telemedicina', 'consumidores', 'sus', 'buscan', 'profesionales', 'tratamientos', 'herramientas', 'eficiencia', 'permitido', 'basadas', 'este', 'todo', 'especialmente', 'mayores', 'mejorar', 'transformando', 'llevado', 'acceso', 'empresas', 'médicos', 'inmersivos', 'tiempo', 'visuales', 'nuevo', 'virtuales', 'desarrollo', 'prometedor', 'cambiado', 'y', 'muchas', 'incorporando', 'democratizando', 'embargo', 'contenido', 'sobre', 'real', 'entretiene', 'tecnológicos', 'impulsa', 'millones', 'años', 'decisiones', 'prioridad', 'monitorean', 'programas', 'como', 'ahora', 'también', 'rápidos', 'habilidades', 'avanzando'}

# %% [markdown]
# # 2. Construcción de la matriz TF-IDF:

# %% [markdown]
# - Cálculo de la frecuencia de término (TF) para cada término en cada documento.

# %%
def tf(term, document):
    # return document.count(term)
    words = document.lower().split()
    # Contar cuántas veces aparece el término en la lista de palabras
    return words.count(term.lower())

# %% [markdown]
# - Cálculo de la frecuencia inversa de documento (IDF) para cada término en el corpus.

# %%
def idf(term, corpus):
    num_documents_with_term = sum(1 for doc in corpus if term in doc)
    if num_documents_with_term == 0:
        return 0

    return math.log10(len(corpus) / num_documents_with_term)

# %% [markdown]
# - Cálculo del peso TF-IDF para cada término en cada documento.

# %%
def tfidf(term, document, corpus):
    return tf(term, document) * idf(term, corpus)

tfidf_matrix = {}
for doc_index, document in enumerate(datos):
    tfidf_matrix[doc_index] = {}
    for term in vocab:
        tfidf_matrix[doc_index][term] = tfidf(term, document, datos)

# %%
for doc_index, doc_tfidf in tfidf_matrix.items():
    print(f"Documento {doc_index+1}:")
    for term, weight in doc_tfidf.items():
        tf_value = tf(term, datos[doc_index])
        idf_value = idf(term, datos)
        print(f"  {term}: TF={tf_value:.4f}, IDF={idf_value:.4f}, TF-IDF={weight:.4f}")
# Out:
# Documento 1:
#   realidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   recomendaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   las: TF=3.0000, IDF=0.0580, TF-IDF=0.1740
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   creciente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   distancia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cómo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   diagnostican: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mercado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interactuar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sin: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   comercio: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avances: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   público: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   donde: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceder: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   aquellos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   trabajos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   videojuegos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   escenas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   digitales: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   películas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   principal: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   cuándo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   a: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   medicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   para: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   algoritmos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   futuro: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   diarias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   sean: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   que: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   dispositivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnologías: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   forma: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   compras: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   artificial: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   continúa: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   cuidados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transacciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vez: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mundo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   en: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   atraen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desafío: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   evolucionado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siguen: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   estudiantes: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   crear: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   su: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   cada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   además: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   ha: TF=0.0000, IDF=0.1249, TF-IDF=0.0000
#   desafían: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   series: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   espectadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educativa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siendo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   tratan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumentada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfermedades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aunque: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   adopción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   viaje: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consume: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nivel: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   jugadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   de: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   calidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   un: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   justas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   cine: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   implicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   convertido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sigue: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   finanzas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   reto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   literarios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   los: TF=0.0000, IDF=0.1249, TF-IDF=0.0000
#   tecnología: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   mundos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   hasta: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   utilizan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   compramos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desde: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   libros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   garantizar: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   enfoque: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transformado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   línea: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   salud: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   pagos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   géneros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ciencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   reflexionar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   integral: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   está: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   la: TF=4.0000, IDF=0.0000, TF-IDF=0.0000
#   permitiendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   efectos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   portátiles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   accesibles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   saludables: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumento: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   crecimiento: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   experiencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   plataformas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   están: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   personalizadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   electrónico: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   demanda: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   personal: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   aplicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   perpetúen: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interacción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   experiencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   más: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   falta: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   uno: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   buscan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   profesionales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratamientos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   herramientas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   basadas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   este: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   todo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   especialmente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mayores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorar: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   transformando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   llevado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   médicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   virtuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desarrollo: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   y: TF=2.0000, IDF=0.0580, TF-IDF=0.1160
#   muchas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   millones: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   prioridad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   monitorean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   programas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   como: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   ahora: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   también: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
# Documento 2:
#   realidad: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   recomendaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   las: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   creciente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   distancia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   cómo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   diagnostican: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mercado: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   mejores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   interactuar: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   sin: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   comercio: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avances: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   público: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   donde: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   acceder: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aquellos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   trabajos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   videojuegos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   escenas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   digitales: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   películas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   principal: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   cuándo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   a: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   medicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   para: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   algoritmos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   futuro: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   diarias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   sean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   que: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   dispositivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnologías: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   forma: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   compras: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   artificial: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   continúa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cuidados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transacciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vez: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mundo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   en: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   atraen: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   desafío: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   evolucionado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siguen: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   estudiantes: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   crear: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   su: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   cada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   además: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   ha: TF=1.0000, IDF=0.1249, TF-IDF=0.1249
#   desafían: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   series: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   espectadores: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   educativa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumentada: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   enfermedades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aunque: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   adopción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   viaje: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consume: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nivel: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   jugadores: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   de: TF=3.0000, IDF=0.0000, TF-IDF=0.0000
#   calidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   un: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   justas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cine: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   implicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   convertido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sigue: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   finanzas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   reto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   literarios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   los: TF=2.0000, IDF=0.1249, TF-IDF=0.2499
#   tecnología: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   mundos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   hasta: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   utilizan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   compramos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desde: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   libros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   garantizar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfoque: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transformado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   línea: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   salud: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   pagos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   géneros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ciencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   reflexionar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   integral: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   está: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   la: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   permitiendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   efectos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   portátiles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   accesibles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   saludables: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumento: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   crecimiento: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   experiencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   plataformas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   están: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   personalizadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   electrónico: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   demanda: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   personal: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   aplicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   perpetúen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interacción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   experiencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   más: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   falta: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   uno: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=3.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   buscan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   profesionales: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   tratamientos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   herramientas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   basadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   este: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   todo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   especialmente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mayores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorar: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   transformando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   llevado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   médicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   virtuales: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   desarrollo: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   y: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   muchas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   millones: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   prioridad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   monitorean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   programas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   como: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   ahora: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   también: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
# Documento 3:
#   realidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   recomendaciones: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   las: TF=2.0000, IDF=0.0580, TF-IDF=0.1160
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   creciente: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   distancia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cómo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   diagnostican: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mercado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejores: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interactuar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sin: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   comercio: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   avances: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   público: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   donde: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceder: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aquellos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   trabajos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   videojuegos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   escenas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   digitales: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   películas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   principal: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   cuándo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   a: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   medicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   para: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   algoritmos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   futuro: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   diarias: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   sean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   que: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   dispositivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnologías: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   forma: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   compras: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   artificial: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   continúa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cuidados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transacciones: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   vez: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mundo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   en: TF=3.0000, IDF=0.0000, TF-IDF=0.0000
#   atraen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desafío: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   evolucionado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siguen: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   estudiantes: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   crear: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   su: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   cada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   además: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   ha: TF=1.0000, IDF=0.1249, TF-IDF=0.1249
#   desafían: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   series: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   espectadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educativa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumentada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfermedades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aunque: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   adopción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   viaje: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consume: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nivel: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   jugadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   de: TF=3.0000, IDF=0.0000, TF-IDF=0.0000
#   calidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   un: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   justas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cine: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   implicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   convertido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sigue: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   finanzas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   reto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   literarios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   los: TF=2.0000, IDF=0.1249, TF-IDF=0.2499
#   tecnología: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   mundos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   hasta: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   utilizan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   compramos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desde: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   libros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   garantizar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfoque: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transformado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   línea: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   salud: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   pagos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   géneros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ciencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   reflexionar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   integral: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   está: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   la: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   permitiendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   efectos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   portátiles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   accesibles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   nuevas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   saludables: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumento: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   crecimiento: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   experiencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   plataformas: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   están: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   personalizadas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   electrónico: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   demanda: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   personal: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   aplicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   perpetúen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interacción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   experiencias: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   más: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   falta: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   uno: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   buscan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   profesionales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratamientos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   herramientas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   basadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   este: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   todo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   especialmente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mayores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorar: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   transformando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   llevado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   médicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   virtuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desarrollo: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   y: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   muchas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   millones: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   prioridad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   monitorean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   programas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   como: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   ahora: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   también: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
# Documento 4:
#   realidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   recomendaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   las: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   creciente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   distancia: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cómo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   diagnostican: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mercado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interactuar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sin: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   comercio: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avances: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   público: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   donde: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceder: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aquellos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   trabajos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   videojuegos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   escenas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   digitales: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   películas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   principal: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   cuándo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   a: TF=4.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   medicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   para: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   algoritmos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   futuro: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   diarias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   sean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   que: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   dispositivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnologías: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   forma: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   compras: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   artificial: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   continúa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cuidados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transacciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vez: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mundo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   en: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   atraen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desafío: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   evolucionado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siguen: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   estudiantes: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   crear: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   su: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   cada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   además: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   ha: TF=1.0000, IDF=0.1249, TF-IDF=0.1249
#   desafían: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   series: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   espectadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educativa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumentada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfermedades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aunque: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   adopción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   viaje: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consume: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nivel: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   jugadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   de: TF=4.0000, IDF=0.0000, TF-IDF=0.0000
#   calidad: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   un: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   justas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cine: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   implicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   convertido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sigue: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   finanzas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   reto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   literarios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   los: TF=1.0000, IDF=0.1249, TF-IDF=0.1249
#   tecnología: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   mundos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   hasta: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   utilizan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   compramos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desde: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   libros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   garantizar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfoque: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transformado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   línea: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   salud: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   pagos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   géneros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ciencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   reflexionar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   integral: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   está: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   la: TF=4.0000, IDF=0.0000, TF-IDF=0.0000
#   permitiendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educación: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   efectos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   portátiles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   accesibles: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   saludables: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumento: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   crecimiento: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   experiencia: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   plataformas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   están: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   personalizadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   electrónico: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   demanda: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   personal: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   aplicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   perpetúen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   interacción: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   personas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   experiencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   más: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   falta: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   uno: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   buscan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   profesionales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratamientos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   herramientas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   basadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   este: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   todo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   especialmente: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   mayores: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   mejorar: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   transformando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   llevado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   médicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   virtuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desarrollo: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   y: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   muchas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   millones: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   prioridad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   monitorean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   programas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   como: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   ahora: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   también: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
# Documento 5:
#   realidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   recomendaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   las: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   creciente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   distancia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cómo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   diagnostican: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mercado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interactuar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sin: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   comercio: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avances: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   público: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   donde: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceder: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aquellos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   trabajos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   videojuegos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   escenas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   digitales: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   películas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   principal: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   cuándo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   a: TF=2.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   medicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   para: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   algoritmos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   futuro: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   diarias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   sean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   que: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   dispositivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnologías: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   forma: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   compras: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
# ...
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   saludables: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   aumento: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   crecimiento: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   experiencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   plataformas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   están: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   personalizadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   electrónico: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   demanda: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   personal: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   aplicaciones: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   perpetúen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interacción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   experiencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   más: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   falta: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   uno: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=5.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   buscan: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   profesionales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratamientos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   herramientas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   basadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   este: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   todo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   especialmente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mayores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorar: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   transformando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   llevado: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   médicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   virtuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desarrollo: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   y: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   muchas: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   millones: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   prioridad: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   monitorean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   programas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   como: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   ahora: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   también: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
# Documento 8:
#   realidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   recomendaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   las: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   contexto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   importar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   creciente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   distancia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   humanidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   una: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   competencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cómo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   diagnostican: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   mercado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   populares: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   alcanzado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interactuar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sin: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   comercio: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avances: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   público: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   donde: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceder: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   realistas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sectores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aquellos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sino: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ética: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   trabajos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   videojuegos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   e-sports: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   automático: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   escenas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   digitales: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   películas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   principal: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   solo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ofrecer: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   cuándo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   bienestar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ficción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   facilitando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   a: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   hábitos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   flexibilidad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   medicina: TF=2.0000, IDF=0.9031, TF-IDF=1.8062
#   género: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aprendizaje: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   para: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   algoritmos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   futuro: TF=1.0000, IDF=0.6021, TF-IDF=0.6021
#   diarias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cursos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   se: TF=1.0000, IDF=0.2041, TF-IDF=0.2041
#   sean: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vida: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   datos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   que: TF=2.0000, IDF=0.0580, TF-IDF=0.1160
#   dispositivos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   tecnologías: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   forma: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   compras: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   promueven: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficaces: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   artificial: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   continúa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cuidados: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   transacciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   vez: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mundo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   en: TF=3.0000, IDF=0.0000, TF-IDF=0.0000
#   atraen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desafío: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   evolucionado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siguen: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   estudiantes: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   crear: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   su: TF=0.0000, IDF=0.3010, TF-IDF=0.0000
#   cada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiando: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   además: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   ha: TF=0.0000, IDF=0.1249, TF-IDF=0.0000
#   desafían: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   series: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   espectadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   educativa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   siendo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratan: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   aumentada: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfermedades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aunque: TF=0.0000, IDF=0.0000, TF-IDF=0.0000
#   adopción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   viaje: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   consume: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nivel: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   jugadores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   de: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   calidad: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   un: TF=0.0000, IDF=0.2041, TF-IDF=0.0000
#   justas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cine: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   implicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   convertido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sigue: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   finanzas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   reto: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   literarios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   los: TF=3.0000, IDF=0.1249, TF-IDF=0.3748
#   tecnología: TF=1.0000, IDF=0.3010, TF-IDF=0.3010
#   mundos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   hasta: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   utilizan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   compramos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desde: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   libros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   garantizar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   enfoque: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   transformado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   línea: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   salud: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   pagos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   géneros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ciencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   reflexionar: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   integral: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   está: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   la: TF=6.0000, IDF=0.0000, TF-IDF=0.0000
#   permitiendo: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   educación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   efectos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   portátiles: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   accesibles: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   temas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   optimizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   saludables: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   aumento: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   beneficios: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   completo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   inteligencia: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   crecimiento: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   experiencia: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   plataformas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   están: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   personalizadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   electrónico: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   producciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   con: TF=1.0000, IDF=0.0580, TF-IDF=0.0580
#   demanda: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   personal: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   aplicaciones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personalizados: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   fundamental: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   perpetúen: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   planetas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   es: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   pueden: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   rápidamente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   presencial: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   interacción: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   personas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   experiencias: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   más: TF=2.0000, IDF=0.3010, TF-IDF=0.6021
#   falta: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   streaming: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   usuario: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   explorando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cinematográficas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   individual: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sesgos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   ubicación: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   no: TF=0.0000, IDF=0.0580, TF-IDF=0.0000
#   otros: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   adoptando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   uno: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   invita: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   el: TF=1.0000, IDF=0.0000, TF-IDF=0.0000
#   telemedicina: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   consumidores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sus: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   buscan: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   profesionales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tratamientos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   herramientas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   eficiencia: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   permitido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   basadas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   este: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   todo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   especialmente: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mayores: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   mejorar: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   transformando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   llevado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   acceso: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   empresas: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   médicos: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   inmersivos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tiempo: TF=1.0000, IDF=0.4260, TF-IDF=0.4260
#   visuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   nuevo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   virtuales: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   desarrollo: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   prometedor: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   cambiado: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   y: TF=2.0000, IDF=0.0580, TF-IDF=0.1160
#   muchas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   incorporando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   democratizando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   embargo: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   contenido: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   sobre: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   real: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   entretiene: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   tecnológicos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   impulsa: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   millones: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   años: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   decisiones: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   prioridad: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   monitorean: TF=1.0000, IDF=0.9031, TF-IDF=0.9031
#   programas: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   como: TF=0.0000, IDF=0.4260, TF-IDF=0.0000
#   ahora: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   también: TF=0.0000, IDF=0.6021, TF-IDF=0.0000
#   rápidos: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   habilidades: TF=0.0000, IDF=0.9031, TF-IDF=0.0000
#   avanzando: TF=0.0000, IDF=0.9031, TF-IDF=0.0000

# %% [markdown]
# # 3. Procesamiento de las consultas:

# %% [markdown]
# - Preprocesamiento de las consultas de manera similar a los documentos.

# %%
consultas = [
    "inteligencia artificial en medicina",
    "beneficios de la educación a distancia",
    "realidad aumentada en videojuegos",
    "desarrollo personal y hábitos saludables",
    "futuro del comercio electrónico",
    "tecnologías en cine moderno",
    "competencias de e-sports",
    "diagnóstico con dispositivos portátiles",
    "literatura de ciencia ficción",
    "plataformas de streaming"
]

def process_query(query):
    query_cleaned = re.sub(r'[,.]', '', query.lower()).split()
    return query_cleaned

# %% [markdown]
# - Representación de las consultas en el espacio vectorial TF-IDF.

# %%
def represent_query_in_tfidf(query, corpus):
    query_vector = {}
    processed_query = process_query(query)

    for term in vocab:
        query_vector[term] = tfidf(term, ' '.join(processed_query), corpus)

    return query_vector

for i, consulta in enumerate(consultas):
    consulta_tfidf = represent_query_in_tfidf(consulta, datos)
    print(f"\nConsulta {i + 1}: '{consulta}'")
    for term, tfidf_value in consulta_tfidf.items():
        if tfidf_value > 0:
            print(f"    {term}: {tfidf_value:.4f}")
# Out:
# Consulta 1: 'inteligencia artificial en medicina'
#     medicina: 0.9031
#     artificial: 0.4260
#     inteligencia: 0.4260
#
# Consulta 2: 'beneficios de la educación a distancia'
#     distancia: 0.9031
#     educación: 0.9031
#     beneficios: 0.9031
#
# Consulta 3: 'realidad aumentada en videojuegos'
#     realidad: 0.6021
#     videojuegos: 0.9031
#     aumentada: 0.9031
#
# Consulta 4: 'desarrollo personal y hábitos saludables'
#     hábitos: 0.9031
#     saludables: 0.9031
#     personal: 0.4260
#     desarrollo: 0.6021
#     y: 0.0580
#
# Consulta 5: 'futuro del comercio electrónico'
#     comercio: 0.9031
#     futuro: 0.6021
#     electrónico: 0.9031
#
# Consulta 6: 'tecnologías en cine moderno'
#     tecnologías: 0.6021
#     cine: 0.9031
#
# Consulta 7: 'competencias de e-sports'
#     competencias: 0.9031
#     e-sports: 0.9031
#
# Consulta 8: 'diagnóstico con dispositivos portátiles'
#     dispositivos: 0.9031
#     portátiles: 0.9031
#     con: 0.0580
#
# Consulta 9: 'literatura de ciencia ficción'
#     ficción: 0.9031
#     ciencia: 0.6021
#
# Consulta 10: 'plataformas de streaming'
#     plataformas: 0.6021
#     streaming: 0.9031

# %% [markdown]
# # 4. Cálculo de similitudes:

# %% [markdown]
# - Cálculo de la similitud entre cada consulta y los documentos del corpus utilizando la similitud del coseno.

# %%
def cosine_similarity(vec1, vec2):
    dot_product = sum(vec1[term] * vec2.get(term, 0) for term in vec1)
    norm_vec1 = math.sqrt(sum(value ** 2 for value in vec1.values()))
    norm_vec2 = math.sqrt(sum(value ** 2 for value in vec2.values()))
    if norm_vec1 == 0 or norm_vec2 == 0:
        return 0
    return dot_product / (norm_vec1 * norm_vec2)

for i, consulta in enumerate(consultas):
    consulta_tfidf = represent_query_in_tfidf(consulta, datos)
    print(f"\nSimilitudes para la consulta '{consulta}':")
    for doc_index, document_tfidf in tfidf_matrix.items():
        similitud = cosine_similarity(consulta_tfidf, document_tfidf)
        print(f"    Similitud con Documento {doc_index + 1}: {similitud:.4f}")
# Out:
# Similitudes para la consulta 'inteligencia artificial en medicina':
#     Similitud con Documento 1: 0.0768
#     Similitud con Documento 2: 0.0383
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.0842
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.3802
#
# Similitudes para la consulta 'beneficios de la educación a distancia':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0000
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.2545
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000
#
# Similitudes para la consulta 'realidad aumentada en videojuegos':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.3233
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000
#
# Similitudes para la consulta 'desarrollo personal y hábitos saludables':
#     Similitud con Documento 1: 0.0010
#     Similitud con Documento 2: 0.0568
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0010
#     Similitud con Documento 6: 0.0011
#     Similitud con Documento 7: 0.3527
#     Similitud con Documento 8: 0.0012
#
# Similitudes para la consulta 'futuro del comercio electrónico':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0000
#     Similitud con Documento 3: 0.2956
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.0647
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0650
#
# Similitudes para la consulta 'tecnologías en cine moderno':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0765
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.2305
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000
#
# Similitudes para la consulta 'competencias de e-sports':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.1462
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000
#
# Similitudes para la consulta 'diagnóstico con dispositivos portátiles':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0006
#     Similitud con Documento 3: 0.0007
#     Similitud con Documento 4: 0.0006
#     Similitud con Documento 5: 0.0006
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.3235
#
# Similitudes para la consulta 'literatura de ciencia ficción':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0000
#     Similitud con Documento 3: 0.0000
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.0000
#     Similitud con Documento 6: 0.2734
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000
#
# Similitudes para la consulta 'plataformas de streaming':
#     Similitud con Documento 1: 0.0000
#     Similitud con Documento 2: 0.0000
#     Similitud con Documento 3: 0.0855
#     Similitud con Documento 4: 0.0000
#     Similitud con Documento 5: 0.2305
#     Similitud con Documento 6: 0.0000
#     Similitud con Documento 7: 0.0000
#     Similitud con Documento 8: 0.0000

# %% [markdown]
# # 5. Ranking de documentos:

# %% [markdown]
# - Ordenar los documentos de mayor a menor similitud para cada consulta.

# %%
for i, consulta in enumerate(consultas):
    consulta_tfidf = represent_query_in_tfidf(consulta, datos)
    similitudes = []

    for doc_index, document_tfidf in tfidf_matrix.items():
        similitud = cosine_similarity(consulta_tfidf, document_tfidf)
        similitudes.append((doc_index + 1, similitud))

    similitudes.sort(key=lambda x: x[1], reverse=True)

    print(f"\nRanking de documentos para la consulta '{consulta}':")
    for doc_id, sim in similitudes:
        print(f"    Documento {doc_id}: Similitud = {sim:.4f}")
# Out:
# Ranking de documentos para la consulta 'inteligencia artificial en medicina':
#     Documento 8: Similitud = 0.3802
#     Documento 6: Similitud = 0.0842
#     Documento 1: Similitud = 0.0768
#     Documento 2: Similitud = 0.0383
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'beneficios de la educación a distancia':
#     Documento 4: Similitud = 0.2545
#     Documento 1: Similitud = 0.0000
#     Documento 2: Similitud = 0.0000
#     Documento 3: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'realidad aumentada en videojuegos':
#     Documento 2: Similitud = 0.3233
#     Documento 1: Similitud = 0.0000
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'desarrollo personal y hábitos saludables':
#     Documento 7: Similitud = 0.3527
#     Documento 2: Similitud = 0.0568
#     Documento 8: Similitud = 0.0012
#     Documento 6: Similitud = 0.0011
#     Documento 1: Similitud = 0.0010
#     Documento 5: Similitud = 0.0010
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'futuro del comercio electrónico':
#     Documento 3: Similitud = 0.2956
#     Documento 8: Similitud = 0.0650
#     Documento 6: Similitud = 0.0647
#     Documento 1: Similitud = 0.0000
#     Documento 2: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'tecnologías en cine moderno':
#     Documento 5: Similitud = 0.2305
#     Documento 2: Similitud = 0.0765
#     Documento 1: Similitud = 0.0000
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'competencias de e-sports':
#     Documento 2: Similitud = 0.1462
#     Documento 1: Similitud = 0.0000
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'diagnóstico con dispositivos portátiles':
#     Documento 8: Similitud = 0.3235
#     Documento 3: Similitud = 0.0007
#     Documento 4: Similitud = 0.0006
#     Documento 2: Similitud = 0.0006
#     Documento 5: Similitud = 0.0006
#     Documento 1: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'literatura de ciencia ficción':
#     Documento 6: Similitud = 0.2734
#     Documento 1: Similitud = 0.0000
#     Documento 2: Similitud = 0.0000
#     Documento 3: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 5: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000
#
# Ranking de documentos para la consulta 'plataformas de streaming':
#     Documento 5: Similitud = 0.2305
#     Documento 3: Similitud = 0.0855
#     Documento 1: Similitud = 0.0000
#     Documento 2: Similitud = 0.0000
#     Documento 4: Similitud = 0.0000
#     Documento 6: Similitud = 0.0000
#     Documento 7: Similitud = 0.0000
#     Documento 8: Similitud = 0.0000

# %% [markdown]
# - Mostrar los documentos más relevantes para cada consulta.

# %%
top_n = 1

for i, consulta in enumerate(consultas):
    consulta_tfidf = represent_query_in_tfidf(consulta, datos)
    similitudes = []

    for doc_index, document_tfidf in tfidf_matrix.items():
        similitud = cosine_similarity(consulta_tfidf, document_tfidf)
        similitudes.append((doc_index + 1, similitud))

    similitudes.sort(key=lambda x: x[1], reverse=True)
    top_similitudes = similitudes[:top_n]

    print(f"\nDocumentos más relevantes para la consulta '{consulta}':")
    for doc_id, sim in top_similitudes:
        print(f"    Documento {doc_id}: Similitud = {sim:.4f}")
# Out:
# Documentos más relevantes para la consulta 'inteligencia artificial en medicina':
#     Documento 8: Similitud = 0.3802
#
# Documentos más relevantes para la consulta 'beneficios de la educación a distancia':
#     Documento 4: Similitud = 0.2545
#
# Documentos más relevantes para la consulta 'realidad aumentada en videojuegos':
#     Documento 2: Similitud = 0.3233
#
# Documentos más relevantes para la consulta 'desarrollo personal y hábitos saludables':
#     Documento 7: Similitud = 0.3527
#
# Documentos más relevantes para la consulta 'futuro del comercio electrónico':
#     Documento 3: Similitud = 0.2956
#
# Documentos más relevantes para la consulta 'tecnologías en cine moderno':
#     Documento 5: Similitud = 0.2305
#
# Documentos más relevantes para la consulta 'competencias de e-sports':
#     Documento 2: Similitud = 0.1462
#
# Documentos más relevantes para la consulta 'diagnóstico con dispositivos portátiles':
#     Documento 8: Similitud = 0.3235
#
# Documentos más relevantes para la consulta 'literatura de ciencia ficción':
#     Documento 6: Similitud = 0.2734
#
# Documentos más relevantes para la consulta 'plataformas de streaming':
#     Documento 5: Similitud = 0.2305
