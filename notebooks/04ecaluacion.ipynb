# %% [markdown]
# **Ejercicio 04: Evaluación de un Sistema de Recuperación de Información**
#
# Nombres: Dilan Andrade, Hernan Sanchez, Galo Tarapues

# %% [markdown]
# 1. Proporcionar un Conjunto de Datos:

# %%
import xml.etree.ElementTree as ET
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity
import pandas as pd

# Procesamiento del corpus
tree = ET.parse('03ranking_corpus.xml')
root = tree.getroot()

corpus = []
for document in root.findall('document'):
    doc_id = document.get('id')
    title = document.find('title').text
    keywords = document.find('keywords').text
    corpus.append({
        'id': doc_id,
        'title': title,
        'keywords': keywords.split(', ')
    })

print("Contenido del Corpus:")
for doc in corpus:
    print(f"Documento ID: {doc['id']}, Título: {doc['title']}, Keywords: {doc['keywords']}")

#Consultas
consultas = [
    "beneficios de la telemedicina en salud crónica",
    "impacto de la nutrición en el rendimiento académico",
    "estrategias para mejorar la salud mental en estudiantes universitarios"
]

print("\nConsultas:")
for idx, consulta in enumerate(consultas, start=1):
    print(f"Consulta {idx}: {consulta}")


#Juicios de relevancia

juicios_relevancia = {
    "Consulta 1": ["1", "10"],   # IDs de documentos relevantes para la primera consulta
    "Consulta 2": ["2", "7"],    # IDs de documentos relevantes para la segunda consulta
    "Consulta 3": ["13", "14", "23"]  # IDs de documentos relevantes para la tercera consulta
}

print("\nJuicios de Relevancia Definidos:")
for consulta, documentos_relevantes in juicios_relevancia.items():
    print(f"{consulta}: Documentos relevantes -> {documentos_relevantes}")
# Out:
# Contenido del Corpus:
# Documento ID: 1, Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas., Keywords: ['telemedicina', 'salud crónica', 'tratamiento', 'tecnología médica']
# Documento ID: 2, Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes., Keywords: ['nutrición', 'rendimiento académico', 'salud mental', 'estudiantes']
# Documento ID: 3, Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus., Keywords: ['amistad', 'bienestar estudiantil', 'campus', 'relaciones sociales']
# Documento ID: 4, Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica., Keywords: ['bibliotecas universitarias', 'investigación', 'academia', 'recursos']
# Documento ID: 5, Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés., Keywords: ['espacios verdes', 'campus universitario', 'concentración', 'estrés']
# Documento ID: 6, Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes., Keywords: ['cultura universitaria', 'hábitos saludables', 'bienestar', 'estudiantes']
# Documento ID: 7, Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios., Keywords: ['sueño', 'salud mental', 'rendimiento académico', 'universitarios']
# Documento ID: 8, Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios., Keywords: ['apoyo familiar', 'apoyo social', 'bienestar emocional', 'estudiantes']
# Documento ID: 9, Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos., Keywords: ['hábitos de lectura', 'desarrollo cognitivo', 'jóvenes', 'adultos']
# Documento ID: 10, Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes., Keywords: ['tecnología médica', 'medicina preventiva', 'jóvenes', 'avances tecnológicos']
# Documento ID: 11, Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios., Keywords: ['ejercicio', 'estrés académico', 'estudiantes universitarios', 'salud']
# Documento ID: 12, Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios., Keywords: ['mindfulness', 'meditación', 'ansiedad', 'estudiantes universitarios']
# Documento ID: 13, Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus., Keywords: ['salud mental', 'estudiantes universitarios', 'apoyo psicológico', 'grupos de estudio']
# Documento ID: 14, Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico., Keywords: ['salud mental', 'desempeño académico', 'servicios universitarios', 'estudiantes']
# Documento ID: 15, Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes., Keywords: ['actividades extracurriculares', 'bienestar emocional', 'social', 'estudiantes']
# Documento ID: 16, Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas., Keywords: ['laboratorios de innovación', 'competencias tecnológicas', 'educación', 'desarrollo']
# Documento ID: 17, Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración., Keywords: ['diseño de campus', 'interacción', 'colaboración', 'tendencias']
# Documento ID: 18, Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian., Keywords: ['bienestar académico', 'estudiantes que trabajan', 'comparación', 'rendimiento']
# Documento ID: 19, Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios., Keywords: ['agotamiento académico', 'factores de riesgo', 'prevención', 'estudiantes universitarios']
# Documento ID: 20, Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes., Keywords: ['tecnología', 'redes sociales', 'calidad del sueño', 'estudiantes']
# Documento ID: 21, Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades., Keywords: ['tecnologías verdes', 'edificios universitarios', 'impacto ambiental', 'sostenibilidad']
# Documento ID: 22, Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad., Keywords: ['bicicletas compartidas', 'movilidad', 'universidades', 'transporte sostenible']
# Documento ID: 23, Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar., Keywords: ['carga académica', 'salud emocional', 'estudiantes', 'apoyo universitario']
# Documento ID: 24, Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas., Keywords: ['equilibrio', 'vida social', 'académica', 'estudiantes', 'estrategias']
# Documento ID: 25, Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria., Keywords: ['actividades artísticas', 'bienestar psicológico', 'vida universitaria', 'creatividad']
# Documento ID: 26, Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades., Keywords: ['programas de becas', 'retención de estudiantes', 'beneficios', 'universidades']
# Documento ID: 27, Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes., Keywords: ['deportes', 'actividad física', 'integración social', 'estudiantes']
# Documento ID: 28, Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés., Keywords: ['eventos de bienestar', 'talleres', 'reducción del estrés', 'universidad']
# Documento ID: 29, Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios., Keywords: ['hábitos de sueño', 'rendimiento en exámenes', 'análisis', 'estudiantes']
# Documento ID: 30, Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas., Keywords: ['inteligencia artificial', 'servicios médicos', 'comunidades remotas', 'tecnología']
#
# Consultas:
# Consulta 1: beneficios de la telemedicina en salud crónica
# Consulta 2: impacto de la nutrición en el rendimiento académico
# Consulta 3: estrategias para mejorar la salud mental en estudiantes universitarios
#
# Juicios de Relevancia Definidos:
# Consulta 1: Documentos relevantes -> ['1', '10']
# Consulta 2: Documentos relevantes -> ['2', '7']
# Consulta 3: Documentos relevantes -> ['13', '14', '23']

# %% [markdown]
# 2. Calcular Resultados de Búsqueda:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity

# Combinar títulos y keywords en un solo texto para cada documento
document_texts = [" ".join([doc['title']] + doc['keywords']) for doc in corpus]

# Vectorizar el corpus y las consultas usando TF-IDF
vectorizer = TfidfVectorizer()
corpus_tfidf = vectorizer.fit_transform(document_texts)
query_tfidf = vectorizer.transform(consultas)

# Calcular la distancia euclidiana
distancia_euclidiana = euclidean_distances(query_tfidf, corpus_tfidf)
print("\nMatriz de Distancia Euclidiana entre Consultas y Documentos:")
print(pd.DataFrame(distancia_euclidiana, index=[f"Consulta {i+1}" for i in range(len(consultas))],
                   columns=[f"Doc {i+1}" for i in range(len(corpus))]))

# Calcular la distancia coseno
distancia_coseno = cosine_similarity(query_tfidf, corpus_tfidf)
print("\nMatriz de Similitud Coseno entre Consultas y Documentos:")
print(pd.DataFrame(distancia_coseno, index=[f"Consulta {i+1}" for i in range(len(consultas))],
                   columns=[f"Doc {i+1}" for i in range(len(corpus))]))

# Ordenar y mostrar los resultados para cada consulta en ambos sistemas
resultados = {}
for idx, consulta in enumerate(consultas):
    print(f"\nConsulta: {consulta}")

    # Resultados para distancia euclidiana (más relevante primero)
    euclidiana_ordenada = distancia_euclidiana[idx].argsort()
    euclidiana_resultados = [corpus[doc_idx]['id'] for doc_idx in euclidiana_ordenada]
    print("\nDocumentos ordenados por distancia euclidiana (más relevante primero):")
    for doc_idx in euclidiana_ordenada:
        print(f"Documento ID: {corpus[doc_idx]['id']}, Distancia Euclidiana: {distancia_euclidiana[idx][doc_idx]:.4f}")

    # Resultados para distancia coseno (más relevante primero)
    coseno_ordenado = distancia_coseno[idx].argsort()[::-1]
    coseno_resultados = [corpus[doc_idx]['id'] for doc_idx in coseno_ordenado]
    print("\nDocumentos ordenados por distancia coseno (más relevante primero):")
    for doc_idx in coseno_ordenado:
        print(f"Documento ID: {corpus[doc_idx]['id']}, Similitud Coseno: {distancia_coseno[idx][doc_idx]:.4f}")

    resultados[f"Consulta {idx + 1}"] = {
        "Distancia Euclidiana": euclidiana_resultados,
        "Distancia Coseno": coseno_resultados
    }
# Out:
# Matriz de Distancia Euclidiana entre Consultas y Documentos:
#                Doc 1     Doc 2     Doc 3     Doc 4     Doc 5     Doc 6  \
# Consulta 1  0.944752  1.299586  1.386398  1.372879  1.395867  1.363431
# Consulta 2  1.345996  0.836806  1.374316  1.348691  1.385194  1.349048
# Consulta 3  1.291102  1.117378  1.390055  1.392815  1.316638  1.349783
#
#                Doc 7     Doc 8     Doc 9    Doc 10  ...    Doc 21    Doc 22  \
# Consulta 1  1.286788  1.384989  1.372554  1.377949  ...  1.387553  1.385360
# Consulta 2  1.117503  1.372775  1.299199  1.374653  ...  1.265502  1.373302
# Consulta 3  1.062958  1.333769  1.398851  1.349887  ...  1.379821  1.312753
#
#               Doc 23    Doc 24    Doc 25    Doc 26    Doc 27    Doc 28  \
# Consulta 1  1.300964  1.394407  1.385536  1.208790  1.367424  1.385179
# Consulta 2  1.330045  1.392619  1.373987  1.343851  1.354197  1.373587
# Consulta 3  1.253845  1.188927  1.384023  1.339824  1.354873  1.403173
#
#               Doc 29    Doc 30
# Consulta 1  1.369823  1.398150
# Consulta 2  1.243585  1.388816
# Consulta 3  1.355754  1.397306
#
# [3 rows x 30 columns]
#
# Matriz de Similitud Coseno entre Consultas y Documentos:
#                Doc 1     Doc 2     Doc 3     Doc 4     Doc 5     Doc 6  \
# Consulta 1  0.553722  0.155539  0.038950  0.057601  0.025777  0.070527
# Consulta 2  0.094147  0.649878  0.055627  0.090516  0.040619  0.090034
# Consulta 3  0.166528  0.375733  0.033873  0.030033  0.133232  0.089042
#
#                Doc 7     Doc 8     Doc 9    Doc 10  ...    Doc 21    Doc 22  \
# Consulta 1  0.172088  0.040902  0.058047  0.050629  ...  0.037348  0.040389
# Consulta 2  0.375593  0.057745  0.156041  0.055165  ...  0.199253  0.057021
# Consulta 3  0.435061  0.110530  0.021608  0.088902  ...  0.048048  0.138339
#
#               Doc 23    Doc 24    Doc 25    Doc 26    Doc 27    Doc 28  \
# Consulta 1  0.153746  0.027815  0.040145  0.269414  0.065076  0.040639
# Consulta 2  0.115491  0.030307  0.056080  0.097033  0.083076  0.056629
# Consulta 3  0.213937  0.293227  0.042240  0.102436  0.082160  0.015553
#
#               Doc 29    Doc 30
# Consulta 1  0.061792  0.022589
# Consulta 2  0.226748  0.035595
# Consulta 3  0.080965  0.023767
#
# [3 rows x 30 columns]
#
# Consulta: beneficios de la telemedicina en salud crónica
#
# Documentos ordenados por distancia euclidiana (más relevante primero):
# Documento ID: 1, Distancia Euclidiana: 0.9448
# Documento ID: 26, Distancia Euclidiana: 1.2088
# Documento ID: 7, Distancia Euclidiana: 1.2868
# Documento ID: 2, Distancia Euclidiana: 1.2996
# Documento ID: 23, Distancia Euclidiana: 1.3010
# Documento ID: 13, Distancia Euclidiana: 1.3053
# Documento ID: 11, Distancia Euclidiana: 1.3083
# Documento ID: 14, Distancia Euclidiana: 1.3085
# Documento ID: 15, Distancia Euclidiana: 1.3158
# Documento ID: 12, Distancia Euclidiana: 1.3511
# Documento ID: 20, Distancia Euclidiana: 1.3588
# Documento ID: 6, Distancia Euclidiana: 1.3634
# Documento ID: 27, Distancia Euclidiana: 1.3674
# Documento ID: 29, Distancia Euclidiana: 1.3698
# Documento ID: 16, Distancia Euclidiana: 1.3722
# Documento ID: 9, Distancia Euclidiana: 1.3726
# Documento ID: 4, Distancia Euclidiana: 1.3729
# Documento ID: 17, Distancia Euclidiana: 1.3773
# Documento ID: 10, Distancia Euclidiana: 1.3779
# Documento ID: 8, Distancia Euclidiana: 1.3850
# Documento ID: 28, Distancia Euclidiana: 1.3852
# Documento ID: 22, Distancia Euclidiana: 1.3854
# Documento ID: 25, Distancia Euclidiana: 1.3855
# Documento ID: 3, Distancia Euclidiana: 1.3864
# Documento ID: 19, Distancia Euclidiana: 1.3865
# Documento ID: 21, Distancia Euclidiana: 1.3876
# Documento ID: 24, Distancia Euclidiana: 1.3944
# Documento ID: 5, Distancia Euclidiana: 1.3959
# Documento ID: 30, Distancia Euclidiana: 1.3981
# Documento ID: 18, Distancia Euclidiana: 1.4070
#
# Documentos ordenados por distancia coseno (más relevante primero):
# Documento ID: 1, Similitud Coseno: 0.5537
# Documento ID: 26, Similitud Coseno: 0.2694
# Documento ID: 7, Similitud Coseno: 0.1721
# Documento ID: 2, Similitud Coseno: 0.1555
# Documento ID: 23, Similitud Coseno: 0.1537
# Documento ID: 13, Similitud Coseno: 0.1481
# Documento ID: 11, Similitud Coseno: 0.1442
# Documento ID: 14, Similitud Coseno: 0.1439
# Documento ID: 15, Similitud Coseno: 0.1344
# Documento ID: 12, Similitud Coseno: 0.0872
# Documento ID: 20, Similitud Coseno: 0.0768
# Documento ID: 6, Similitud Coseno: 0.0705
# Documento ID: 27, Similitud Coseno: 0.0651
# Documento ID: 29, Similitud Coseno: 0.0618
# Documento ID: 16, Similitud Coseno: 0.0585
# Documento ID: 9, Similitud Coseno: 0.0580
# Documento ID: 4, Similitud Coseno: 0.0576
# Documento ID: 17, Similitud Coseno: 0.0515
# Documento ID: 10, Similitud Coseno: 0.0506
# Documento ID: 8, Similitud Coseno: 0.0409
# Documento ID: 28, Similitud Coseno: 0.0406
# Documento ID: 22, Similitud Coseno: 0.0404
# Documento ID: 25, Similitud Coseno: 0.0401
# Documento ID: 3, Similitud Coseno: 0.0390
# Documento ID: 19, Similitud Coseno: 0.0388
# Documento ID: 21, Similitud Coseno: 0.0373
# Documento ID: 24, Similitud Coseno: 0.0278
# Documento ID: 5, Similitud Coseno: 0.0258
# Documento ID: 30, Similitud Coseno: 0.0226
# Documento ID: 18, Similitud Coseno: 0.0102
#
# Consulta: impacto de la nutrición en el rendimiento académico
#
# Documentos ordenados por distancia euclidiana (más relevante primero):
# Documento ID: 2, Distancia Euclidiana: 0.8368
# Documento ID: 7, Distancia Euclidiana: 1.1175
# Documento ID: 11, Distancia Euclidiana: 1.1835
# Documento ID: 29, Distancia Euclidiana: 1.2436
# Documento ID: 21, Distancia Euclidiana: 1.2655
# Documento ID: 18, Distancia Euclidiana: 1.2756
# Documento ID: 14, Distancia Euclidiana: 1.2773
# Documento ID: 20, Distancia Euclidiana: 1.2808
# Documento ID: 19, Distancia Euclidiana: 1.2956
# Documento ID: 9, Distancia Euclidiana: 1.2992
# Documento ID: 23, Distancia Euclidiana: 1.3300
# Documento ID: 12, Distancia Euclidiana: 1.3351
# Documento ID: 26, Distancia Euclidiana: 1.3439
# Documento ID: 1, Distancia Euclidiana: 1.3460
# Documento ID: 4, Distancia Euclidiana: 1.3487
# Documento ID: 6, Distancia Euclidiana: 1.3490
# Documento ID: 13, Distancia Euclidiana: 1.3496
# Documento ID: 16, Distancia Euclidiana: 1.3514
# Documento ID: 27, Distancia Euclidiana: 1.3542
# Documento ID: 17, Distancia Euclidiana: 1.3649
# Documento ID: 8, Distancia Euclidiana: 1.3728
# Documento ID: 22, Distancia Euclidiana: 1.3733
# Documento ID: 28, Distancia Euclidiana: 1.3736
# Documento ID: 25, Distancia Euclidiana: 1.3740
# Documento ID: 3, Distancia Euclidiana: 1.3743
# Documento ID: 10, Distancia Euclidiana: 1.3747
# Documento ID: 15, Distancia Euclidiana: 1.3809
# Documento ID: 5, Distancia Euclidiana: 1.3852
# Documento ID: 30, Distancia Euclidiana: 1.3888
# Documento ID: 24, Distancia Euclidiana: 1.3926
#
# Documentos ordenados por distancia coseno (más relevante primero):
# Documento ID: 2, Similitud Coseno: 0.6499
# Documento ID: 7, Similitud Coseno: 0.3756
# Documento ID: 11, Similitud Coseno: 0.2996
# Documento ID: 29, Similitud Coseno: 0.2267
# Documento ID: 21, Similitud Coseno: 0.1993
# Documento ID: 18, Similitud Coseno: 0.1864
# Documento ID: 14, Similitud Coseno: 0.1843
# Documento ID: 20, Similitud Coseno: 0.1798
# Documento ID: 19, Similitud Coseno: 0.1608
# Documento ID: 9, Similitud Coseno: 0.1560
# Documento ID: 23, Similitud Coseno: 0.1155
# Documento ID: 12, Similitud Coseno: 0.1088
# Documento ID: 26, Similitud Coseno: 0.0970
# Documento ID: 1, Similitud Coseno: 0.0941
# Documento ID: 4, Similitud Coseno: 0.0905
# Documento ID: 6, Similitud Coseno: 0.0900
# Documento ID: 13, Similitud Coseno: 0.0893
# Documento ID: 16, Similitud Coseno: 0.0869
# Documento ID: 27, Similitud Coseno: 0.0831
# Documento ID: 17, Similitud Coseno: 0.0685
# Documento ID: 8, Similitud Coseno: 0.0577
# Documento ID: 22, Similitud Coseno: 0.0570
# Documento ID: 28, Similitud Coseno: 0.0566
# Documento ID: 25, Similitud Coseno: 0.0561
# Documento ID: 3, Similitud Coseno: 0.0556
# Documento ID: 10, Similitud Coseno: 0.0552
# Documento ID: 15, Similitud Coseno: 0.0465
# Documento ID: 5, Similitud Coseno: 0.0406
# Documento ID: 30, Similitud Coseno: 0.0356
# Documento ID: 24, Similitud Coseno: 0.0303
#
# Consulta: estrategias para mejorar la salud mental en estudiantes universitarios
#
# Documentos ordenados por distancia euclidiana (más relevante primero):
# Documento ID: 13, Distancia Euclidiana: 0.9476
# Documento ID: 7, Distancia Euclidiana: 1.0630
# Documento ID: 14, Distancia Euclidiana: 1.0688
# Documento ID: 2, Distancia Euclidiana: 1.1174
# Documento ID: 24, Distancia Euclidiana: 1.1889
# Documento ID: 19, Distancia Euclidiana: 1.2207
# Documento ID: 11, Distancia Euclidiana: 1.2227
# Documento ID: 23, Distancia Euclidiana: 1.2538
# Documento ID: 12, Distancia Euclidiana: 1.2635
# Documento ID: 1, Distancia Euclidiana: 1.2911
# Documento ID: 22, Distancia Euclidiana: 1.3128
# Documento ID: 5, Distancia Euclidiana: 1.3166
# Documento ID: 8, Distancia Euclidiana: 1.3338
# Documento ID: 26, Distancia Euclidiana: 1.3398
# Documento ID: 20, Distancia Euclidiana: 1.3456
# Documento ID: 6, Distancia Euclidiana: 1.3498
# Documento ID: 10, Distancia Euclidiana: 1.3499
# Documento ID: 15, Distancia Euclidiana: 1.3504
# Documento ID: 27, Distancia Euclidiana: 1.3549
# Documento ID: 29, Distancia Euclidiana: 1.3558
# Documento ID: 17, Distancia Euclidiana: 1.3691
# Documento ID: 18, Distancia Euclidiana: 1.3783
# Documento ID: 21, Distancia Euclidiana: 1.3798
# Documento ID: 25, Distancia Euclidiana: 1.3840
# Documento ID: 3, Distancia Euclidiana: 1.3901
# Documento ID: 4, Distancia Euclidiana: 1.3928
# Documento ID: 30, Distancia Euclidiana: 1.3973
# Documento ID: 9, Distancia Euclidiana: 1.3989
# Documento ID: 28, Distancia Euclidiana: 1.4032
# Documento ID: 16, Distancia Euclidiana: 1.4068
#
# Documentos ordenados por distancia coseno (más relevante primero):
# Documento ID: 13, Similitud Coseno: 0.5511
# Documento ID: 7, Similitud Coseno: 0.4351
# Documento ID: 14, Similitud Coseno: 0.4289
# Documento ID: 2, Similitud Coseno: 0.3757
# Documento ID: 24, Similitud Coseno: 0.2932
# Documento ID: 19, Similitud Coseno: 0.2549
# Documento ID: 11, Similitud Coseno: 0.2525
# Documento ID: 23, Similitud Coseno: 0.2139
# Documento ID: 12, Similitud Coseno: 0.2018
# Documento ID: 1, Similitud Coseno: 0.1665
# Documento ID: 22, Similitud Coseno: 0.1383
# Documento ID: 5, Similitud Coseno: 0.1332
# Documento ID: 8, Similitud Coseno: 0.1105
# Documento ID: 26, Similitud Coseno: 0.1024
# Documento ID: 20, Similitud Coseno: 0.0947
# Documento ID: 6, Similitud Coseno: 0.0890
# Documento ID: 10, Similitud Coseno: 0.0889
# Documento ID: 15, Similitud Coseno: 0.0882
# Documento ID: 27, Similitud Coseno: 0.0822
# Documento ID: 29, Similitud Coseno: 0.0810
# Documento ID: 17, Similitud Coseno: 0.0628
# Documento ID: 18, Similitud Coseno: 0.0502
# Documento ID: 21, Similitud Coseno: 0.0480
# Documento ID: 25, Similitud Coseno: 0.0422
# Documento ID: 3, Similitud Coseno: 0.0339
# Documento ID: 4, Similitud Coseno: 0.0300
# Documento ID: 30, Similitud Coseno: 0.0238
# Documento ID: 9, Similitud Coseno: 0.0216
# Documento ID: 28, Similitud Coseno: 0.0156
# Documento ID: 16, Similitud Coseno: 0.0105

# %% [markdown]
# 3. Calcular las Métricas de Evaluación:

# %%
from sklearn.metrics import ndcg_score

def calcular_metricas(resultados, relevancia, k=5):
    relevantes_encontrados = len([doc_id for doc_id in resultados[:k] if doc_id in relevancia])
    total_relevantes = len(relevancia)

    # Precisión en el top-k (Prec@k)
    precision_at_k = relevantes_encontrados / k if k > 0 else 0

    # Recall
    recall = relevantes_encontrados / total_relevantes if total_relevantes > 0 else 0

    # F1-score
    f1_score = (2 * precision_at_k * recall) / (precision_at_k + recall) if (precision_at_k + recall) > 0 else 0

    # Mean Average Precision (MAP)
    ap_sum = 0
    num_relevantes = 0
    for i, doc_id in enumerate(resultados[:k]):
        if doc_id in relevancia:
            num_relevantes += 1
            ap_sum += num_relevantes / (i + 1)
    map_score = ap_sum / total_relevantes if total_relevantes > 0 else 0

    # nDCG
    relevancias_binarias = [1 if doc_id in relevancia else 0 for doc_id in resultados[:k]]
    ndcg = ndcg_score([relevancias_binarias], [range(k)], k=k)

    return precision_at_k, recall, f1_score, map_score, ndcg

# Calcular e imprimir métricas para cada consulta y sistema
for idx, consulta in enumerate(consultas):
    relevancia = juicios_relevancia[f"Consulta {idx + 1}"]

    print(f"\nMétricas de Evaluación para Consulta {idx + 1} - '{consulta}'")

    # Distancia Euclidiana
    euclidiana_resultados = resultados[f"Consulta {idx + 1}"]["Distancia Euclidiana"]
    prec_at_k, recall, f1, map_score, ndcg = calcular_metricas(euclidiana_resultados, relevancia)
    print(f"\nDistancia Euclidiana:")
    print(f"Prec@k: {prec_at_k:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}, MAP: {map_score:.4f}, nDCG: {ndcg:.4f}")

    # Distancia Coseno
    coseno_resultados = resultados[f"Consulta {idx + 1}"]["Distancia Coseno"]
    prec_at_k, recall, f1, map_score, ndcg = calcular_metricas(coseno_resultados, relevancia)
    print(f"\nDistancia Coseno:")
    print(f"Prec@k: {prec_at_k:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}, MAP: {map_score:.4f}, nDCG: {ndcg:.4f}")
# Out:
# Métricas de Evaluación para Consulta 1 - 'beneficios de la telemedicina en salud crónica'
#
# Distancia Euclidiana:
# Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
#
# Distancia Coseno:
# Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
#
# Métricas de Evaluación para Consulta 2 - 'impacto de la nutrición en el rendimiento académico'
#
# Distancia Euclidiana:
# Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
#
# Distancia Coseno:
# Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
#
# Métricas de Evaluación para Consulta 3 - 'estrategias para mejorar la salud mental en estudiantes universitarios'
#
# Distancia Euclidiana:
# Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438
#
# Distancia Coseno:
# Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438

# %% [markdown]
# 4. Análisis y Comparación:

# %%
print("\nAnálisis y Comparación de los Sistemas de Recuperación:")

for idx, consulta in enumerate(consultas):
    relevancia = juicios_relevancia[f"Consulta {idx + 1}"]

    print(f"\nAnálisis para Consulta {idx + 1} - '{consulta}'")

    # Evaluación de cada sistema con base en las métricas calculadas
    euclidiana_resultados = resultados[f"Consulta {idx + 1}"]["Distancia Euclidiana"]
    coseno_resultados = resultados[f"Consulta {idx + 1}"]["Distancia Coseno"]

    # Cálculo de métricas de evaluación
    euclidiana_metrica = calcular_metricas(euclidiana_resultados, relevancia)
    coseno_metrica = calcular_metricas(coseno_resultados, relevancia)

    # Comparar las métricas entre los dos sistemas
    if euclidiana_metrica[2] > coseno_metrica[2]:  # Comparación basada en F1-score
        print("Distancia Euclidiana es más efectiva en esta consulta.")
    elif coseno_metrica[2] > euclidiana_metrica[2]:
        print("Distancia Coseno es más efectiva en esta consulta.")
    else:
        print("Ambos sistemas muestran un desempeño similar.")
# Out:
# Análisis y Comparación de los Sistemas de Recuperación:
#
# Análisis para Consulta 1 - 'beneficios de la telemedicina en salud crónica'
# Ambos sistemas muestran un desempeño similar.
#
# Análisis para Consulta 2 - 'impacto de la nutrición en el rendimiento académico'
# Ambos sistemas muestran un desempeño similar.
#
# Análisis para Consulta 3 - 'estrategias para mejorar la salud mental en estudiantes universitarios'
# Ambos sistemas muestran un desempeño similar.
