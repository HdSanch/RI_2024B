# %% [markdown]
# ##**Ejercicio 03: Cálculo de Relevancia y Ranking de Documentos**
#
# ##### **Integrantes:** Dilan Andrade, Hernán Sánchez y Galo Tarapués
#
# El objetivo de este ejercicio es calcular analíticamente la relevancia de cada documento en un corpus y luego ordenar (rankear) los documentos basándonos en esa puntuación de relevancia para tres consultas específicas. Seguirás los siguientes pasos:

# %% [markdown]
# #### **1. Procesamiento del Corpus:**
# *   Leer y parsear el archivo XML proporcionado que contiene el corpus de documentos con sus metadatos (keywords, autor y fecha).

# %%
# Importar las librerías necesarias
import xml.etree.ElementTree as ET

# Definir las consultas
queries = {
    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",
    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",
    3: "Estrategias universitarias para reducir el estrés en estudiantes"
}
# Definir una lista de stopwords en español
stopwords = {'de', 'el', 'en', 'la', 'los', 'las', 'y', 'a', 'que', 'para', 'un', 'una', 'es', 'con', 'por', 'del'}


# Función para procesar el texto y extraer palabras clave
def process_text(text):
    # Convertir a minúsculas
    text = text.lower()
    # Reemplazar caracteres no alfanuméricos por espacios
    import re
    text = re.sub(r'[^a-záéíóúñü]+', ' ', text)
    # Tokenizar y eliminar palabras vacías si es necesario
    tokens = text.strip().split()
    # Filtrar stopwords
    tokens = [token for token in tokens if token not in stopwords]
    return set(tokens)

# Paso 1: Leer y parsear el archivo XML
def parse_corpus(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    corpus = {}
    for doc in root.findall('document'):
        doc_id = int(doc.get('id'))
        title = doc.find('title').text
        keywords = doc.find('keywords').text
        author = doc.find('author').text
        date = doc.find('date').text
        # Procesar las palabras clave
        keyword_set = process_text(keywords)
        corpus[doc_id] = {
            'title': title,
            'keywords': keyword_set,
            'author': author,
            'date': date
        }
    return corpus

# %%
corpus = parse_corpus('/content/03ranking_corpus.xml')
corpus
# Out:
# {1: {'title': 'El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.',
#   'keywords': {'crónica',
#    'médica',
#    'salud',
#    'tecnología',
#    'telemedicina',
#    'tratamiento'},
#   'author': 'Dr. Juan Pérez',
#   'date': '2023-01-15'},
#  2: {'title': 'Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.',
#   'keywords': {'académico',
#    'estudiantes',
#    'mental',
#    'nutrición',
#    'rendimiento',
#    'salud'},
#   'author': 'Dra. María López',
#   'date': '2023-02-10'},
#  3: {'title': 'Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.',
#   'keywords': {'amistad',
#    'bienestar',
#    'campus',
#    'estudiantil',
#    'relaciones',
#    'sociales'},
#   'author': 'Miguel Rodríguez',
#   'date': '2023-03-05'},
#  4: {'title': 'El rol de las bibliotecas universitarias en el fomento de la investigación académica.',
#   'keywords': {'academia',
#    'bibliotecas',
#    'investigación',
#    'recursos',
#    'universitarias'},
#   'author': 'Lucía Martínez',
#   'date': '2023-04-20'},
#  5: {'title': 'Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.',
#   'keywords': {'campus',
#    'concentración',
#    'espacios',
#    'estrés',
#    'universitario',
#    'verdes'},
#   'author': 'Carlos Fernández',
#   'date': '2023-05-15'},
#  6: {'title': 'La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.',
#   'keywords': {'bienestar',
#    'cultura',
#    'estudiantes',
#    'hábitos',
#    'saludables',
#    'universitaria'},
#   'author': 'Ana Sánchez',
#   'date': '2023-06-10'},
#  7: {'title': 'La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.',
#   'keywords': {'académico',
#    'mental',
#    'rendimiento',
#    'salud',
#    'sueño',
#    'universitarios'},
#   'author': 'Javier Torres',
#   'date': '2023-07-25'},
#  8: {'title': 'La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.',
#   'keywords': {'apoyo',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'familiar',
#    'social'},
#   'author': 'Laura Gómez',
#   'date': '2023-08-30'},
#  9: {'title': 'El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.',
#   'keywords': {'adultos',
#    'cognitivo',
#    'desarrollo',
#    'hábitos',
#    'jóvenes',
#    'lectura'},
#   'author': 'Fernando Ruiz',
#   'date': '2023-09-18'},
#  10: {'title': 'Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.',
#   'keywords': {'avances',
#    'jóvenes',
#    'medicina',
#    'médica',
#    'preventiva',
#    'tecnología',
#    'tecnológicos'},
#   'author': 'Elena Navarro',
#   'date': '2023-10-05'},
#  11: {'title': 'Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'ejercicio',
#    'estrés',
#    'estudiantes',
#    'salud',
#    'universitarios'},
#   'author': 'Diego Castro',
#   'date': '2023-11-12'},
#  12: {'title': 'El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.',
#   'keywords': {'ansiedad',
#    'estudiantes',
#    'meditación',
#    'mindfulness',
#    'universitarios'},
#   'author': 'Sofía Vega',
#   'date': '2023-12-01'},
#  13: {'title': 'Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.',
#   'keywords': {'apoyo',
#    'estudiantes',
#    'estudio',
#    'grupos',
#    'mental',
#    'psicológico',
#    'salud',
#    'universitarios'},
#   'author': 'Marcos Ortiz',
#   'date': '2024-01-10'},
#  14: {'title': 'Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.',
#   'keywords': {'académico',
#    'desempeño',
#    'estudiantes',
#    'mental',
#    'salud',
#    'servicios',
#    'universitarios'},
#   'author': 'Paula Morales',
#   'date': '2024-02-15'},
#  15: {'title': 'Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.',
#   'keywords': {'actividades',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'extracurriculares',
#    'social'},
#   'author': 'José Herrera',
#   'date': '2024-03-05'},
#  16: {'title': 'El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.',
#   'keywords': {'competencias',
#    'desarrollo',
#    'educación',
#    'innovación',
#    'laboratorios',
#    'tecnológicas'},
#   'author': 'Andrea Díaz',
#   'date': '2024-04-20'},
#  17: {'title': 'Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.',
#   'keywords': {'campus',
#    'colaboración',
#    'diseño',
#    'interacción',
#    'tendencias'},
#   'author': 'Sergio Muñoz',
#   'date': '2024-05-15'},
#  18: {'title': 'Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.',
#   'keywords': {'académico',
#    'bienestar',
#    'comparación',
#    'estudiantes',
#    'rendimiento',
#    'trabajan'},
#   'author': 'Isabel Flores',
#   'date': '2024-06-10'},
#  19: {'title': 'Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'agotamiento',
#    'estudiantes',
#    'factores',
#    'prevención',
#    'riesgo',
#    'universitarios'},
#   'author': 'Ricardo Ramos',
#   'date': '2024-07-25'},
#  20: {'title': 'El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.',
#   'keywords': {'calidad',
#    'estudiantes',
#    'redes',
#    'sociales',
#    'sueño',
#    'tecnología'},
#   'author': 'Valeria Castillo',
#   'date': '2024-08-30'},
#  21: {'title': 'Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.',
#   'keywords': {'ambiental',
#    'edificios',
#    'impacto',
#    'sostenibilidad',
#    'tecnologías',
#    'universitarios',
#    'verdes'},
#   'author': 'Daniel Medina',
#   'date': '2024-09-18'},
#  22: {'title': 'Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.',
#   'keywords': {'bicicletas',
#    'compartidas',
#    'movilidad',
#    'sostenible',
#    'transporte',
#    'universidades'},
#   'author': 'Patricia Reyes',
#   'date': '2024-10-05'},
#  23: {'title': 'Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.',
#   'keywords': {'académica',
#    'apoyo',
#    'carga',
#    'emocional',
#    'estudiantes',
#    'salud',
#    'universitario'},
#   'author': 'Gonzalo Soto',
#   'date': '2024-11-12'},
#  24: {'title': 'Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.',
#   'keywords': {'académica',
#    'equilibrio',
#    'estrategias',
#    'estudiantes',
#    'social',
#    'vida'},
#   'author': 'Camila Aguilar',
#   'date': '2024-12-01'},
#  25: {'title': 'La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.',
#   'keywords': {'actividades',
#    'artísticas',
#    'bienestar',
#    'creatividad',
#    'psicológico',
#    'universitaria',
#    'vida'},
#   'author': 'Adrián Vargas',
#   'date': '2025-01-10'},
#  26: {'title': 'Los beneficios de los programas de becas para la retención de estudiantes en universidades.',
#   'keywords': {'becas',
#    'beneficios',
#    'estudiantes',
#    'programas',
#    'retención',
#    'universidades'},
#   'author': 'Teresa Romero',
#   'date': '2025-02-15'},
#  27: {'title': 'El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.',
#   'keywords': {'actividad',
#    'deportes',
#    'estudiantes',
#    'física',
#    'integración',
#    'social'},
#   'author': 'Alberto Peña',
#   'date': '2025-03-05'},
#  28: {'title': 'Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.',
#   'keywords': {'bienestar',
#    'estrés',
#    'eventos',
#    'reducción',
#    'talleres',
#    'universidad'},
#   'author': 'Silvia Campos',
#   'date': '2025-04-20'},
#  29: {'title': 'Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.',
#   'keywords': {'análisis',
#    'estudiantes',
#    'exámenes',
#    'hábitos',
#    'rendimiento',
#    'sueño'},
#   'author': 'Óscar Luna',
#   'date': '2025-05-15'},
#  30: {'title': 'Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.',
#   'keywords': {'artificial',
#    'comunidades',
#    'inteligencia',
#    'médicos',
#    'remotas',
#    'servicios',
#    'tecnología'},
#   'author': 'María Paredes',
#   'date': '2025-06-10'}}

# %% [markdown]
# #### **2. Procesamiento de las Consultas:**
# *   Definir las consultas proporcionadas.
# *   Extraer las palabras clave de cada consulta.

# %%
# Extraer palabras clave de cada consulta usando la función process_text
query_keywords = {query_id: process_text(query) for query_id, query in queries.items()}

# Imprimir las palabras clave de cada consulta
query_keywords
# Out:
# {1: {'académico',
#   'estudiantes',
#   'impacto',
#   'mental',
#   'rendimiento',
#   'salud',
#   'universitarios'},
#  2: {'actividades',
#   'bienestar',
#   'campus',
#   'emocional',
#   'extracurriculares',
#   'universitario'},
#  3: {'estrategias', 'estrés', 'estudiantes', 'reducir', 'universitarias'}}

# %% [markdown]
# **Generación del Vocabulario**: Recorremos todos los documentos y consultas para extraer el conjunto de todas las palabras clave únicas, construyendo el vocabulario completo.

# %%
# Importar la biblioteca numpy para operaciones numéricas
import numpy as np

# Crear un conjunto de todas las palabras clave únicas de los documentos y las consultas
all_keywords = set()

# Agregar palabras clave de cada documento al conjunto all_keywords
for doc in corpus.values():
    all_keywords.update(doc['keywords'])

# Agregar palabras clave de cada consulta al conjunto all_keywords
for query_keywords_set in query_keywords.values():
    all_keywords.update(query_keywords_set)

# Genera un diccionario de palabras clave donde cada palabra clave se asocia a un índice único
keyword_to_index = {keyword: idx for idx, keyword in enumerate(all_keywords)}

# Imprimir el diccionario de palabras clave con sus índices correspondientes
print(keyword_to_index)
# Out:
# {'eventos': 0, 'artificial': 1, 'estudio': 2, 'psicológico': 3, 'redes': 4, 'carga': 5, 'espacios': 6, 'ansiedad': 7, 'bicicletas': 8, 'tendencias': 9, 'tecnologías': 10, 'estrés': 11, 'saludables': 12, 'social': 13, 'exámenes': 14, 'telemedicina': 15, 'mental': 16, 'cognitivo': 17, 'calidad': 18, 'trabajan': 19, 'sostenible': 20, 'investigación': 21, 'salud': 22, 'preventiva': 23, 'servicios': 24, 'estrategias': 25, 'campus': 26, 'sueño': 27, 'hábitos': 28, 'médica': 29, 'adultos': 30, 'comunidades': 31, 'universitario': 32, 'extracurriculares': 33, 'retención': 34, 'grupos': 35, 'laboratorios': 36, 'competencias': 37, 'agotamiento': 38, 'universitaria': 39, 'emocional': 40, 'educación': 41, 'física': 42, 'tratamiento': 43, 'concentración': 44, 'vida': 45, 'cultura': 46, 'verdes': 47, 'equilibrio': 48, 'interacción': 49, 'comparación': 50, 'creatividad': 51, 'ejercicio': 52, 'avances': 53, 'riesgo': 54, 'beneficios': 55, 'recursos': 56, 'ambiental': 57, 'académica': 58, 'desempeño': 59, 'edificios': 60, 'desarrollo': 61, 'universitarias': 62, 'rendimiento': 63, 'estudiantes': 64, 'universitarios': 65, 'actividad': 66, 'diseño': 67, 'movilidad': 68, 'reducción': 69, 'médicos': 70, 'bibliotecas': 71, 'deportes': 72, 'impacto': 73, 'nutrición': 74, 'universidades': 75, 'crónica': 76, 'estudiantil': 77, 'reducir': 78, 'jóvenes': 79, 'factores': 80, 'remotas': 81, 'tecnología': 82, 'meditación': 83, 'compartidas': 84, 'mindfulness': 85, 'relaciones': 86, 'academia': 87, 'actividades': 88, 'colaboración': 89, 'prevención': 90, 'bienestar': 91, 'talleres': 92, 'sociales': 93, 'integración': 94, 'universidad': 95, 'innovación': 96, 'apoyo': 97, 'inteligencia': 98, 'sostenibilidad': 99, 'familiar': 100, 'académico': 101, 'análisis': 102, 'artísticas': 103, 'transporte': 104, 'programas': 105, 'lectura': 106, 'amistad': 107, 'tecnológicos': 108, 'tecnológicas': 109, 'becas': 110, 'medicina': 111}

# %% [markdown]
# #### **3. Cálculo de Relevancia:**
# *   Utilizar métricas de similitud (Similitud Coseno y Jaccard) entre la representación vectorial de los documentos y las de las consultas.
# *   Calcular la puntuación de relevancia para cada documento del corpus respecto a cada consulta.

# %% [markdown]
# **Funcion de Vectores Binarios y Similitud de Jaccard:** create_binary_vector convierte palabras clave en un vector binario basado en el vocabulario y jaccard_similarity mide la similitud entre dos conjuntos y la division entre su intersección y unión.

# %%
# Convierte palabras clave en un vector binario con base en el vocabulario
def create_binary_vector(keywords, keyword_to_index):
    vector = np.zeros(len(keyword_to_index))  # Inicializa un vector de 0s
    for keyword in keywords:
        if keyword in keyword_to_index:       # Si la palabra clave está en el vocabulario
            vector[keyword_to_index[keyword]] = 1  # Asigna 1
    return vector

# Calcula la similitud de Jaccard
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))  # Tamaño de la intersección
    union = len(set1.union(set2))                # Tamaño de la unión
    return intersection / union if union != 0 else 0  # Retorna el valor de Jaccard

# %% [markdown]
# **Función para Calcular la Similitud de Coseno:** similitud entre dos vectores calculando el coseno del ángulo entre ellos.

# %%
# Función para calcular la similitud de coseno entre dos vectores
def cosine_similarity(vector1, vector2):
    dot_product = np.dot(vector1, vector2)         # Producto punto entre los dos vectores
    norm_a = np.linalg.norm(vector1)               # magnitud del primer vector
    norm_b = np.linalg.norm(vector2)               # magnitud del segundo vector
    # Retorna la similitud de coseno, manejamos si es que una magnitud es 0 retornamos 0
    return dot_product / (norm_a * norm_b) if norm_a != 0 and norm_b != 0 else 0

# %% [markdown]
# **Calcular Similitudes entre Consultas y Documentos**: calcula las similitudes entre cada consulta y cada documento utilizando tanto la similitud de coseno como la similitud de Jaccard. Estos se almacenan en un diccionario para cada consulta-documento.

# %%
# Creamos un diccionario para almacenar las similitudes
similarities = {query_id: {} for query_id in queries}

# Iterar sobre cada consulta y calcular las similitudes con todos los documentos
for query_id, query_keywords_set in query_keywords.items():
    query_vector = create_binary_vector(query_keywords_set, keyword_to_index)  # Crear el vector binario para la consulta

    for doc_id, doc_info in corpus.items():
        doc_vector = create_binary_vector(doc_info['keywords'], keyword_to_index)  # Crear el vector binario para el documento

        # Calcular similitud de Coseno usando la funcion
        cos_sim = cosine_similarity(query_vector, doc_vector)

        # Calcular similitud de Jaccard usando la funcion
        jaccard_sim = jaccard_similarity(query_keywords_set, doc_info['keywords'])

        # Guardar ambas similitudes en el diccionario
        similarities[query_id][doc_id] = {
            'cosine_similarity': cos_sim,
            'jaccard_similarity': jaccard_sim
        }

# Mostrar las similitudes calculadas
similarities
# Out:
# {1: {1: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   2: {'cosine_similarity': 0.7715167498104595, 'jaccard_similarity': 0.625},
#   3: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   4: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   5: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   6: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   7: {'cosine_similarity': 0.7715167498104595, 'jaccard_similarity': 0.625},
#   8: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   9: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   10: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   11: {'cosine_similarity': 0.6172133998483676,
#    'jaccard_similarity': 0.4444444444444444},
#   12: {'cosine_similarity': 0.33806170189140655, 'jaccard_similarity': 0.2},
#   13: {'cosine_similarity': 0.5345224838248487,
#    'jaccard_similarity': 0.36363636363636365},
#   14: {'cosine_similarity': 0.7142857142857142,
#    'jaccard_similarity': 0.5555555555555556},
#   15: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   16: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   17: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   18: {'cosine_similarity': 0.4629100498862757, 'jaccard_similarity': 0.3},
#   19: {'cosine_similarity': 0.4285714285714285,
#    'jaccard_similarity': 0.2727272727272727},
#   20: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   21: {'cosine_similarity': 0.2857142857142857,
#    'jaccard_similarity': 0.16666666666666666},
#   22: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   23: {'cosine_similarity': 0.2857142857142857,
#    'jaccard_similarity': 0.16666666666666666},
#   24: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   25: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   26: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   27: {'cosine_similarity': 0.1543033499620919,
#    'jaccard_similarity': 0.08333333333333333},
#   28: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   29: {'cosine_similarity': 0.3086066999241838,
#    'jaccard_similarity': 0.18181818181818182},
#   30: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0}},
#  2: {1: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   2: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   3: {'cosine_similarity': 0.33333333333333337, 'jaccard_similarity': 0.2},
#   4: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   5: {'cosine_similarity': 0.33333333333333337, 'jaccard_similarity': 0.2},
#   6: {'cosine_similarity': 0.16666666666666669,
#    'jaccard_similarity': 0.09090909090909091},
#   7: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   8: {'cosine_similarity': 0.33333333333333337, 'jaccard_similarity': 0.2},
#   9: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   10: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   11: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   12: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   13: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   14: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   15: {'cosine_similarity': 0.6666666666666667, 'jaccard_similarity': 0.5},
#   16: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   17: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   18: {'cosine_similarity': 0.16666666666666669,
#    'jaccard_similarity': 0.09090909090909091},
#   19: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   20: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   21: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   22: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   23: {'cosine_similarity': 0.3086066999241838,
#    'jaccard_similarity': 0.18181818181818182},
#   24: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   25: {'cosine_similarity': 0.3086066999241838,
#    'jaccard_similarity': 0.18181818181818182},
#   26: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   27: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   28: {'cosine_similarity': 0.16666666666666669,
#    'jaccard_similarity': 0.09090909090909091},
#   29: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   30: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0}},
#  3: {1: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   2: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   3: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   4: {'cosine_similarity': 0.19999999999999996,
#    'jaccard_similarity': 0.1111111111111111},
#   5: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   6: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   7: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   8: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   9: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   10: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   11: {'cosine_similarity': 0.3651483716701107,
#    'jaccard_similarity': 0.2222222222222222},
#   12: {'cosine_similarity': 0.19999999999999996,
#    'jaccard_similarity': 0.1111111111111111},
#   13: {'cosine_similarity': 0.15811388300841897,
#    'jaccard_similarity': 0.08333333333333333},
#   14: {'cosine_similarity': 0.16903085094570328,
#    'jaccard_similarity': 0.09090909090909091},
#   15: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   16: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   17: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   18: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   19: {'cosine_similarity': 0.16903085094570328,
#    'jaccard_similarity': 0.09090909090909091},
#   20: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   21: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   22: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   23: {'cosine_similarity': 0.16903085094570328,
#    'jaccard_similarity': 0.09090909090909091},
#   24: {'cosine_similarity': 0.3651483716701107,
#    'jaccard_similarity': 0.2222222222222222},
#   25: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0},
#   26: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   27: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   28: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   29: {'cosine_similarity': 0.18257418583505536, 'jaccard_similarity': 0.1},
#   30: {'cosine_similarity': 0.0, 'jaccard_similarity': 0.0}}}

# %% [markdown]
# #### **4. Ranking de Documentos:**
# *   Ordenar los documentos en función de su puntuación de relevancia de mayor a menor.
# *   Mostrar el ranking de documentos para cada consulta.

# %% [markdown]
# Ordenamos los documentos para cada consulta según la similitud de cosenoo Jaccard y genera un ranking. Luego, imprimimos el ranking.

# %%
# Crear un diccionario para almacenar los rankings
ranked_documents = {query_id: {} for query_id in queries}

# Para cada consulta, ordenar los documentos por la métrica de similitud
for query_id, doc_similarities in similarities.items():
    # Ordenar por similitud de coseno
    sorted_docs = sorted(doc_similarities.items(), key=lambda item: item[1]['cosine_similarity'], reverse=True)

    # El siguiente codigo comentado es si quremos ordenar el codigo mediante la similitud jaccard
    # sorted_docs = sorted(doc_similarities.items(), key=lambda item: item[1]['jaccard_similarity']], reverse=True)

    # Almacenar el ranking de documentos en ranked_documents
    ranked_documents[query_id] = [(doc_id, scores['cosine_similarity'], scores['jaccard_similarity']) for doc_id, scores in sorted_docs]

# Mostrar el ranking de documentos para cada consulta
for query_id, ranking in ranked_documents.items():
    print(f"\nConsulta {query_id}: '{queries[query_id]}'")
    print("Ranking de documentos:")
    for rank, (doc_id, cos_sim, jaccard_sim) in enumerate(ranking, start=1):
        doc_title = corpus[doc_id]['title']  # Obtener el título del documento
        print(f"  {rank}. Documento {doc_id} - Similitud de Coseno: {cos_sim:.4f}, Similitud de Jaccard: {jaccard_sim:.4f}")
        print(f"     Título: {doc_title}")
# Out:
# Consulta 1: 'Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios'
# Ranking de documentos:
#   1. Documento 2 - Similitud de Coseno: 0.7715, Similitud de Jaccard: 0.6250
#      Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#   2. Documento 7 - Similitud de Coseno: 0.7715, Similitud de Jaccard: 0.6250
#      Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#   3. Documento 14 - Similitud de Coseno: 0.7143, Similitud de Jaccard: 0.5556
#      Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#   4. Documento 11 - Similitud de Coseno: 0.6172, Similitud de Jaccard: 0.4444
#      Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#   5. Documento 13 - Similitud de Coseno: 0.5345, Similitud de Jaccard: 0.3636
#      Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#   6. Documento 18 - Similitud de Coseno: 0.4629, Similitud de Jaccard: 0.3000
#      Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#   7. Documento 19 - Similitud de Coseno: 0.4286, Similitud de Jaccard: 0.2727
#      Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#   8. Documento 12 - Similitud de Coseno: 0.3381, Similitud de Jaccard: 0.2000
#      Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#   9. Documento 29 - Similitud de Coseno: 0.3086, Similitud de Jaccard: 0.1818
#      Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#   10. Documento 21 - Similitud de Coseno: 0.2857, Similitud de Jaccard: 0.1667
#      Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#   11. Documento 23 - Similitud de Coseno: 0.2857, Similitud de Jaccard: 0.1667
#      Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#   12. Documento 1 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#   13. Documento 6 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#   14. Documento 8 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#   15. Documento 15 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#   16. Documento 20 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#   17. Documento 24 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#   18. Documento 26 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#   19. Documento 27 - Similitud de Coseno: 0.1543, Similitud de Jaccard: 0.0833
#      Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#   20. Documento 3 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#   21. Documento 4 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#   22. Documento 5 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#   23. Documento 9 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#   24. Documento 10 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#   25. Documento 16 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#   26. Documento 17 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#   27. Documento 22 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#   28. Documento 25 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#   29. Documento 28 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#   30. Documento 30 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#
# Consulta 2: 'Actividades extracurriculares y bienestar emocional en el campus universitario'
# Ranking de documentos:
#   1. Documento 15 - Similitud de Coseno: 0.6667, Similitud de Jaccard: 0.5000
#      Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#   2. Documento 3 - Similitud de Coseno: 0.3333, Similitud de Jaccard: 0.2000
#      Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#   3. Documento 5 - Similitud de Coseno: 0.3333, Similitud de Jaccard: 0.2000
#      Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#   4. Documento 8 - Similitud de Coseno: 0.3333, Similitud de Jaccard: 0.2000
#      Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#   5. Documento 23 - Similitud de Coseno: 0.3086, Similitud de Jaccard: 0.1818
#      Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#   6. Documento 25 - Similitud de Coseno: 0.3086, Similitud de Jaccard: 0.1818
#      Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#   7. Documento 17 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#   8. Documento 6 - Similitud de Coseno: 0.1667, Similitud de Jaccard: 0.0909
#      Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#   9. Documento 18 - Similitud de Coseno: 0.1667, Similitud de Jaccard: 0.0909
#      Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#   10. Documento 28 - Similitud de Coseno: 0.1667, Similitud de Jaccard: 0.0909
#      Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#   11. Documento 1 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#   12. Documento 2 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#   13. Documento 4 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#   14. Documento 7 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#   15. Documento 9 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#   16. Documento 10 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#   17. Documento 11 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#   18. Documento 12 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#   19. Documento 13 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#   20. Documento 14 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#   21. Documento 16 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#   22. Documento 19 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#   23. Documento 20 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#   24. Documento 21 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#   25. Documento 22 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#   26. Documento 24 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#   27. Documento 26 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#   28. Documento 27 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#   29. Documento 29 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#   30. Documento 30 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#
# Consulta 3: 'Estrategias universitarias para reducir el estrés en estudiantes'
# Ranking de documentos:
#   1. Documento 11 - Similitud de Coseno: 0.3651, Similitud de Jaccard: 0.2222
#      Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#   2. Documento 24 - Similitud de Coseno: 0.3651, Similitud de Jaccard: 0.2222
#      Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#   3. Documento 4 - Similitud de Coseno: 0.2000, Similitud de Jaccard: 0.1111
#      Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#   4. Documento 12 - Similitud de Coseno: 0.2000, Similitud de Jaccard: 0.1111
#      Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#   5. Documento 2 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#   6. Documento 5 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#   7. Documento 6 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#   8. Documento 8 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#   9. Documento 15 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#   10. Documento 18 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#   11. Documento 20 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#   12. Documento 26 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#   13. Documento 27 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#   14. Documento 28 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#   15. Documento 29 - Similitud de Coseno: 0.1826, Similitud de Jaccard: 0.1000
#      Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#   16. Documento 14 - Similitud de Coseno: 0.1690, Similitud de Jaccard: 0.0909
#      Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#   17. Documento 19 - Similitud de Coseno: 0.1690, Similitud de Jaccard: 0.0909
#      Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#   18. Documento 23 - Similitud de Coseno: 0.1690, Similitud de Jaccard: 0.0909
#      Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#   19. Documento 13 - Similitud de Coseno: 0.1581, Similitud de Jaccard: 0.0833
#      Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#   20. Documento 1 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#   21. Documento 3 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#   22. Documento 7 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#   23. Documento 9 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#   24. Documento 10 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#   25. Documento 16 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#   26. Documento 17 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#   27. Documento 21 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#   28. Documento 22 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#   29. Documento 25 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#   30. Documento 30 - Similitud de Coseno: 0.0000, Similitud de Jaccard: 0.0000
#      Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
