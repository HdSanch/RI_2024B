# %% [markdown]
# ## Taller 05: Herramientas para Indexación
# ##### Fecha de entrega: Lunes 13 de enero de 2025.
# ### Integrantes: Dilan Andrade, Hernán Sánchez y Galo Tarapués

# %% [markdown]
# ## **Parte 1: Construcción Manual de un Índice Invertido**

# %% [markdown]
# 1. Cargar los datos en Python.
# El código utiliza la biblioteca 'pandas' para cargar el archivo CSV en un DataFrame mediante 'pd.read_csv', lo que permite manejar los datos. La función 'dataset.head()' confirma que los datos se cargaron correctamente.

# %%
import pandas as pd
import re
from collections import defaultdict

file_path = r'.\wiki_movie_plots_deduped.csv'
dataset = pd.read_csv(file_path)

dataset.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %% [markdown]
# 2. Construir un índice invertido manualmente:
#     - Procesa las tramas de las películas para crear un índice invertido.
#     - Normaliza el texto de las tramas.

# %% [markdown]
# El código selecciona las columnas 'Title' y 'Plot' del dataset y verifica si hay valores nulos en ellas. Luego, elimina las filas que contienen valores nulos para asegurar que los datos sean completos. Después, normaliza el texto de la columna Plot convirtiéndolo a minúsculas y eliminando la puntuación, creando una nueva columna Normalized Plot con el texto limpio.

# %%
data = dataset[['Title', 'Plot']]

print(f"Valores nulos antes de limpiar:\n{data.isnull().sum()}")

data = data.dropna(subset=['Title', 'Plot'])

def normalize_text(text):
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

data['Normalized Plot'] = data['Plot'].apply(normalize_text)
data[['Title', 'Normalized Plot']].head()
# Out:
# Valores nulos antes de limpiar:
# Title    0
# Plot     0
# dtype: int64
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                      Normalized Plot
# 0  a bartender is working at a saloon serving dri...
# 1  the moon painted with a smiling face hangs ove...
# 2  the film just over a minute long is composed o...
# 3  lasting just 61 seconds and consisting of two ...
# 4  the earliest known adaptation of the classic f...

# %% [markdown]
# Se construye un índice invertido al iterar sobre cada fila del DataFrame. Para cada película, se extrae el título y la trama normalizada, luego se tokeniza en palabras. Cada palabra se agrega al índice invertido. Luego, se eliminan los duplicados de las listas de títulos para optimizar el índice. Finalmente, se muestra una parte del índice invertido.

# %%
index = defaultdict(list)

for idx, row in data.iterrows():
    title = row['Title']
    plot = row['Normalized Plot']
    tokens = plot.split()  # Tokenizar el texto en palabras

    for token in tokens:
        index[token].append(title)  # Agregar el título al índice

for key in index:
    index[key] = list(set(index[key]))

list(index.items())[:10]
# Out:
# [('a',
#   ['Alex & Emma',
#    'Strip Tease Murder',
#    'Carry on Jatta',
#    'Shrieker',
#    'Everything Is Illuminated',
#    'The Attorney',
#    'Sthalathe Pradhana Payyans',
#    'A Cold Wind in August',
#    'Margot at the Wedding',
#    'En Sakhiye',
#    'Ghosts',
#    'East of Piccadilly',
#    'Fool Coverage',
#    'The Inner Circle',
#    'The Pompatus of Love',
#    'Dhaai Akshar Prem Ke',
#    "A Dog's Purpose",
#    'Flaming Brothers',
#    'Damadamm!',
#    "Just Another Pandora's Box",
#    'Dog Pound',
#    'Kanni Thaai',
#    'On the Town',
#    'The Legend of Qin',
#    'Star Trek VI: The Undiscovered Country',
#    'Ami Aaj Nasto Hoye Jai',
#    'Bhagyadevatha (ഭാഗ്യദേവത)',
#    'Hell in the Pacific',
#    'Virginia',
#    'Christmas with the Dead',
#    'Nuvvostanante Nenoddantana',
#    'Center Stage',
#    "There's One Born Every Minute",
#    'Badsha The Don',
#    'Ali',
#    'I Love You, Man',
#    'Star!',
#    'Goal!',
#    'Cry for Happy',
#    'Ebbtide',
#    'A Daughter of the Gods',
#    'Texas Across the River',
#    'The Butcher, the Chef and the Swordsman',
#    'Resistance',
#    'Kondaveeti Raja',
#    'Night Passage',
#    'What Happens in Vegas',
#    'A King in New York',
#    'Vedam',
#    'Memories in March',
#    'Rudolph the Red-Nosed Reindeer: The Movie',
#    'Singham Returns',
#    'The Cardinal',
#    'The NeverEnding Story II: The Next Chapter',
#    'Leprechaun',
#    'Latitude 55°',
#    'Love and Bullets',
#    'MCA (Middle Class Abbayi)',
#    'Sendhoorapandi',
#    "Taming Sutton's Gal",
#    'Plastic',
#    'Valley Girl',
#    'The Chocolate Soldier',
#    'Chetna',
#    'Decoding Annie Parker',
#    'Desiya Geetham',
#    'Enlighten Thy Daughter',
#    'Bazi',
#    'Fox Terror',
#    'Jet Pilot',
#    'Plunder Road',
#    'Zor',
#    'Fallen',
#    'Lady of Burlesque',
#    'Hyde and Hare',
#    'Naina',
#    'Day Watch',
#    'California Split',
#    'A Shot at Glory',
#    'Female Prisoner #701: Scorpion',
#    'The Resistance',
#    'Godzilla vs. King Ghidorah',
#    'Cat-Tails for Two',
#    'Mere Oblivion',
#    'Miss Robin Crusoe',
#    'October Sky',
#    'Ayee Milan Ki Bela',
#    'Larceny, Inc.',
#    'The Big Pond',
#    "I've Heard the Mermaids Singing",
#    'Oru Vadakkan Selfie',
#    'Repeaters',
#    'Stuck',
#    'Cardcaptor Sakura Movie 2: The Sealed Card',
#    'Miley Naa Miley Hum',
#    'Bella',
#    'Flying Tigers',
#    'Cross-Country Romance',
#    'Narsimha',
#    'Godzilla vs. Hedorah',
#    'Permanent Record',
#    'The Naked Jungle',
#    'The Accused',
#    'Wild on the Beach',
#    'Paris',
#    'Jhootha Hi Sahi',
#    'Five-Year Engagement, TheThe Five-Year Engagement',
#    'The Falcon and the Co-eds',
#    'Ghosts of Mississippi',
#    'Requiem for a Handsome Bastard (Requiem pour un beau sans-coeur)',
#    ' Dish, TheThe Dish',
#    'The Caterpillar Wish',
#    'Kathputli',
#    'Calling Homicide',
#    'The Fifth Estate',
#    'Sivappu Mazhai',
#    'Panic Room',
#    'Hollywood',
#    "6'2",
#    'Fall Time',
#    'If I Were Rich',
#    'Rhythm and Weep',
#    '27 Down',
#    ' On Line',
#    'Go',
#    'Veer',
#    'New Orleans Uncensored',
#    'The Evil of Frankenstein',
#    'Only Lovers Left Alive',
#    'The Oogieloves in the Big Balloon Adventure',
#    'Prison on Fire',
#    'The Scarlet Pimpernel',
#    'Pataal Bhairavi',
#    'The Wind and the Lion',
#    'Tamayura 3',
#    'Mansfield Park',
#    'Lovely',
#    'The Sky Pilot',
#    'My Gun Is Quick',
#    'The Wizard of Gore',
#    'Gangs of Wasseypur – Part 2',
#    'Navdeep, Santhoshi, Ayesha Jhulka',
#    'Bodyguards and Assassins',
#    'The Mini-Affair',
#    'Nice Women',
#    'The Night We Called it a Day',
#    'The Long and the Short and the Tall',
#    'Snow Flower and the Secret Fan',
#    '3 Ninjas',
#    'Quintet',
#    'Rag Doll',
#    'Barry Munday',
#    'Pedro Calungsod: Batang Martir',
#    'Balarama Krishnulu',
#    'Volcano',
#    'Mayangaathey',
#    'Abe Lincoln in Illinois',
#    'Nila Penne',
#    'Ed Wood',
#    'Munthirivallikal Thalirkkumbol',
#    'Pan',
#    'Armaan',
#    'Enigma',
#    'LIE',
#    'Me and You and Everyone We Know',
#    'The Last Days of Pompeii',
#    'You Came Along',
#    'Oru Vidukadhai Oru Thodarkadhai',
#    "Sophie's Choice",
#    'Dutiful But Dumb',
#    'Backlash',
#    'Superstar: The Karen Carpenter Story',
#    ' The Tao of Steve',
#    'The Shakedown',
#    'Gandeevam',
#    'Kiss Me Deadly',
#    'Deewangee',
#    'Shin Godzilla',
#    'Pudhu Pudhu Arthangal',
#    'A Beautiful Mind',
#    'Sarvam ',
#    'Tales from the Crypt',
#    'The Games Maker',
#    'Superstar',
#    'Bangaarada Hoovu',
#    'Ek Baar Chale Aao',
#    'A Calamitous Elopement',
#    'The Little Minister',
#    'Geethaanjali',
#    'The Final Test',
#    'Teja Bhai & Family',
#    'Dark Star',
#    'Christmas Child',
#    'Caught Up',
#    'Creeps',
#    'Sweet Sixteen',
#    'The Lost Bladesman',
#    'Prabhuvinte Makkal (പ്രഭുവിന്റെ മക്കൾ)',
#    'Doppelganger',
#    'Song of the Thin Man',
#    'The Dance of Life',
#    'The Knack …and How to Get It',
#    'All That Jazz',
#    'Bheegi Palkein',
#    'Khadgam',
#    'My Last Five Girlfriends',
#    "Don't Bet on Women",
#    'Juwanna Mann',
#    'Tom & Jerry',
#    'Shadow Conspiracy',
#    'Some Kind of Wonderful',
#    'Bunshinsaba 2',
#    'Rare Birds',
#    'No Orchids for Miss Blandish',
#    'Yo-kai Watch: Soratobu Kujira to Double no Sekai no Daibōken da Nyan!',
#    'Hard Rain',
#    'Son of a Gun',
#    'Thambi Vettothi Sundaram',
#    'Shaolin Wooden Men',
#    'Sssshhh...',
#    'Honnōji Hotel',
#    'Teachers',
#    'Some Kind of Hero',
#    'The Yellow Mountain',
#    'Book Thief, TheThe Book Thief',
#    'Anantha Poongathe',
#    'Step Down to Terror',
#    'Four Wives',
#    'Thenali Raman',
#    'Flight Nurse',
#    'Double Harness',
#    '9 KK Road',
#    'Man in the Middle',
#    ' Ratatouille',
#    'Aadmi Sadak Ka',
#    'The Case of the Mukkinese Battle Horn',
#    'Header',
#    'The Sound of Fury',
#    'Nefes: Vatan Sağolsun',
#    'Silver Bullet',
#    'The Ghost and Mrs. Muir',
#    'Underworld: Awakening',
#    'The Secret Invasion',
#    'Rambo',
#    'Together',
#    'Cocoon: The Return',
#    'The Ruins',
#    'Bran Nue Dae',
#    'En Veedu',
#    'Most Wanted',
#    'Tick Tock Tuckered',
#    'Rhino!',
#    'Sangili',
#    'Stork',
#    'The Nightmare Before Christmas',
#    'Stand By for Action',
#    "Hell's Heroes",
#    'I Dood It',
#    'Seven Swords',
#    'Endrendrum Punnagai',
#    'About Time',
#    'Bhairav',
#    '25',
#    'Hangover Part III, TheThe Hangover Part III',
#    'Singeetam Srinivasa Rao',
#    'Apna Sapna Money Money',
#    'Tip on a Dead Jockey',
#    'Angrej',
#    'Dalapathi',
#    'Nimirndhu Nil',
#    'Haseena Parkar',
#    'Takers',
#    'The Glass Mountain',
#    'Diplomatic Courier',
#    'Having Wonderful Time',
#    'Laurence Anyways',
#    'Elena',
#    'Mystic River',
#    'Amanush',
#    'Indra En Selvam',
#    'The Girl Who Came Late (aka Daydream Believer)',
#    'The Barefoot Mailman',
#    'Sairat',
#    'The Speckled Band',
#    'The Big Lift',
#    'Insaaf Kaun Karega',
#    'Beach Red',
#    "Dr. O'Dowd",
#    'Pelli Sandadi',
#    'Spanglish',
#    'Joggers Park',
#    "The Man from Blankley's",
#    'Lone Wolf and Cub: Baby Cart in Peril',
#    ' Mehndi Waley Hath',
#    'Sergeant Deadhead',
#    'Wired',
#    'No Way to Treat a Lady',
#    'Kusthi',
#    'The Great Escape',
#    'International Lady',
#    'Crooked Business',
#    'Bad Moon',
#    'Lady Snowblood: Love Song of Vengeance',
#    'Falling Down',
#    'Limitless',
#    'Electric Shadows',
#    'The Indian in the Cupboard',
#    'Collector',
#    'Super Nani',
#    'The Docks of New York',
#    'Puppet Master II',
#    'Fierce Creatures',
#    'The Divided Heart',
#    'The Last Producer',
#    'Target Zero',
#    'Meaghamann',
#    'Paradesi',
#    'Confessions of a Dangerous Mind',
#    'Madatha Kaja',
#    'Veettuku Veedu',
#    'Take Away',
#    'Grey Owl',
#    "Mama's Affair",
#    'Muddula Koduku',
#    'Rango',
#    'Manasulo Maata',
#    'Love Potion No. 9',
#    'I Was a Teenage Werewolf',
#    'What Every Woman Wants',
#    'Akaash Vani',
#    'Dirty Rotten Scoundrels',
#    'Raggedy Ann & Andy: A Musical Adventure',
#    'Is There a Doctor in the Mouse?',
#    'Two Weddings and a Funeral',
#    'Carry On Girls',
#    'Getting Straight',
#    'Dav Pech',
#    'Nightmare Alley',
#    'The Secret Life of an American Wife',
#    "Breakin'",
#    'Janice Meredith',
#    'The Fox Lover',
#    'Kadavul',
#    'Dizzy Detectives',
#    ' The Haunted Mansion',
#    '22 Jump Street',
#    'Moner Manush (film)',
#    'Miracle in Harlem',
#    'Million Dollar Mystery',
#    'My Flesh and Blood',
#    'Ashta Chamma',
#    'Samudhiram',
#    'Every Which Way but Loose',
#    'The Rocks of Valpre',
#    'Solid Geometry',
#    'Mister Roberts',
#    'The Great Waldo Pepper',
#    'Patrani',
#    'Beast to Die !The Beast to Die',
#    'Zindagi Na Milegi Dobara',
#    'The Hoodlum Saint',
#    'Nancy Goes to Rio',
#    'Ride Out for Revenge',
#    'Angel Baby',
#    "So's Your Aunt Emma",
#    "Badman's Territory",
#    'Hot Heir',
#    'Sindhu Bhairavi',
#    "I'm Dancing as Fast as I Can",
#    'Red Kingdom Rising',
#    'Tarzan and the Valley of Gold',
#    'The Corruptor',
#    'Q Planes',
#    'House of 1000 Corpses',
#    'Ek Thi Ladki',
#    'Tarana',
#    'Such Good Friends',
#    'Paradise Alley',
#    'Road to Perdition',
#    'Innathe Chintha Vishayam',
#    'This Angry Age',
#    'Radar Men from the Moon',
#    'Gentle Strangers',
#    'Retro Puppet Master',
#    'Tiyaan',
#    'The Riddle',
#    'The Mortal Instruments: City of Bones',
#    'Romie-0 and Julie-8',
#    'Wild Horse Hank',
#    'Attack of the Giant Leeches',
#    'Avan Ivan',
#    'Flipper',
#    'Mirch',
#    'Oru Murai Vanthu Parthaya',
#    'So Proudly We Hail!',
#    'Manal Kayiru',
#    'Out of Africa',
#    "The Warrior's Husband",
#    'I Have Lived',
#    'Mannadhi Mannan',
#    'Stander',
#    'White Reindeer',
#    '123',
#    'Arcadia',
#    'Fireworks, Should We See It from the Side or the Bottom? and Raving Jeff’s Stronger Battle',
#    'Minna no Ie',
#    'Daivathinte Swantham Cleetus',
#    'Animal Farm',
#    'Best Foot Forward',
#    "Comin' Round the Mountain",
#    'Blood Brothers',
#    'Sweet Home',
#    'The Touchables',
#    'Penthouse',
#    'Quest for Camelot',
#    'Sawan Aya Re',
#    'The Americano',
#    'Night Tide',
#    'The Jokers',
#    'Cabin in the Sky',
#    'Holy Man',
#    'Doctor in the House',
#    'Bel Ami',
#    '29th Street',
#    "One Night at McCool's",
#    'Johnny Come Lately',
#    'Sam and Me',
#    'Peddamanushulu',
#    'Far from Home: The Adventures of Yellow Dog',
#    'The Blue Peter',
#    'The War Lord',
#    'Shaun of the Dead',
#    'Birdcage Inn',
#    'Addams Family Values',
#    'Fragment of Fear',
#    ' Waist Deep',
#    'Dastaan',
#    'Makalkku',
#    'Dil Hi Dil Mein',
#    'In the Meantime, Darling',
#    'Capote',
#    'The Flintstones',
#    'Godzilla: Final Wars',
#    'Soul Men',
#    'Breaking Wind',
#    'Spandana',
#    'First Offenders',
#    'Ruby Gentry',
#    'Bunny',
#    'The Lost Tribe',
#    '12 Rounds 2: Reloaded',
#    'That Brennan Girl',
#    "Teacher's Pet",
#    'Dehorokkhi: The Bodyguard',
#    'Raise the Red Lantern',
#    'From Riches to Rags',
#    'The Tune',
#    'Asteroid',
#    'Sit Tight',
#    'Nartanasala',
#    'Never Say Die',
#    'Out of True',
#    'Thanga Padhumai',
#    'Yokomichi Yonosuke',
#    'Tuck Everlasting',
#    'Akasha Gopuram',
#    'Pasa Kiligal',
#    'The Treacherous',
#    'Pen Singam',
#    'Yugpurush',
#    'Gone',
#    'Those Redheads from Seattle',
#    'The Bed-Sitting Room',
#    'Picture Perfect',
#    'The Hi-Jackers',
#    'Manikya Kallu (മാണിക്യക്കല്ല്)',
#    'Chamak',
#    'Jebu Donga',
#    'Sitting Pretty',
#    'David',
#    'Runningshaadi.com',
#    'Oklahoma Annie',
#    'Outside These Walls',
#    'Hoovu Hannu',
#    'When Time Ran Out',
#    'Shadowboxing 3: Last Round',
#    'Here Comes Fortune',
#    'Neighbors',
#    'The Prisoner of Shark Island',
#    'Inside the Walls of Folsom Prison',
#    'Road to Paloma',
#    'Kathakali',
#    'Chances Are',
#    "Days of Darkness (L'Âge des ténèbres)",
#    'Dhosth',
#    'Those Magnificent Men in their Flying Machines',
#    'Welcome to Sarajevo',
#    'Athisaya Thirudan',
#    'Supernova',
#    'The Sun Sets at Dawn',
#    'The Mating Call',
#    'Duplicity',
#    'Freighters of Destiny',
#    'The Wild',
#    'The Adventurous Blonde',
#    'Blair Witch',
#    'Confessions of Boston Blackie',
#    'War for the Planet of the Apes',
#    'These Wilder Years',
#    'In Old Oklahoma',
#    'Maanasaandarapetta Yezdi',
#    'Gumnaam',
#    'Nongjungjo',
#    'The Dawns Here Are Quiet',
#    'Carolina Moon',
#    'Kakera: A Piece of Our Life',
#    'Periya Thambi',
#    "A Woman's Face",
#    'Mr. India',
#    'Corridors of Blood',
#    'Part Time Wife',
#    'Flavours',
#    'Pondatti Thevai',
#    'Counsel for Crime',
#    'Fast Break',
#    'Milan',
#    'What If...',
#    'Iti Srikanto',
#    'Hedwig and the Angry Inch',
#    'The Greatest Game Ever Played',
#    'Thodasa Roomani Ho Jaayen',
#    'She Married a Cop',
#    'Corpse Party',
#    'Gunaah',
#    'Time Bomb',
#    'Jaws: The Revenge',
#    'Gabriel Over the White House',
#    'Heroes Shed No Tears',
#    ' Yours, Mine and Ours',
#    'The Girl Said No',
#    'Naan Sigappu Manithan',
#    'Shri Ram Bhakta Hanuman',
#    'Oozham',
#    'Avengers of the Reef',
#    'Pushing Tin',
#    'Clash of the Titans',
#    'This Is My Father',
#    'Parayam',
#    'Young Soul Rebels',
#    'Desam',
#    'Time Table',
#    'Another Day in Paradise',
#    'Siragadikka Aasai',
#    "Guess Who's Coming to Dinner",
#    'Heavy Metal 2000',
#    'The Glass Cage',
#    'Charlie Chan in Panama',
#    'The Girl with the Dragon Tattoo',
#    'Jhinder Bandi',
#    'Wild 7',
#    'Always Be With You',
#    'Ambassador Bill',
#    'The Life and Death of Colonel Blimp',
#    'Ambuli',
#    'Boni',
#    'Pakarnnattam (പകർന്നാട്ടം)',
#    'Small Town Story',
#    'The Bitch',
#    'Red Cliff: Episode 2',
#    'Kuch Khatti Kuch Meethi',
#    'The Cars That Ate Paris',
#    'The Wall',
#    'Last Embrace',
#    'Children of the Corn',
#    'Yōkai Ningen Bem',
#    'Bye Bye Braverman',
#    'Rihaee',
#    'Three Who Loved',
#    'Criminals of the Air',
#    'Baby Take a Bow',
#    'He Married His Wife',
#    "Yes Sir, That's My Baby",
#    'The Doctor',
#    'Let Me Out',
#    'Kanni Rasi',
#    'Sorry Baby',
#    'Savithriyude Aranjanam',
#    'Whistle Blower',
#    'Aces High',
#    'The Phantom Rider',
#    'Edward II',
#    'Cantonen Iron Kung Fu',
#    'Beverly Hills Cop III',
#    'First Kid',
#    'Yuvaraja',
#    'Elvis & Nixon',
#    'Arie',
#    'Mammy',
#    "Who's Minding the Store?",
#    'Bhram',
#    'Pudhu Padagan',
#    'Imitation of Life',
#    'Murari',
#    'Through the Back Door',
#    'Darkness Falls',
#    "Nobody's Perfect",
#    'Moscow on the Hudson',
#    'Lured',
#    'Time Is My Enemy',
#    'Stone of Destiny',
#    'Wolfman',
#    'CZ12',
#    'Bad Moms',
#    'The Last Days on Mars',
#    'Beverly Hills Ninja',
#    'Three Strangers',
#    'Peddannayya',
#    'Adventures of Zatoichi',
#    'The Mark',
#    'Queen of the Mob',
#    'The Love Light',
#    'Afrita Hanem(The Genie Lady)',
#    'Oru Odai Nadhiyagirathu',
#    'Happy Though Married',
#    'G.I. Wanna Home',
#    'Brother of Bommali',
#    'Mudhal Kanave',
#    'Interlude',
#    'Megha',
#    'Solaris',
#    'Deranged',
#    'Seerivarum Kaalai',
#    'The Circle',
#    'The Prize Pest',
#    'In Name Only',
#    'Blackjack',
#    'Red Light',
#    'Manju Poloru Penkutty',
#    'Idlewild',
#    'BumRush',
#    'From Hell It Came',
#    'The Blue Butterfly',
#    'The Woman in Green',
#    'One Dangerous Night',
#    'Manoranjan',
#    'Take Me Home Tonight',
#    'The Matrix Revolutions',
#    'The Oscar',
#    'Ugly',
#    "River's End",
#    'One More Tomorrow',
#    'There Will Be Blood',
#    'Finger Print',
#    'Ippadai Vellum',
#    'Lust in the Dust',
#    'Kalangarai Vilakkam',
#    'Urumi',
#    'The Redhead from Wyoming',
#    'That Lady from Peking',
#    'No Holds Barred',
#    'The Man from U.N.C.L.E.',
#    'Chandrahasa',
#    'Nagasaki: Memories of My Son',
#    'Escape Me Never',
#    'I Think I Love My Wife',
#    'Third Person',
#    '99',
#    'The Domino Principle',
#    'Sharapanjara',
#    'Man of Will',
#    'Paddington 2',
#    'Anchorman 2: The Legend Continues',
#    'Passkey to Danger',
#    'Maw`ed Ma` al-Hayat (Appointment with Life)',
#    'My Summer Story',
#    'Josephine and Men',
#    'Akhil',
#    'Three-Cornered Moon',
#    'Hell Is a City',
#    'Border Incident',
#    'Crooked House',
#    'The Case for the Crown',
#    'Pyar Ka Mausam',
#    'Married and in Love',
#    'Alone with Her',
#    'The High Powered Rifle',
#    'Free Jimmy',
#    'Vampire Circus',
#    'Brotherhood of Blood',
#    'The Creeping Terror',
#    'The Way',
#    'Yodha',
#    'Salt',
#    'Company Business',
#    'The Black Pirate',
#    'Men in Her Life',
#    'Battle Cry',
#    'Love Breakups Zindagi',
#    'The Architect',
#    'Gamyam',
#    'Rome Adventure',
#    'Cowboys & Aliens',
#    'Lords of Dogtown',
#    'Fred Claus',
#    'Raging Bull',
#    'The Rise and Fall of a White Collar Hooligan',
#    "Hey Good Lookin'",
#    'Varasudu',
#    'Daaku Aur Jawan',
#    'First Yank into Tokyo',
#    'One for the Money',
#    'Modesty Blaise',
#    'Sleepy-Time Tom',
#    'Free Birds',
#    'Career Opportunities',
#    'Protégé',
#    'Freebie and the Bean',
#    "Wes Craven's New Nightmare",
#    'National Treasure',
#    'Madhumati',
#    'When I Fall in Love... with Both',
#    'Ribbit',
#    'The Inn of the Sixth Happiness',
#    'Pookari',
#    'Live Wire',
#    'The Impassive Footman',
#    'The Firefly',
#    'The Lawless Breed',
#    'Heneral Luna',
#    'The Rest Cure',
#    'Encounters of the Spooky Kind',
#    'Devatha',
#    ' Racing Stripes',
#    'Moonar',
#    'Planes, Trains and Automobiles',
#    'Carnegie Hall',
#    'Easy Come, Easy Go',
#    'Pisau Cukur',
#    'Confession',
#    'The Red Mill',
#    'Natarang',
#    'Nenjil Jil Jil',
#    'Invisible Target',
#    'Rabb Da Radio',
#    'Messiah of Evil aka Dead People',
#    'Butch and Sundance: The Early Days',
#    'Battle of the Year',
#    'Mean Creek',
#    'All Saints',
#    'Righting Wrongs',
#    'Me and the Colonel',
#    'The Dark Mirror',
#    'Go, Go Second Time Virgin',
#    'The Devil Is Driving',
#    'The Table',
#    'Naan Kadavul ',
#    'Ammakkilikkoodu',
#    'Bloodfist II',
#    'Woman in the Dunes',
#    'Divorce',
#    'Legend of a Fighter',
#    'Chungking Express',
#    'Maïna',
#    'The Squaw Man',
#    'Mommo',
#    'Sex Jack[23]',
#    'Hot Rod',
#    'The Angry Birds Movie',
#    'Mughal-e-Azam (Colorized Version)',
#    'Dr. Plonk',
#    'Mylanchi Monchulla Veedu',
#    'Night of the Living Dead',
#    'The Boys Next Door',
#    'The Best Years',
#    'Captain Nemo and the Underwater City',
#    'Seven Days to Noon',
#    'Ironweed',
#    'Ice Cream',
#    'A Gunfight',
#    'Jumping for Joy',
#    'The Falcon in Mexico',
#    'The Last Tycoon',
#    'Ninaithale',
#    'Paadam Onnu: Oru Vilapam',
#    'The Blood of Jesus',
#    'Indecent Proposal',
#    'Nee Kosam',
#    'Sachin: A Billion Dreams',
#    'The Family Jewels',
#    'Revenge of the Creature',
#    'Lord of the Flies',
#    'Outrage Coda',
#    ' Yogi Bear',
#    'Kanchana 2',
#    'Breezy',
#    'The Life Aquatic with Steve Zissou',
#    'Holy Matrimony',
#    'Kurukshetram',
#    'The Girl from Missouri',
#    'The Gulf Between',
#    'Jack Frost',
#    'Anbe Deivam',
#    'Deception',
#    'Wrong World',
#    'Undercover',
#    'Police Academy 3: Back in Training',
#    'Primeval',
#    'The Kingdom',
#    'Suite Française',
#    'Solo',
#    'The Wind That Shakes the Barley',
#    'Niram Maaratha Pookkal',
#    'The Thief',
#    'Line Walker',
#    'Adhe Kangal',
#    'The Wild Geese',
#    'Fort Utah',
#    'Moon 44',
#    'And One Was Beautiful',
#    'Meshes of the Afternoon',
#    'Kajraare',
#    'Steamboat Bill, Jr.',
#    'City Slickers',
#    'Zameen Ke Tare',
#    'Thomas & the Magic Railroad',
#    'The Little Kidnappers',
#    'Among Giants',
#    'Playing the Victim',
#    'Vichitra Kutumbam',
#    'Yuvaraju',
#    'Woman in Hiding',
#    'Summertree',
#    'The Long Goodbye',
#    'Don Seenu',
#    'Off Track',
#    'A Film by Aravind',
#    'The Golden Rabbit',
#    'Billu',
#    'Rudraksh',
#    'Dredd',
#    'The Emerald Forest',
#    'Camp Sawi',
#    "Blackbeard's Ghost",
#    'Padma Nadir Majhi',
#    'Curdled',
#    'The Invisible Man Returns',
#    "OOO, Den-O, All Riders: Let's Go Kamen Riders",
#    'My Man and I',
#    'Rocket',
#    'The Iron Lady',
#    ' Rachel Getting Married',
#    'Daughters of Pharmacist Kim',
#    'The Boxer',
#    'Melody Cruise',
#    'Laugh, Clown, Laugh',
#    'Eighteen Springs',
#    'Vasanthi',
#    'Chhupa Rustam',
#    'Star',
#    'The Great Impostor',
#    'Passport to Pimlico',
#    'Polytechnique',
#    'Joe Smith, American',
#    'The Bottom of the Bottle',
#    'Karla',
#    'The Producers',
#    'Quantez',
#    'Femme Fatale, Jang Hee-bin Yohwa, Jang Hee-bin',
#    'Ragasiya Police 115',
#    'Vijayalakshmi',
#    'The Bunker',
#    'Reform School Girl',
#    'The Teckman Mystery',
#    'Vanakkam Thalaiva',
#    'When Night Is Falling',
#    'Summer of the Seventeenth Doll',
#    'One Night in Supermarket',
#    'Sailor Moon S: The Movie',
#    'The Mind of Mr. Soames',
#    'The War',
#    'Hunt the Man Down',
#    'Chef',
#    'The Philadelphia Story',
#    'The Three Weird Sisters',
#    'Host, TheThe Host',
#    'The Gay Desperado',
#    'Soldier of Fortune',
#    'Mr. Lambu',
#    'The Cisco Kid and the Lady',
#    'Loophole',
#    'Jaffa',
#    'Jeepers Creepers',
#    'Afterschool Midnighters',
#    'Ocean Heaven',
#    'Sant Sakhu',
#    'Room No.7',
#    'Alias Boston Blackie',
#    'Mouse Cleaning',
#    "What to Expect When You're Expecting",
#    'Pudhu Vazhvu',
#    'Chinna Pulla',
#    'Ezhu Sundara Rathrikal',
#    'Alien Autopsy',
#    'Eastern Promises',
#    'Weddings and Babies',
#    'The Steel Jungle',
#    'Manpower',
#    'Athithi',
#    'You Never Can Tell',
#    "Der Fuehrer's Face",
#    'Paradise Kiss',
#    'Blackbird',
#    'Daniel Boone, Trail Blazer',
#    'Blonde Fever',
#    'A Very Long Engagement',
#    'Ali and Nino',
#    'The Devil-Doll',
#    'Men with Brooms',
#    'Ex with Benefits',
#    'Ahista Ahista',
#    'Gurinder Chadha',
#    'Pourudu',
#    'Ring of Bright Water',
#    'The Good Son',
#    'Kaaka Muttai',
#    'Faraar a.k.a. Dev Anand in Goa',
#    'A Man to Remember',
#    'Kansas City Bomber',
#    'Manhattan Murder Mystery',
#    'Santa Claws',
#    'Vasantha Maligai',
#    'The State Counsellor',
#    'Hellions',
#    'Rhythm on the River',
#    'Incredible Burt Wonderstone, TheThe Incredible Burt Wonderstone',
#    'Indianapolis Speedway',
#    'Take a Letter, Darling',
#    'Three Businessmen',
#    'Rimfire',
#    'Lord of Tears',
#    'Lonesome Dove',
#    'Into the White Night',
#    'Castle Keep',
#    'A Kid from Tibet',
#    'Amara Shilpi Jakkanna',
#    'So This Is Paris',
#    'Nakhuda',
#    'A Funny Thing Happened on the Way to the Forum',
#    'Labor Day',
#    'Double Bunk',
#    'The Super Dimension Fortress Macross: Do You Remember Love?',
#    'Pattiyude Divasam',
#    'Two Sisters',
#    'Black Limelight',
#    '7 October',
#    'The Parent Trap',
#    'Pokkisham',
#    'Kalabha Kadhalan',
#    'Iron & Silk',
#    'Sarkari Mehmaan',
#    "Bulldog Drummond's Peril",
#    'New York, New York',
#    'The Birds and the Bees',
#    'The Man Who Cheated Himself',
#    'Ginger Snaps 2: Unleashed',
#    'Shhh!',
#    'Scooby-Doo and the Ghoul School',
#    'The Painted Desert',
#    "Who's the Man?",
#    'The Black Prince',
#    'Crow Hollow',
#    'The Virginian',
#    'Miami Expose',
#    'Barricade',
#    'Ab-Normal Beauty',
#    ' X2: X-Men United',
#    'Caught in Trap',
#    'Corrections Class',
#    'Rebel in Town',
#    'Pattaya Kelappanum Pandiya',
#    'Anbu Thozhi',
#    'The Alligator People',
#    'The Wicker Tree',
#    'Saw VII',
#    "We Can't Have Everything",
#    'Toofan',
#    'A Better Life',
#    'Storm Over the Nile',
#    'Kavacham',
#    'Birdman of Alcatraz',
#    'From up on Poppy Hill',
#    'Flipped',
#    "Hitler's Children",
#    'Scruples',
#    'Gejje Pooje',
#    'The Beloved',
#    'The Ruling Class',
#    'Cowboy Counsellor',
#    'Fried Green Tomatoes',
#    'Balgandharva',
#    ...]),
#  ('bartender',
#   ['Whale Music',
#    'Prelude to a Kiss',
#    'People Like Us',
#    'Black Rage',
#    'Side Street',
#    "Bébé's Kids",
#    'Fighting Back',
#    ' I Can Do Bad All By Myself',
#    'The Linguini Incident',
#    'Running Target',
#    'Fire Down Below',
#    '48 Hrs.',
#    'Choose Me',
#    'Rage at Dawn',
#    'Evelyn',
#    'The MatchMaker',
#    'Coast to Coast',
#    'Gone Baby Gone',
#    'Coyote Ugly',
#    'Crazy in Alabama',
#    'The Boondock Saints II: All Saints Day',
#    'Hurricane Streets',
#    '200 Cigarettes',
#    'Tell No Tales',
#    'Miss You Already',
#    'The Lost Weekend',
#    'Invincible',
#    "Chato's Land",
#    'Blues Harp',
#    'Dogfight',
#    'Finders Keepers, Lovers Weepers!',
#    'Randy Rides Alone',
#    'The Banger Sisters',
#    'Fritz the Cat',
#    'Three Blind Mice',
#    "That's My Boy",
#    'The Shootist',
#    "Tough Guys Don't Dance",
#    'How to Be Single',
#    'Kansas Saloon Smashers',
#    'The Way of All Men',
#    'Burglar',
#    'The Matchmaker',
#    'The Man Who Died Twice',
#    'In This Our Life',
#    'Ruby',
#    'The Thirteenth Floor',
#    'Out West',
#    'China Moon',
#    'Broadway Limited',
#    ' Keeping the Faith',
#    'The Fighter',
#    'Vice',
#    'The Big Parade',
#    'Mad Dog and Glory',
#    'Supervixens',
#    'Bungalow 13',
#    '88 Antop Hill',
#    'Barfly',
#    'Cafe Society',
#    'The Man with a Cloak',
#    'The Sin of Harold Diddlebock',
#    'What Happens in Vegas',
#    'Springtime in the Rockies',
#    'Easter Parade',
#    'Harper Valley PTA',
#    'Tom at the Farm (Tom à la ferme)',
#    'Ten Cents a Dance',
#    'The Killing',
#    'Inbred',
#    'Belly',
#    'Roxanne',
#    'Anatomy of a Murder',
#    'Bruce Lee and I',
#    'Rocky Balboa',
#    'Predestination',
#    'A Walk Among the Tombstones',
#    'The Last 5 Years',
#    'Parting Shots',
#    'The Walking Hills',
#    'The Nutty Professor',
#    'McQ',
#    '4',
#    'Scorchers',
#    'Ride Beyond Vengeance',
#    'Win Win',
#    'Joe',
#    'Cocktail',
#    'Sunshine on Leith',
#    'Kajraare',
#    'Rio Bravo',
#    'Little City',
#    '54',
#    'Blues Brothers 2000',
#    'The Hot Chick',
#    'Letters to God',
#    'One Way Passage',
#    "Hell on Devil's Island",
#    'Jet Over the Atlantic',
#    'Aftershock',
#    'Nurse Betty',
#    'Heartbreakers',
#    "Bert Rigby, You're a Fool",
#    'Mr. Destiny',
#    'Miracles',
#    'Love Fiction',
#    'Memento',
#    'Paradise',
#    'The Indian Runner',
#    'Snowball Express',
#    'Heavy Traffic',
#    'Wrongfully Accused',
#    'Bonanza Bunny',
#    'CrissCross',
#    'Just Write',
#    'The Shining',
#    'Silver Bullet',
#    'Blood Simple',
#    'Boys on the Side',
#    'Face',
#    'Phantom Lady',
#    'Lucky Them',
#    'The Snows of Kilimanjaro',
#    '10',
#    'The Hurricane',
#    'Green Room',
#    'Without Orders',
#    'Full Grown Men',
#    'I Still Know What You Did Last Summer',
#    'The Mouthpiece',
#    'Hysterical Blindness',
#    'Despicable Me 3',
#    'Just Friends',
#    'Omega Doom',
#    'Walk of Shame',
#    'The Big Kahuna',
#    'Born to the West',
#    'She-Devils on Wheels',
#    'Star Trek Generations',
#    'Going the Distance',
#    'The Guest',
#    'The Ref',
#    'Tales of Terror',
#    ' Waiting...',
#    'Sex, Lies, and Videotape',
#    "The World's End",
#    'Double Jeopardy',
#    'Strawberry Cliff',
#    'French Connection II',
#    'Amarilly of Clothes-Line Alley',
#    'The Quest',
#    'For Colored Girls',
#    'Eating Out 5: The Open Weekend',
#    'The Great McGinty',
#    'Sex and the City 2',
#    'Restaurant',
#    'Out of the Furnace',
#    'Honey',
#    'Frankie and Alice',
#    'Miracle in the Rain',
#    'Secret Life of Walter Mitty, TheThe Secret Life of Walter Mitty',
#    'The Pledge',
#    'Blackjack',
#    'Rock All Night',
#    'My Bloody Valentine',
#    'Prefontaine',
#    'All Ashore']),
#  ('is',
#   ['Alex & Emma',
#    'Strip Tease Murder',
#    'Carry on Jatta',
#    'Shrieker',
#    'Everything Is Illuminated',
#    'The Attorney',
#    'Sthalathe Pradhana Payyans',
#    'A Cold Wind in August',
#    'Margot at the Wedding',
#    'En Sakhiye',
#    'Ghosts',
#    'Fool Coverage',
#    'The Inner Circle',
#    'The Pompatus of Love',
#    'Dhaai Akshar Prem Ke',
#    "A Dog's Purpose",
#    'Flaming Brothers',
#    'Damadamm!',
#    "Just Another Pandora's Box",
#    'Dog Pound',
#    'Kanni Thaai',
#    'On the Town',
#    'The Legend of Qin',
#    'Star Trek VI: The Undiscovered Country',
#    'Ami Aaj Nasto Hoye Jai',
#    'Bhagyadevatha (ഭാഗ്യദേവത)',
#    'Hell in the Pacific',
#    'Virginia',
#    'Christmas with the Dead',
#    'Nuvvostanante Nenoddantana',
#    'Center Stage',
#    "There's One Born Every Minute",
#    'Ali',
#    'I Love You, Man',
#    'Star!',
#    'Goal!',
#    'Cry for Happy',
#    'Texas Across the River',
#    'The Butcher, the Chef and the Swordsman',
#    'Resistance',
#    'Kondaveeti Raja',
#    'Night Passage',
#    'What Happens in Vegas',
#    'A King in New York',
#    'Vedam',
#    'Memories in March',
#    'Rudolph the Red-Nosed Reindeer: The Movie',
#    'Singham Returns',
#    'The Cardinal',
#    'The NeverEnding Story II: The Next Chapter',
#    'Leprechaun',
#    'Latitude 55°',
#    'Love and Bullets',
#    'MCA (Middle Class Abbayi)',
#    'Sendhoorapandi',
#    "Taming Sutton's Gal",
#    'Valley Girl',
#    'The Chocolate Soldier',
#    'Chetna',
#    'Decoding Annie Parker',
#    'Desiya Geetham',
#    'Enlighten Thy Daughter',
#    'Bazi',
#    'Fox Terror',
#    'Jet Pilot',
#    'Plunder Road',
#    'Zor',
#    'Fallen',
#    'Hyde and Hare',
#    'Naina',
#    'Day Watch',
#    'California Split',
#    'A Shot at Glory',
#    'Female Prisoner #701: Scorpion',
#    'The Resistance',
#    'Godzilla vs. King Ghidorah',
#    'Cat-Tails for Two',
#    'Mere Oblivion',
#    'Miss Robin Crusoe',
#    'October Sky',
#    'Ayee Milan Ki Bela',
#    'Larceny, Inc.',
#    'The Big Pond',
#    "I've Heard the Mermaids Singing",
#    'Oru Vadakkan Selfie',
#    'Repeaters',
#    'Stuck',
#    'Cardcaptor Sakura Movie 2: The Sealed Card',
#    'Miley Naa Miley Hum',
#    'Bella',
#    'Flying Tigers',
#    'Cross-Country Romance',
#    'Narsimha',
#    'Godzilla vs. Hedorah',
#    'Permanent Record',
#    'The Naked Jungle',
#    'The Accused',
#    'Paris',
#    'Jhootha Hi Sahi',
#    'Five-Year Engagement, TheThe Five-Year Engagement',
#    'The Falcon and the Co-eds',
#    'Requiem for a Handsome Bastard (Requiem pour un beau sans-coeur)',
#    ' Dish, TheThe Dish',
#    'The Caterpillar Wish',
#    'Kathputli',
#    'Calling Homicide',
#    'The Fifth Estate',
#    'Sivappu Mazhai',
#    'Panic Room',
#    'Hollywood',
#    "6'2",
#    'Fall Time',
#    'Rhythm and Weep',
#    '27 Down',
#    ' On Line',
#    'Go',
#    'Veer',
#    'New Orleans Uncensored',
#    'The Evil of Frankenstein',
#    'Only Lovers Left Alive',
#    'The Oogieloves in the Big Balloon Adventure',
#    'Prison on Fire',
#    'The Scarlet Pimpernel',
#    'Pataal Bhairavi',
#    'The Wind and the Lion',
#    'Tamayura 3',
#    'Heaven and Earth',
#    'Mansfield Park',
#    'Lovely',
#    'The Sky Pilot',
#    'My Gun Is Quick',
#    'The Wizard of Gore',
#    'Gangs of Wasseypur – Part 2',
#    'Navdeep, Santhoshi, Ayesha Jhulka',
#    'Bodyguards and Assassins',
#    'The Mini-Affair',
#    'Nice Women',
#    'The Night We Called it a Day',
#    'The Long and the Short and the Tall',
#    'Snow Flower and the Secret Fan',
#    '3 Ninjas',
#    'Quintet',
#    'Rag Doll',
#    'Balarama Krishnulu',
#    'Pedro Calungsod: Batang Martir',
#    'Volcano',
#    'Mayangaathey',
#    'Abe Lincoln in Illinois',
#    'Nila Penne',
#    'Ed Wood',
#    'Munthirivallikal Thalirkkumbol',
#    'Pan',
#    'Armaan',
#    'Enigma',
#    'LIE',
#    'Me and You and Everyone We Know',
#    'The Last Days of Pompeii',
#    'You Came Along',
#    'Oru Vidukadhai Oru Thodarkadhai',
#    "Sophie's Choice",
#    'Dutiful But Dumb',
#    'Backlash',
#    'Superstar: The Karen Carpenter Story',
#    ' The Tao of Steve',
#    'Gandeevam',
#    'Kiss Me Deadly',
#    'Deewangee',
#    "Dr. Gillespie's Criminal Case",
#    'Shin Godzilla',
#    'Pudhu Pudhu Arthangal',
#    'A Beautiful Mind',
#    'Sarvam ',
#    'Tales from the Crypt',
#    'The Games Maker',
#    'Superstar',
#    'Bangaarada Hoovu',
#    'Daughter of Don Q',
#    'Ek Baar Chale Aao',
#    'The Little Minister',
#    'Geethaanjali',
#    'The Final Test',
#    'Dark Star',
#    'Christmas Child',
#    'Caught Up',
#    'Sweet Sixteen',
#    'The Lost Bladesman',
#    'Prabhuvinte Makkal (പ്രഭുവിന്റെ മക്കൾ)',
#    'Doppelganger',
#    'Song of the Thin Man',
#    'The Knack …and How to Get It',
#    'All That Jazz',
#    'Bheegi Palkein',
#    'Khadgam',
#    'My Last Five Girlfriends',
#    "Don't Bet on Women",
#    'Juwanna Mann',
#    'Shadow Conspiracy',
#    'Some Kind of Wonderful',
#    'Bunshinsaba 2',
#    'Rare Birds',
#    'No Orchids for Miss Blandish',
#    'Hard Rain',
#    'Son of a Gun',
#    'Thambi Vettothi Sundaram',
#    'Shaolin Wooden Men',
#    'Sssshhh...',
#    'Teachers',
#    'Some Kind of Hero',
#    'The Yellow Mountain',
#    'Book Thief, TheThe Book Thief',
#    'Anantha Poongathe',
#    'Step Down to Terror',
#    'Four Wives',
#    'Thenali Raman',
#    'Flight Nurse',
#    'Double Harness',
#    '9 KK Road',
#    'Man in the Middle',
#    ' Ratatouille',
#    'Aadmi Sadak Ka',
#    'Header',
#    'The Sound of Fury',
#    'Nefes: Vatan Sağolsun',
#    'Silver Bullet',
#    'The Ghost and Mrs. Muir',
#    'Underworld: Awakening',
#    'The Secret Invasion',
#    'Rambo',
#    'Together',
#    'Cocoon: The Return',
#    'The Ruins',
#    'Bran Nue Dae',
#    'En Veedu',
#    'Most Wanted',
#    'Tick Tock Tuckered',
#    'Rhino!',
#    'Sangili',
#    'Stork',
#    'The Nightmare Before Christmas',
#    'Stand By for Action',
#    'Silambarasan, Divya Spandana, Kalabhavan Mani',
#    "Hell's Heroes",
#    'I Dood It',
#    'Seven Swords',
#    'Endrendrum Punnagai',
#    'About Time',
#    'Bhairav',
#    '25',
#    'Hangover Part III, TheThe Hangover Part III',
#    'Singeetam Srinivasa Rao',
#    'Apna Sapna Money Money',
#    'Tip on a Dead Jockey',
#    'Angrej',
#    'Dalapathi',
#    'Nimirndhu Nil',
#    'Haseena Parkar',
#    'Takers',
#    'The Glass Mountain',
#    'Diplomatic Courier',
#    'Having Wonderful Time',
#    'Laurence Anyways',
#    'Elena',
#    'Mystic River',
#    'Amanush',
#    'Indra En Selvam',
#    'The Girl Who Came Late (aka Daydream Believer)',
#    'The Barefoot Mailman',
#    'Sairat',
#    'The Speckled Band',
#    'The Big Lift',
#    'Insaaf Kaun Karega',
#    'Beach Red',
#    "Dr. O'Dowd",
#    'Pelli Sandadi',
#    'Spanglish',
#    'Joggers Park',
#    "The Man from Blankley's",
#    'Lone Wolf and Cub: Baby Cart in Peril',
#    ' Mehndi Waley Hath',
#    'Sergeant Deadhead',
#    'Wired',
#    'No Way to Treat a Lady',
#    'Kusthi',
#    'The Great Escape',
#    'International Lady',
#    'Crooked Business',
#    'Bad Moon',
#    'Lady Snowblood: Love Song of Vengeance',
#    'Falling Down',
#    'Limitless',
#    'Electric Shadows',
#    'The Indian in the Cupboard',
#    'Collector',
#    'Super Nani',
#    'The Docks of New York',
#    'Puppet Master II',
#    'Fierce Creatures',
#    'The Divided Heart',
#    'The Last Producer',
#    'Target Zero',
#    'Meaghamann',
#    'Paradesi',
#    'Confessions of a Dangerous Mind',
#    'Madatha Kaja',
#    'Veettuku Veedu',
#    'Take Away',
#    "Mama's Affair",
#    'Muddula Koduku',
#    'Rango',
#    'Manasulo Maata',
#    'Love Potion No. 9',
#    'I Was a Teenage Werewolf',
#    'Akaash Vani',
#    'Dirty Rotten Scoundrels',
#    'Raggedy Ann & Andy: A Musical Adventure',
#    'Is There a Doctor in the Mouse?',
#    'Carry On Girls',
#    'Getting Straight',
#    'Nightmare Alley',
#    'The Secret Life of an American Wife',
#    "Breakin'",
#    'Janice Meredith',
#    'The Fox Lover',
#    'Kadavul',
#    'Dizzy Detectives',
#    ' The Haunted Mansion',
#    '22 Jump Street',
#    'Moner Manush (film)',
#    'Miracle in Harlem',
#    'Million Dollar Mystery',
#    'My Flesh and Blood',
#    'Ashta Chamma',
#    'Samudhiram',
#    'Every Which Way but Loose',
#    'The Rocks of Valpre',
#    'Solid Geometry',
#    'Mister Roberts',
#    'The Great Waldo Pepper',
#    'Patrani',
#    'Zindagi Na Milegi Dobara',
#    'The Hoodlum Saint',
#    'Nancy Goes to Rio',
#    'Ride Out for Revenge',
#    'Angel Baby',
#    "So's Your Aunt Emma",
#    "Badman's Territory",
#    'Sindhu Bhairavi',
#    "I'm Dancing as Fast as I Can",
#    'Red Kingdom Rising',
#    'Tarzan and the Valley of Gold',
#    'The Corruptor',
#    'Q Planes',
#    'House of 1000 Corpses',
#    'Ek Thi Ladki',
#    'Tarana',
#    'Such Good Friends',
#    'Paradise Alley',
#    'Road to Perdition',
#    'Innathe Chintha Vishayam',
#    'Radar Men from the Moon',
#    'Gentle Strangers',
#    'Retro Puppet Master',
#    'Tiyaan',
#    'The Riddle',
#    'The Mortal Instruments: City of Bones',
#    'Romie-0 and Julie-8',
#    'Wild Horse Hank',
#    'Avan Ivan',
#    'Flipper',
#    'Mirch',
#    'Oru Murai Vanthu Parthaya',
#    'So Proudly We Hail!',
#    'Manal Kayiru',
#    'Out of Africa',
#    'Achchani',
#    "The Warrior's Husband",
#    'Stander',
#    'White Reindeer',
#    '123',
#    'Arcadia',
#    'Fireworks, Should We See It from the Side or the Bottom? and Raving Jeff’s Stronger Battle',
#    'Minna no Ie',
#    'Daivathinte Swantham Cleetus',
#    'Animal Farm',
#    'Best Foot Forward',
#    "Comin' Round the Mountain",
#    'Blood Brothers',
#    'Sweet Home',
#    'Penthouse',
#    'Quest for Camelot',
#    'Sawan Aya Re',
#    'Night Tide',
#    'The Jokers',
#    'Cabin in the Sky',
#    'Holy Man',
#    'Doctor in the House',
#    'Bel Ami',
#    '29th Street',
#    "One Night at McCool's",
#    'Johnny Come Lately',
#    'Sam and Me',
#    'Peddamanushulu',
#    'Far from Home: The Adventures of Yellow Dog',
#    'The War Lord',
#    'Shaun of the Dead',
#    'Birdcage Inn',
#    'Addams Family Values',
#    'Fragment of Fear',
#    ' Waist Deep',
#    'Dastaan',
#    'Makalkku',
#    'Dil Hi Dil Mein',
#    'In the Meantime, Darling',
#    'Capote',
#    'The Flintstones',
#    'Godzilla: Final Wars',
#    'Soul Men',
#    'Breaking Wind',
#    'Spandana',
#    'Bunny',
#    'Ruby Gentry',
#    'The Lost Tribe',
#    '12 Rounds 2: Reloaded',
#    'That Brennan Girl',
#    "Teacher's Pet",
#    'Dehorokkhi: The Bodyguard',
#    'Raise the Red Lantern',
#    'From Riches to Rags',
#    'The Tune',
#    'Asteroid',
#    'Sit Tight',
#    'Nartanasala',
#    'Never Say Die',
#    'Out of True',
#    'Thanga Padhumai',
#    'Yokomichi Yonosuke',
#    'Tuck Everlasting',
#    'Akasha Gopuram',
#    'Pasa Kiligal',
#    'Pen Singam',
#    'Yugpurush',
#    'Gone',
#    'Those Redheads from Seattle',
#    'The Bed-Sitting Room',
#    'Picture Perfect',
#    'The Hi-Jackers',
#    'Manikya Kallu (മാണിക്യക്കല്ല്)',
#    'Chamak',
#    'Jebu Donga',
#    'Sitting Pretty',
#    'David',
#    'Runningshaadi.com',
#    'Hoovu Hannu',
#    'When Time Ran Out',
#    'Shadowboxing 3: Last Round',
#    'Here Comes Fortune',
#    'Neighbors',
#    'The Prisoner of Shark Island',
#    'Inside the Walls of Folsom Prison',
#    'Kathakali',
#    'Chances Are',
#    "Days of Darkness (L'Âge des ténèbres)",
#    'Dhosth',
#    'Those Magnificent Men in their Flying Machines',
#    'Welcome to Sarajevo',
#    'Athisaya Thirudan',
#    'Supernova',
#    'The Sun Sets at Dawn',
#    'The Mating Call',
#    'Duplicity',
#    'Freighters of Destiny',
#    'The Wild',
#    'The Adventurous Blonde',
#    'Blair Witch',
#    'Confessions of Boston Blackie',
#    'War for the Planet of the Apes',
#    'These Wilder Years',
#    'In Old Oklahoma',
#    'Maanasaandarapetta Yezdi',
#    'Gumnaam',
#    'Nongjungjo',
#    'The Dawns Here Are Quiet',
#    'Carolina Moon',
#    'Kakera: A Piece of Our Life',
#    'Periya Thambi',
#    "A Woman's Face",
#    'Mr. India',
#    'Corridors of Blood',
#    'Part Time Wife',
#    'Flavours',
#    'Pondatti Thevai',
#    'Counsel for Crime',
#    'Fast Break',
#    'Milan',
#    'What If...',
#    'Iti Srikanto',
#    'Hedwig and the Angry Inch',
#    'The Greatest Game Ever Played',
#    'Thodasa Roomani Ho Jaayen',
#    'She Married a Cop',
#    'Corpse Party',
#    'Gunaah',
#    'Time Bomb',
#    'Jaws: The Revenge',
#    'Gabriel Over the White House',
#    ' Yours, Mine and Ours',
#    'The Girl Said No',
#    'Naan Sigappu Manithan',
#    'Oozham',
#    'Avengers of the Reef',
#    'Pushing Tin',
#    'Clash of the Titans',
#    'This Is My Father',
#    'Parayam',
#    'Young Soul Rebels',
#    'Desam',
#    'Time Table',
#    'Another Day in Paradise',
#    'Siragadikka Aasai',
#    "Guess Who's Coming to Dinner",
#    'Heavy Metal 2000',
#    'The Glass Cage',
#    'Charlie Chan in Panama',
#    'The Girl with the Dragon Tattoo',
#    'Jhinder Bandi',
#    'Always Be With You',
#    'Ambassador Bill',
#    'The Life and Death of Colonel Blimp',
#    'Ambuli',
#    'Boni',
#    'Pakarnnattam (പകർന്നാട്ടം)',
#    'Small Town Story',
#    'The Bitch',
#    'Red Cliff: Episode 2',
#    'Kuch Khatti Kuch Meethi',
#    'The Cars That Ate Paris',
#    'The Wall',
#    'Last Embrace',
#    'Children of the Corn',
#    'Bye Bye Braverman',
#    'Rihaee',
#    'Three Who Loved',
#    'Criminals of the Air',
#    'Baby Take a Bow',
#    'He Married His Wife',
#    "Yes Sir, That's My Baby",
#    'The Doctor',
#    'Let Me Out',
#    'Kanni Rasi',
#    'Sorry Baby',
#    'Savithriyude Aranjanam',
#    'Whistle Blower',
#    'Aces High',
#    'The Phantom Rider',
#    'Edward II',
#    'Cantonen Iron Kung Fu',
#    'Beverly Hills Cop III',
#    'First Kid',
#    'Yuvaraja',
#    'Elvis & Nixon',
#    'Arie',
#    'Mammy',
#    "Who's Minding the Store?",
#    'Bhram',
#    'Pudhu Padagan',
#    'Imitation of Life',
#    'Murari',
#    'Through the Back Door',
#    'Darkness Falls',
#    "Nobody's Perfect",
#    'Moscow on the Hudson',
#    'Lured',
#    'Time Is My Enemy',
#    'Stone of Destiny',
#    'Wolfman',
#    'CZ12',
#    'Bad Moms',
#    'The Last Days on Mars',
#    'Beverly Hills Ninja',
#    'Three Strangers',
#    'Peddannayya',
#    'Adventures of Zatoichi',
#    'The Mark',
#    'Queen of the Mob',
#    'The Love Light',
#    'Oru Odai Nadhiyagirathu',
#    'Happy Though Married',
#    'Brother of Bommali',
#    'Mudhal Kanave',
#    'Interlude',
#    'Megha',
#    'Solaris',
#    'Deranged',
#    'Seerivarum Kaalai',
#    'The Circle',
#    'In Name Only',
#    'Blackjack',
#    'Red Light',
#    'Manju Poloru Penkutty',
#    'Idlewild',
#    'From Hell It Came',
#    'The Blue Butterfly',
#    'The Woman in Green',
#    'One Dangerous Night',
#    'Manoranjan',
#    'Take Me Home Tonight',
#    'The Matrix Revolutions',
#    'The Oscar',
#    'Ugly',
#    "River's End",
#    'One More Tomorrow',
#    'There Will Be Blood',
#    'Ippadai Vellum',
#    'Lust in the Dust',
#    'Kalangarai Vilakkam',
#    'Urumi',
#    'The Redhead from Wyoming',
#    'That Lady from Peking',
#    'No Holds Barred',
#    'The Man from U.N.C.L.E.',
#    'Chandrahasa',
#    'Nagasaki: Memories of My Son',
#    'Flying Disc Man from Mars',
#    'Escape Me Never',
#    'I Think I Love My Wife',
#    'Third Person',
#    '99',
#    'The Domino Principle',
#    'Sharapanjara',
#    'Man of Will',
#    'Paddington 2',
#    'Anchorman 2: The Legend Continues',
#    'Passkey to Danger',
#    'Maw`ed Ma` al-Hayat (Appointment with Life)',
#    'The Road to Reno',
#    'My Summer Story',
#    'Josephine and Men',
#    'Akhil',
#    'Hell Is a City',
#    'Border Incident',
#    'Crooked House',
#    'The Case for the Crown',
#    'Pyar Ka Mausam',
#    'Married and in Love',
#    'Alone with Her',
#    'The High Powered Rifle',
#    'Free Jimmy',
#    'Vampire Circus',
#    'Brotherhood of Blood',
#    'The Creeping Terror',
#    'The Way',
#    'Yodha',
#    'Salt',
#    'Company Business',
#    'The Black Pirate',
#    'Men in Her Life',
#    'Battle Cry',
#    'Love Breakups Zindagi',
#    'The Architect',
#    'Gamyam',
#    'Rome Adventure',
#    'Cowboys & Aliens',
#    'Lords of Dogtown',
#    'Fred Claus',
#    'Raging Bull',
#    'The Rise and Fall of a White Collar Hooligan',
#    "Hey Good Lookin'",
#    'Varasudu',
#    'Daaku Aur Jawan',
#    'First Yank into Tokyo',
#    'One for the Money',
#    'Modesty Blaise',
#    'Sleepy-Time Tom',
#    'Free Birds',
#    'Career Opportunities',
#    'Protégé',
#    'Freebie and the Bean',
#    "Wes Craven's New Nightmare",
#    'National Treasure',
#    'Madhumati',
#    'When I Fall in Love... with Both',
#    'Ribbit',
#    'The Inn of the Sixth Happiness',
#    'Pookari',
#    'Live Wire',
#    'The Impassive Footman',
#    'The Firefly',
#    'The Lawless Breed',
#    'Heneral Luna',
#    'Encounters of the Spooky Kind',
#    'Devatha',
#    ' Racing Stripes',
#    'Planes, Trains and Automobiles',
#    'Easy Come, Easy Go',
#    'Pisau Cukur',
#    'Confession',
#    'The Red Mill',
#    'Natarang',
#    'Nenjil Jil Jil',
#    'Invisible Target',
#    'Rabb Da Radio',
#    'Girls at Sea',
#    'Messiah of Evil aka Dead People',
#    'Butch and Sundance: The Early Days',
#    'Mean Creek',
#    'All Saints',
#    'Righting Wrongs',
#    'Me and the Colonel',
#    'The Dark Mirror',
#    'Go, Go Second Time Virgin',
#    'The Devil Is Driving',
#    'Naan Kadavul ',
#    'Ammakkilikkoodu',
#    'Bloodfist II',
#    'Woman in the Dunes',
#    'Legend of a Fighter',
#    'Chungking Express',
#    'Ondrupattal Undu Vazhvu',
#    'The Squaw Man',
#    'Mommo',
#    'Hot Rod',
#    'The Angry Birds Movie',
#    'Mughal-e-Azam (Colorized Version)',
#    'Dr. Plonk',
#    'Mylanchi Monchulla Veedu',
#    'Night of the Living Dead',
#    'The Boys Next Door',
#    'The Best Years',
#    'Captain Nemo and the Underwater City',
#    'Seven Days to Noon',
#    'Ironweed',
#    'Ice Cream',
#    'A Gunfight',
#    'The Last Tycoon',
#    'The Falcon in Mexico',
#    'Ninaithale',
#    'Paadam Onnu: Oru Vilapam',
#    'The Blood of Jesus',
#    'Indecent Proposal',
#    'Nee Kosam',
#    'Sachin: A Billion Dreams',
#    'The Family Jewels',
#    'Revenge of the Creature',
#    'Lord of the Flies',
#    'Outrage Coda',
#    ' Yogi Bear',
#    'Kanchana 2',
#    'Breezy',
#    'The Life Aquatic with Steve Zissou',
#    'Holy Matrimony',
#    'Kurukshetram',
#    'The Girl from Missouri',
#    'The Gulf Between',
#    'Jack Frost',
#    'Anbe Deivam',
#    'Deception',
#    'Undercover',
#    'Police Academy 3: Back in Training',
#    'Primeval',
#    'The Kingdom',
#    'Suite Française',
#    'Solo',
#    'The Wind That Shakes the Barley',
#    'Niram Maaratha Pookkal',
#    'The Thief',
#    'Line Walker',
#    'Adhe Kangal',
#    'The Wild Geese',
#    'Moon 44',
#    'And One Was Beautiful',
#    'Meshes of the Afternoon',
#    'Kajraare',
#    'Steamboat Bill, Jr.',
#    'City Slickers',
#    'Thomas & the Magic Railroad',
#    'The Little Kidnappers',
#    'Among Giants',
#    'Playing the Victim',
#    'Vichitra Kutumbam',
#    'Yuvaraju',
#    'Woman in Hiding',
#    'Summertree',
#    'The Long Goodbye',
#    'Don Seenu',
#    'Tale in the Darkness',
#    'Off Track',
#    'A Film by Aravind',
#    'Billu',
#    'Rudraksh',
#    'Dredd',
#    'The Emerald Forest',
#    "Blackbeard's Ghost",
#    'Padma Nadir Majhi',
#    'Curdled',
#    'The Invisible Man Returns',
#    "OOO, Den-O, All Riders: Let's Go Kamen Riders",
#    'My Man and I',
#    'Rocket',
#    'The Iron Lady',
#    ' Rachel Getting Married',
#    'The Boxer',
#    'Melody Cruise',
#    'Laugh, Clown, Laugh',
#    'Eighteen Springs',
#    'Chhupa Rustam',
#    'The 11th Hour',
#    'Star',
#    'The Great Impostor',
#    'Passport to Pimlico',
#    'Polytechnique',
#    'Joe Smith, American',
#    'The Bottom of the Bottle',
#    'Karla',
#    'The Producers',
#    'Quantez',
#    'Femme Fatale, Jang Hee-bin Yohwa, Jang Hee-bin',
#    'Ragasiya Police 115',
#    'The Bunker',
#    'Reform School Girl',
#    'Vanakkam Thalaiva',
#    'When Night Is Falling',
#    'Summer of the Seventeenth Doll',
#    'One Night in Supermarket',
#    'Sailor Moon S: The Movie',
#    'The Mind of Mr. Soames',
#    'The War',
#    'Hunt the Man Down',
#    'Chef',
#    'The Philadelphia Story',
#    'The Three Weird Sisters',
#    'Host, TheThe Host',
#    'The Gay Desperado',
#    'Soldier of Fortune',
#    'Mr. Lambu',
#    'The Cisco Kid and the Lady',
#    'Loophole',
#    'Jaffa',
#    'Jeepers Creepers',
#    'Afterschool Midnighters',
#    'Ocean Heaven',
#    'Sant Sakhu',
#    'Room No.7',
#    'Alias Boston Blackie',
#    'Mouse Cleaning',
#    "What to Expect When You're Expecting",
#    'Pudhu Vazhvu',
#    'Chinna Pulla',
#    'Ezhu Sundara Rathrikal',
#    'Alien Autopsy',
#    'Eastern Promises',
#    'Weddings and Babies',
#    'The Steel Jungle',
#    'Manpower',
#    'Athithi',
#    'You Never Can Tell',
#    "Der Fuehrer's Face",
#    'Paradise Kiss',
#    'Blackbird',
#    'Daniel Boone, Trail Blazer',
#    'Blonde Fever',
#    'A Very Long Engagement',
#    'Tripfall',
#    'Ali and Nino',
#    'The Devil-Doll',
#    'Men with Brooms',
#    'Ex with Benefits',
#    'Ahista Ahista',
#    'Gurinder Chadha',
#    'Pourudu',
#    'Ring of Bright Water',
#    'The Good Son',
#    'Kaaka Muttai',
#    'Faraar a.k.a. Dev Anand in Goa',
#    'A Man to Remember',
#    'Kansas City Bomber',
#    'Manhattan Murder Mystery',
#    'Santa Claws',
#    'Vasantha Maligai',
#    'The State Counsellor',
#    'Hellions',
#    'Rhythm on the River',
#    'Incredible Burt Wonderstone, TheThe Incredible Burt Wonderstone',
#    'Indianapolis Speedway',
#    'Rimfire',
#    'Lord of Tears',
#    'Nirbhay',
#    'Lonesome Dove',
#    'Into the White Night',
#    'Castle Keep',
#    'A Kid from Tibet',
#    'Amara Shilpi Jakkanna',
#    'So This Is Paris',
#    'A Funny Thing Happened on the Way to the Forum',
#    'Labor Day',
#    'Double Bunk',
#    'The Super Dimension Fortress Macross: Do You Remember Love?',
#    'Pattiyude Divasam',
#    'Two Sisters',
#    'Black Limelight',
#    '7 October',
#    'The Parent Trap',
#    'A Time to Remember',
#    'Pokkisham',
#    'Kalabha Kadhalan',
#    'Sarkari Mehmaan',
#    "Bulldog Drummond's Peril",
#    'New York, New York',
#    'The Birds and the Bees',
#    'The Man Who Cheated Himself',
#    'Ginger Snaps 2: Unleashed',
#    'Shhh!',
#    'Scooby-Doo and the Ghoul School',
#    'The Painted Desert',
#    "Who's the Man?",
#    'The Black Prince',
#    'Crow Hollow',
#    'The Virginian',
#    'Miami Expose',
#    'Barricade',
#    'Ab-Normal Beauty',
#    ' X2: X-Men United',
#    'Caught in Trap',
#    'Corrections Class',
#    'Rebel in Town',
#    'Anbu Thozhi',
#    'The Alligator People',
#    'The Wicker Tree',
#    'Saw VII',
#    "We Can't Have Everything",
#    'Toofan',
# ...
#    'The Prize Pest',
#    'In Name Only',
#    'Blackjack',
#    'Red Light',
#    'Manju Poloru Penkutty',
#    'Idlewild',
#    'BumRush',
#    'From Hell It Came',
#    'The Blue Butterfly',
#    'The Woman in Green',
#    'One Dangerous Night',
#    'Manoranjan',
#    'Take Me Home Tonight',
#    'The Matrix Revolutions',
#    'The Oscar',
#    'Ugly',
#    "River's End",
#    'One More Tomorrow',
#    'There Will Be Blood',
#    'Finger Print',
#    'Ippadai Vellum',
#    'Lust in the Dust',
#    'Kalangarai Vilakkam',
#    'Urumi',
#    'The Redhead from Wyoming',
#    'That Lady from Peking',
#    'No Holds Barred',
#    'The Man from U.N.C.L.E.',
#    'Chandrahasa',
#    'Nagasaki: Memories of My Son',
#    'Flying Disc Man from Mars',
#    'Escape Me Never',
#    'I Think I Love My Wife',
#    'Third Person',
#    '99',
#    'The Domino Principle',
#    'Sharapanjara',
#    'Man of Will',
#    'Paddington 2',
#    'Anchorman 2: The Legend Continues',
#    'Passkey to Danger',
#    'Maw`ed Ma` al-Hayat (Appointment with Life)',
#    'My Summer Story',
#    'Josephine and Men',
#    'Akhil',
#    'Hell Is a City',
#    'Border Incident',
#    'Crooked House',
#    'Pyar Ka Mausam',
#    'Married and in Love',
#    'Alone with Her',
#    'Free Jimmy',
#    'Vampire Circus',
#    'Brotherhood of Blood',
#    'The Creeping Terror',
#    'The Way',
#    'Yodha',
#    'Salt',
#    'Company Business',
#    'The Black Pirate',
#    'Men in Her Life',
#    'Battle Cry',
#    'Love Breakups Zindagi',
#    'The Architect',
#    'Gamyam',
#    'Rome Adventure',
#    'Cowboys & Aliens',
#    'Lords of Dogtown',
#    'Fred Claus',
#    'Raging Bull',
#    'The Rise and Fall of a White Collar Hooligan',
#    "Hey Good Lookin'",
#    'Varasudu',
#    'Daaku Aur Jawan',
#    'First Yank into Tokyo',
#    'One for the Money',
#    'Modesty Blaise',
#    'Sleepy-Time Tom',
#    'Free Birds',
#    'Career Opportunities',
#    'Protégé',
#    'Freebie and the Bean',
#    "Wes Craven's New Nightmare",
#    'National Treasure',
#    'Madhumati',
#    'When I Fall in Love... with Both',
#    'Ribbit',
#    'The Inn of the Sixth Happiness',
#    'Pookari',
#    'Live Wire',
#    'The Impassive Footman',
#    'The Firefly',
#    'The Lawless Breed',
#    'Heneral Luna',
#    'The Rest Cure',
#    'Encounters of the Spooky Kind',
#    'Devatha',
#    ' Racing Stripes',
#    'Planes, Trains and Automobiles',
#    'Carnegie Hall',
#    'Easy Come, Easy Go',
#    'Confession',
#    'The Red Mill',
#    'Natarang',
#    'Nenjil Jil Jil',
#    'Invisible Target',
#    'Rabb Da Radio',
#    'Girls at Sea',
#    'Messiah of Evil aka Dead People',
#    'Butch and Sundance: The Early Days',
#    'Battle of the Year',
#    'Mean Creek',
#    'All Saints',
#    'Righting Wrongs',
#    'Me and the Colonel',
#    'The Dark Mirror',
#    'Go, Go Second Time Virgin',
#    'The Devil Is Driving',
#    'Naan Kadavul ',
#    'Ammakkilikkoodu',
#    'Bloodfist II',
#    'Woman in the Dunes',
#    'Divorce',
#    'Legend of a Fighter',
#    'Chungking Express',
#    'Maïna',
#    'The Squaw Man',
#    'Mommo',
#    'Sex Jack[23]',
#    'Hot Rod',
#    'The Angry Birds Movie',
#    'Mughal-e-Azam (Colorized Version)',
#    'Dr. Plonk',
#    'Mylanchi Monchulla Veedu',
#    'Night of the Living Dead',
#    'The Boys Next Door',
#    'The Best Years',
#    'Captain Nemo and the Underwater City',
#    'Seven Days to Noon',
#    'Ironweed',
#    'Ice Cream',
#    'A Gunfight',
#    'Jumping for Joy',
#    'The Falcon in Mexico',
#    'The Last Tycoon',
#    'Ninaithale',
#    'Paadam Onnu: Oru Vilapam',
#    'The Blood of Jesus',
#    'Indecent Proposal',
#    'Nee Kosam',
#    'Sachin: A Billion Dreams',
#    'The Family Jewels',
#    'Revenge of the Creature',
#    'Lord of the Flies',
#    'Outrage Coda',
#    ' Yogi Bear',
#    'Kanchana 2',
#    'Breezy',
#    'The Life Aquatic with Steve Zissou',
#    'Holy Matrimony',
#    'Kurukshetram',
#    'The Girl from Missouri',
#    'The Gulf Between',
#    'Jack Frost',
#    'Anbe Deivam',
#    'Deception',
#    'Undercover',
#    'Police Academy 3: Back in Training',
#    'Primeval',
#    'The Kingdom',
#    'Suite Française',
#    'Solo',
#    'The Wind That Shakes the Barley',
#    'Niram Maaratha Pookkal',
#    'The Thief',
#    'Line Walker',
#    'Adhe Kangal',
#    'The Wild Geese',
#    'Fort Utah',
#    'Moon 44',
#    'And One Was Beautiful',
#    'Meshes of the Afternoon',
#    'Kajraare',
#    'Steamboat Bill, Jr.',
#    'City Slickers',
#    'Thomas & the Magic Railroad',
#    'The Little Kidnappers',
#    'Among Giants',
#    'Playing the Victim',
#    'Vichitra Kutumbam',
#    'Yuvaraju',
#    'Woman in Hiding',
#    'Summertree',
#    'The Long Goodbye',
#    'Don Seenu',
#    'Off Track',
#    'A Film by Aravind',
#    'The Golden Rabbit',
#    'Billu',
#    'Rudraksh',
#    'Dredd',
#    'The Emerald Forest',
#    "Blackbeard's Ghost",
#    'Padma Nadir Majhi',
#    'Curdled',
#    'The Invisible Man Returns',
#    "OOO, Den-O, All Riders: Let's Go Kamen Riders",
#    'My Man and I',
#    'The Iron Lady',
#    ' Rachel Getting Married',
#    'The Boxer',
#    'Melody Cruise',
#    'Laugh, Clown, Laugh',
#    'Eighteen Springs',
#    'Chhupa Rustam',
#    'The 11th Hour',
#    'Star',
#    'The Great Impostor',
#    'Passport to Pimlico',
#    'Polytechnique',
#    'Joe Smith, American',
#    'The Bottom of the Bottle',
#    'Karla',
#    'The Producers',
#    'Quantez',
#    'Femme Fatale, Jang Hee-bin Yohwa, Jang Hee-bin',
#    'Ragasiya Police 115',
#    'Vijayalakshmi',
#    'The Bunker',
#    'Reform School Girl',
#    'The Teckman Mystery',
#    'Vanakkam Thalaiva',
#    'When Night Is Falling',
#    'Summer of the Seventeenth Doll',
#    'One Night in Supermarket',
#    'Sailor Moon S: The Movie',
#    'The Mind of Mr. Soames',
#    'The War',
#    'Hunt the Man Down',
#    'Chef',
#    'The Philadelphia Story',
#    'The Three Weird Sisters',
#    'Host, TheThe Host',
#    'The Gay Desperado',
#    'Soldier of Fortune',
#    'Mr. Lambu',
#    'The Cisco Kid and the Lady',
#    'Loophole',
#    'Jaffa',
#    'Jeepers Creepers',
#    'Afterschool Midnighters',
#    'Ocean Heaven',
#    'Sant Sakhu',
#    'Room No.7',
#    'Alias Boston Blackie',
#    'Mouse Cleaning',
#    "What to Expect When You're Expecting",
#    'Pudhu Vazhvu',
#    'Chinna Pulla',
#    'Ezhu Sundara Rathrikal',
#    'Alien Autopsy',
#    'The Homecoming',
#    'Eastern Promises',
#    'Weddings and Babies',
#    'The Steel Jungle',
#    'Manpower',
#    'Athithi',
#    'You Never Can Tell',
#    "Der Fuehrer's Face",
#    'Paradise Kiss',
#    'Blackbird',
#    'A Very Long Engagement',
#    'Blonde Fever',
#    'Ali and Nino',
#    'The Devil-Doll',
#    'Men with Brooms',
#    'Ex with Benefits',
#    'Ahista Ahista',
#    'Gurinder Chadha',
#    'Pourudu',
#    'Ring of Bright Water',
#    'The Good Son',
#    'Kaaka Muttai',
#    'Faraar a.k.a. Dev Anand in Goa',
#    'Christopher Columbus: The Discovery',
#    'A Man to Remember',
#    'Kansas City Bomber',
#    'Manhattan Murder Mystery',
#    'Santa Claws',
#    'Vasantha Maligai',
#    'The State Counsellor',
#    'Hellions',
#    'Rhythm on the River',
#    'Incredible Burt Wonderstone, TheThe Incredible Burt Wonderstone',
#    'Indianapolis Speedway',
#    'Take a Letter, Darling',
#    'Lord of Tears',
#    'Lonesome Dove',
#    'Into the White Night',
#    'Castle Keep',
#    'A Kid from Tibet',
#    'Amara Shilpi Jakkanna',
#    'So This Is Paris',
#    'Nakhuda',
#    'A Funny Thing Happened on the Way to the Forum',
#    'Labor Day',
#    'Double Bunk',
#    'The Super Dimension Fortress Macross: Do You Remember Love?',
#    'Pattiyude Divasam',
#    'Two Sisters',
#    'Black Limelight',
#    '7 October',
#    'The Parent Trap',
#    'Pokkisham',
#    'Kalabha Kadhalan',
#    'Iron & Silk',
#    'Sarkari Mehmaan',
#    "Bulldog Drummond's Peril",
#    'New York, New York',
#    'The Birds and the Bees',
#    'The Man Who Cheated Himself',
#    'Ginger Snaps 2: Unleashed',
#    'Shhh!',
#    'Scooby-Doo and the Ghoul School',
#    'The Painted Desert',
#    "Who's the Man?",
#    'The Black Prince',
#    'Crow Hollow',
#    'The Virginian',
#    'Miami Expose',
#    'Barricade',
#    'Ab-Normal Beauty',
#    ' X2: X-Men United',
#    'Caught in Trap',
#    'Corrections Class',
#    'Rebel in Town',
#    'Anbu Thozhi',
#    'The Alligator People',
#    'The Wicker Tree',
#    'Saw VII',
#    "We Can't Have Everything",
#    'Toofan',
#    'A Better Life',
#    'Storm Over the Nile',
#    'Kavacham',
#    'Birdman of Alcatraz',
#    'From up on Poppy Hill',
#    'Flipped',
#    "Hitler's Children",
#    'Scruples',
#    'Bless This House',
#    'Gejje Pooje',
#    'The Beloved',
#    'Clover',
#    'The Ruling Class',
#    'Cowboy Counsellor',
#    'Fried Green Tomatoes',
#    'Balgandharva',
#    'Johnny',
#    'Thirteen Days',
#    'Anees Bazmee',
#    'Disbarred',
#    'Silent Running',
#    'Watan',
#    'Radio Inside',
#    'Rocky',
#    'Star Wars Episode IV: A New Hope (aka Star Wars)',
#    'Monsieur Beaucaire',
#    'The Running Man',
#    'Blackthorn',
#    'South of Sanity',
#    'Tere Mere Sapne',
#    'Seven Years Bad Luck',
#    'Son of Rambow',
#    'Bitter Victory',
#    'Pat and Mike',
#    'Confessions of a Queen',
#    'Gutterballs',
#    "Somewhere I'll Find You",
#    'Gouravam',
#    "Dead Man's Shoes",
#    ...]),
#  ('customers',
#   ['Popeye',
#    'Ameerin Aadhi Bhagavan',
#    'A Cinderella Story',
#    'Kuselan',
#    'Malice in the Palace',
#    'Saudagar',
#    'My First Mister',
#    'Needful Things',
#    'CJ7',
#    'Lay the Favourite',
#    'Frightmare',
#    'Queen of the Yukon',
#    'Repo! The Genetic Opera',
#    'Sweeney Todd: The Demon Barber of Fleet Street',
#    'Paul Blart: Mall Cop',
#    'Sesame Street Presents Follow That Bird',
#    'Mannequin',
#    'Miss Hokusai',
#    'The Cocoanuts',
#    'Girls Trip',
#    'A Monster Calls',
#    'The Cook, the Thief, His Wife & Her Lover',
#    'Barfly',
#    'Gumby: The Movie',
#    'Poodle Springs',
#    'Confessions of a Window Cleaner',
#    'Branded',
#    'Sally',
#    'Billy Liar',
#    'The Star',
#    'Predestination',
#    'Clerks',
#    'Urimai Por',
#    'Frances',
#    'Jungle Fever',
#    'The House',
#    'Holiday in Mexico',
#    'Samay: When Time Strikes',
#    'Way of the Dragon',
#    'Mystery of the Wax Museum',
#    'Sadak',
#    'Human Highway',
#    'Supermarket Woman',
#    'Whisky Galore!',
#    'Larceny, Inc.',
#    'Miracle Mile',
#    'Win a Date with Tad Hamilton!',
#    'Last Night',
#    'An Ache in Every Stake',
#    'On the Night of the Fire',
#    'Fun with Dick and Jane',
#    'The Crop',
#    'Mary Poppins',
#    'It Happened to Jane',
#    ' Wish You Were Here',
#    'Snowball Express',
#    'The Players Club',
#    'The Tuxedo',
#    'Burlesque',
#    'Hot Cars',
#    ' Waitress',
#    'Book of Love',
#    'Deterrence',
#    'Curtain Call at Cactus Creek',
#    'Troublesome Night 12',
#    'Gunday',
#    'Dev.D',
#    'Champagne Charlie',
#    'X',
#    'Ice Cream Man',
#    'Idhu Namma Aalu',
#    'Matchstick Men',
#    'Rupkatha Noy',
#    'Rendu',
#    'The Barber of Seville',
#    'Let It Ride',
#    'Rollover',
#    'Begum Jaan',
#    'Blood In Blood Out',
#    'Passion Play',
#    "Trailer Park Boys: Don't Legalize It",
#    'Barbershop',
#    'The SpongeBob Movie: Sponge Out of Water',
#    "It's Great to Be Young",
#    'Johnny Belinda',
#    'The Pace That Kills',
#    'Susan Slade',
#    'His Wedding Night',
#    'Spun',
#    'Spring Subway',
#    'Attack the Block',
#    'The H-Man',
#    'From Beyond the Grave',
#    'Smart Money',
#    'Eternal Sunshine of the Spotless Mind',
#    'Hitch',
#    'Pudhu Pudhu Arthangal',
#    'Les Misérables',
#    'What a Way to Go!',
#    'Kabuliwala',
#    'Dance Hall Racket',
#    '23',
#    'Robin Hood',
#    'The Mambo Kings',
#    'The Smallest Show on Earth',
#    'Multiplicity',
#    'Berlin Express',
#    'A Fantastic Fear of Everything',
#    'High Fidelity',
#    'Something Always Happens',
#    'City for Conquest',
#    'Beauty Shop',
#    'Freaks',
#    'Chingaari',
#    'Legend',
#    ' Laid to Rest',
#    "Ripley's Game",
#    'Fitness Tour',
#    'The Smurfs',
#    'Adulthood',
#    'Are You with It?',
#    'The Wrestler',
#    'Waking Ned',
#    'Jailhouse Rock',
#    "Monty Python's The Meaning of Life",
#    'Eden',
#    'Rakht: What If You Can See the Future',
#    'Naanu Avanalla...Avalu',
#    'Planes, Trains and Automobiles',
#    'Prosperity',
#    'Curious George',
#    'Life is Sweet',
#    'Jackass Presents: Bad Grandpa',
#    'Shifty',
#    'Mona Lisa',
#    'An Everlasting Piece',
#    'Four Sisters and a Wedding',
#    ' Paid in Full',
#    'Charlie Chan in Paris',
#    'Paambhu Sattai',
#    'From Noon till Three',
#    'Flight to Hong Kong',
#    'Manhandled',
#    'Mid-Afternoon Barks',
#    'The Balcony',
#    "Citizen's Band",
#    'Big Night',
#    'Sky Bride',
#    'Used Cars',
#    'Night World',
#    'Modern Girls',
#    'The Best Little Whorehouse in Texas',
#    'Little Shop of Horrors',
#    'Oath of Vengeance',
#    'Natsamrat',
#    'An Autumn Afternoon',
#    'CBGB',
#    'Chastity',
#    'Dough and Dynamite',
#    'Psycho',
#    'Kiss and Tell',
#    'Coyote Ugly',
#    'The Angry Birds Movie',
#    'Water',
#    'Stuck on You',
#    'Hugo Pool',
#    'What! No Beer?',
#    'Dallas Buyers Club',
#    'Rumpus in the Harem',
#    'Fighter',
#    'Kansas Saloon Smashers',
#    'The Bride',
#    'Falling Down',
#    'Son of the Gods',
#    'Thalaivaa',
#    'One Good Cop',
#    'Dirty Work',
#    'Highway',
#    'Wells Fargo',
#    'John Day',
#    'Prahaar: The Final Attack',
#    'The Plainsman',
#    'Maari',
#    'Shiawase no Pan',
#    ' Caffeine',
#    'Gambling Ship',
#    "Everybody's Doing It",
#    'Aby',
#    'Luck Key',
#    'Internship, TheThe Internship',
#    'Sorrowful Jones',
#    'Eye for an Eye',
#    'The Panic in Needle Park',
#    'Swordfish',
#    'One Hour Photo',
#    'Rishi',
#    'Repo Men',
#    'The Courtship of Andy Hardy',
#    'The Pursuit of Happyness',
#    'The Little Shop of Horrors',
#    'Malaya',
#    'Ouran High School Host Club',
#    "Sweet Sweetback's Baadasssss Song",
#    'Maanja Velu',
#    'Shower',
#    'Smokey and the Bandit',
#    "De Dana Dan'",
#    'Barbary Coast',
#    "Daffy's Inn Trouble",
#    'The Rochdale Pioneers',
#    'Licence to Kill',
#    'Bad Ass',
#    'Heavy Traffic',
#    'Lakshyam',
#    'Protector, The',
#    'Chauraha',
#    'Where East is East',
#    'Stars in Your Eyes',
#    'The Life and Times of Judge Roy Bean',
#    'Loverboy',
#    'The Bingo Long Traveling All-Stars & Motor Kings',
#    'ATM',
#    ' Waiting...',
#    'Twelve',
#    'The Cotton Club',
#    'Little Big Man',
#    'Belle of the Yukon',
#    'Piccadilly',
#    'Love in Bloom',
#    'Doomsday Party',
#    'Mannar Mathai Speaking 2',
#    'High Gear',
#    'Borderline',
#    'Kamome Shokudo',
#    'Employee of the Month',
#    'Tharle Nan Maga',
#    'The Comedy of Terrors',
#    'Chance of a Lifetime',
#    'Beast Cops',
#    'She Done Him Wrong',
#    'Sky Full of Moon',
#    'Eating Raoul',
#    'Of Human Bondage',
#    'A Madea Christmas',
#    'Tickle Me',
#    'Holy Man',
#    'Frankenhooker',
#    'Journals of Musan, The !The Journals of Musan',
#    'Movie 43',
#    'The Dark Eyes of London',
#    'A Dangerous Profession',
#    'Dick Tracy Meets Gruesome',
#    'Younger and Younger',
#    "What to Expect When You're Expecting",
#    'Hotel',
#    "I'm No Angel",
#    "Love's Kitchen",
#    'Hum To Mohabbat Karega',
#    "Jason's Lyric",
#    'Suspicious River',
#    'Sabotage',
#    'Caught Plastered',
#    'Los Amigos',
#    'The Personality Kid',
#    'Hall Pass',
#    'When a Woman Ascends the Stairs',
#    'Attack the Gas Station',
#    'Brooklyn',
#    'What Men Talk About',
#    'The Arrival',
#    'The Dukes of Hazzard',
#    'The Cable Guy',
#    'The Unholy Three',
#    'Dickie Roberts: Former Child Star',
#    'Hurricane Smith',
#    'The Protector',
#    'Winner Take All',
#    'The Spitfire Grill',
#    'Varadanayaka',
#    'Reefer Madness',
#    'Cocktail',
#    'Yaamirukka Bayamey',
#    'Getting Any?',
#    'Oil for the Lamps of China',
#    'Baby Face',
#    'King Creole',
#    'Roustabout',
#    'Margin Call',
#    'Sadhna',
#    'Band of the Hand',
#    'Dial 1119',
#    'Just Write',
#    ' 15 Minutes',
#    ' Napoleon Dynamite',
#    'Straight',
#    'A Likely Story',
#    'Lady for a Night',
#    'Crossroads',
#    'Chicken and Duck Talk',
#    'Mando Meyer Upakshan',
#    "Who's the Man?",
#    'Tampopo',
#    'The Sun Sets at Dawn',
#    'She Had to Choose',
#    'No Kidding',
#    'Final Justice',
#    'On Secret Service',
#    'Eat the Rich',
#    'Kinjite: Forbidden Subjects',
#    'Hoodlum',
#    'Hai Hai Nayaka',
#    'The Clock',
#    'Nothing But a Man',
#    'Night of the Ghouls',
#    'Moving Day',
#    'Four Last Songs',
#    'Kenny',
#    'Graffiti Bridge',
#    'The Best Exotic Marigold Hotel',
#    'Life Show',
#    'The Collector',
#    'Lawless',
#    'Welcome to Sajjanpur',
#    'Call of the Flesh',
#    'Flywheel',
#    'Evil Dead 3: Army of Darkness',
#    'Miranda',
#    'Scruples',
#    'Shriman Satyawadi'])]

# %% [markdown]
# 3. Realizar consultas en el índice invertido:
#     - Implementa funciones que permitan buscar palabras clave y devolver los títulos de las películas que contienen dichas palabras.

# %% [markdown]
# Se implementa la función search_index, que recibe una consulta y busca cada palabra en el índice invertido. Devuelve un conjunto de títulos de películas que contienen las palabras de la consulta.

# %%
def search_index(query, index):
    query_tokens = normalize_text(query).split()
    results = set()

    for token in query_tokens:
        if token in index:
            results.update(index[token])  # Agregar títulos que contienen el token

    return results

# query = "saloon"
query = input("Introduce la palabra clave para la búsqueda: ")
results = search_index(query, index)
print(f"Películas encontradas para la consulta '{query}':\n{results}")
# Out:
# Películas encontradas para la consulta 'moon':
# {'Kaalam Maari Pochu', 'Lords of Salem, TheThe Lords of Salem', 'Die Another Day', 'Isle of Forgotten Sins', 'Way...Way Out', 'Tabloid Truth', 'The Adventures of Baron Munchausen', 'The Genius Club', 'Rent', 'Wallace & Gromit: The Curse of the Were-Rabbit', 'Troublesome Night 9', 'Space Truckers', 'Project Moonbase', 'Madonna', 'The Swan Princess', 'Man in the Moon', 'Star Trek VI: The Undiscovered Country', 'The Mountain Men', 'You Ruined My Life', 'Dating the Enemy', 'Masters of the Universe', 'Kamen Rider Decade The Movie: All Riders vs. Great Shocker', ' Race to Witch Mountain', "The Mummy's Ghost", 'The Swan Princess II: Escape from Castle Mountain', 'The Adventures of Pluto Nash', 'Brick Bradford', 'Scooby-Doo and the Reluctant Werewolf', "It's In the Water", "Legend of the Guardians: The Owls of Ga'Hoole", "Jules Verne's Rocket to the Moon", 'The Ninth Configuration', 'Hugo', 'White Comanche', 'An American Werewolf in London', 'Vinayaga Chathurthi Dubbed from Telugu', 'Assassination Classroom', 'Slacker', 'She Creature', 'Dus Kahaniyaan', 'Once in a New Moon', 'Airplane II: The Sequel', 'Tell Me That You Love Me, Junie Moon', 'Beyond Skyline', 'Going Hollywood', 'Fright Night 2: New Blood', 'Dangerous Moonlight', 'Yagnam', 'Fun and Fancy Free', 'Destination Moon', 'Uchu Sentai Kyuranger the Movie: Gase Indaver Strikes Back', 'Shake, Rattle & Roll 13', 'Dr. Prakash baba Amte', 'Whisper of the Heart', 'Private School', 'Naruto the Movie: Road to Ninja', 'Big Bully', 'Halloween', '009 Re:Cyborg', 'Journey 2: The Mysterious Island', 'The Lords of Salem', 'Welcome to the Space Show', 'Two Moon Junction', 'The Secret of Moonacre', 'Robot Monster', 'Samurai Sentai Shinkenger vs. Go-onger: GinmakuBang!!', 'CrissCross', 'Mermaid', 'Cardfight!! Vanguard The Movie', ' Waitress', 'Vampire in Brooklyn', 'Tracing Shadow', 'Dead Leaves', 'Murari', ' Dish, TheThe Dish', "The Mummy's Hand", 'The Werewolf of Washington', 'Avatar', 'Star Trek Into Darkness', 'A Walk on the Moon', 'Love by the Light of the Moon', 'House of Dracula', 'Countdown', 'Vinayaka Chaviti', 'The Lone Wolf Keeps a Date', 'A Month in the Country', 'Mean Guns', 'The Good Girl', 'End of Days', 'War of the Arrows', 'Bees Saal Baad', 'True Grit', 'Hocus Pocus', '100 Days', 'Dances with Dragon', 'Rumor Has It...', 'Bedazzled', 'Wolf', 'The Stand', ' Arrowhead', 'Leave Her to Heaven', 'Lost in a Harem', 'Jameen Kottai', 'The Cat Returns', 'Angel', 'Hunky Dory', 'Persona 3 The Movie: No. 3, Falling Down', 'Red Dragon', 'Pathfinder', 'CQ', 'Oblivion', 'Evangelion: 2.0 You Can (Not) Advance', 'Harry Potter and the Prisoner of Azkaban', 'Yuga', 'There Was a Crooked Man...', 'The Spiderwick Chronicles', 'Be Cool', 'Creature', 'Brother Sun, Sister Moon', 'The Chronicles of Riddick', 'Black Moon Rising', 'The Howling', 'Armageddon', 'Sathuranga Vettai', 'Prancer', 'Murder, Inc.', 'Piranha', 'Semi-Pro', 'Abbott and Costello Meet Frankenstein', 'Tekken', 'Howling III', 'Underworld', 'Austin Powers: The Spy Who Shagged Me', 'Never Die Alone', 'Charley Moon', 'Go West, Young Man', 'Beep Prepared', 'At Play in the Fields of the Lord', 'Battle in Outer Space', 'Doctor X', 'Down Beat Bear', 'Apollo 13', 'Mood of the Day', 'Set Up', 'Flash Gordon', 'The Gorgon', 'Diamonds Are Forever', 'Legend of the Werewolf', 'Interkosmos', 'Fire Maidens from Outer Space', 'Rocketship X-M', 'Moon Zero Two', 'Evangelion: 1.0 You Are (Not) Alone', 'Beautiful Creatures', 'The Smurfs', 'First Men in the Moon', 'The Onion Field', 'Gone with the West', 'Junoon', 'The Mad Monk', 'The Black Cat', 'Around the World in Eighty Days', 'Tengen Toppa Gurren Lagann the Movie: Spiral Stone Chapter', 'Silver Bullet', 'The Shameless', 'Mirror Mirror', 'Kubo and the Two Strings', 'Amazon Women on the Moon', ' Racing Stripes', 'Anand', 'Folly to Be Wise', 'August Rush', 'Tick Tock Tuckered', 'Alexander the Great', 'Moonstruck', 'The Advocate: A Missing Body', 'Superman IV: The Quest for Peace', 'The Secret of the Sword',  ...

# %% [markdown]
# ### **Parte 2: Usar Whoosh para Indexación y Recuperación**

# %%
# !pip install whoosh
# Out:
# Requirement already satisfied: whoosh in c:\python312\lib\site-packages (2.7.4)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from whoosh.index import create_in
from whoosh.fields import Schema, TEXT
from whoosh.qparser import QueryParser
import os

# %% [markdown]
# * create_in: Crea un índice en un directorio especificado.
# * Schema y TEXT: Definen la estructura del índice, donde TEXT es el tipo de dato para almacenar texto.
# * QueryParser: Convierte las consultas de búsqueda en un formato que Whoosh pueda procesar.
# * os: Permite manejar operaciones del sistema de archivos, como crear directorios.

# %% [markdown]
# 1. Configurar un índice con Whoosh:
#     * Define un esquema con los campos Title y Plot.
#     * Crea un índice y agrega las películas seleccionadas.

# %% [markdown]
# Se define un esquema con los campos title y plot, ambos como texto almacenado. Luego, se verifica si el directorio para almacenar el índice (indexdir) existe, y si no, se crea. Finalmente, se crea el índice en el directorio especificado utilizando el esquema previamente definido.

# %%
schema = Schema(title=TEXT(stored=True), plot=TEXT(stored=True))

indexdir = "indexdir"
if not os.path.exists(indexdir):
    os.mkdir(indexdir)

from whoosh.index import create_in
index = create_in(indexdir, schema)

print(f"Índice creado en el directorio '{indexdir}'.")
# Out:
# Índice creado en el directorio 'indexdir'.

# %% [markdown]
# 2. Agregar documentos al índice:
#     * Usa las funciones de escritura de Whoosh para indexar los títulos y tramas.

# %% [markdown]
# Se utiliza AsyncWriter de Whoosh para agregar documentos al índice. A través de un bucle, se recorren las filas de los datos, se agregan los títulos y tramas al índice mediante la función add_document. Finalmente, se confirma la adición de los documentos al índice con el método commit, y se imprime el número total de documentos agregados.

# %%
from whoosh.writing import AsyncWriter

writer = AsyncWriter(index)

for idx, row in data.iterrows():
    writer.add_document(title=row['Title'], plot=row['Plot'])

writer.commit()

print(f"Se han agregado {data.shape[0]} documentos al índice.")
# Out:
# Se han agregado 34886 documentos al índice.

# %% [markdown]
# 3. Realizar consultas:
#     * Busca películas relevantes usando palabras clave relacionadas con las tramas (e.g., "dinosaurs", "cyborg").

# %% [markdown]
# Se define una función 'search_whoosh' para realizar consultas en el índice. Esta función abre el índice para lectura, analiza la consulta usando el QueryParser con el campo plot, y luego busca los documentos que coincidan con la consulta. Los resultados de la búsqueda se almacenan y se extraen los títulos de las películas correspondientes. Finalmente, se realiza una consulta y se muestran las películas encontradas.

# %%
def search_whoosh(query, index):
    with index.searcher() as searcher:
        query_parser = QueryParser("plot", index.schema)
        parsed_query = query_parser.parse(query)
        results = searcher.search(parsed_query)
        titles = [result['title'] for result in results]
        return titles

# query = "dinosaurs park"
query = input("Introduce la palabra clave para la búsqueda: ")
results = search_whoosh(query, index)
print(f"Películas encontradas para la consulta '{query}':\n{results}")
# Out:
# Películas encontradas para la consulta 'moon':
# ["Goin' South", 'Love by the Light of the Moon', 'Andrew Lau, Alan Mak', "This Girl's Life", 'Set Up', 'At Play in the Fields of the Lord', 'Missile to the Moon', 'Kamen Rider World', 'Pontiac Moon', 'Nude on the Moon']

# %% [markdown]
# Para hacer mas pruebas, se define una lista de consultas con diferentes palabras clave relacionadas con las tramas de las películas. Luego, se recorre esta lista y se realiza una búsqueda para cada palabra clave utilizando la función search_whoosh. Los resultados de cada consulta se imprimen, mostrando las películas encontradas para cada término de búsqueda.

# %%
queries = ["cyborg", "time travel", "space adventure", "robot"]
for query in queries:
    results = search_whoosh(query, index)
    print(f"Películas encontradas para '{query}': {results}\n")
# Out:
# Películas encontradas para 'cyborg': ['Future War', 'Space Truckers', 'JAKQ Dengeki Tai', 'JAKQ Dengeki Tai vs. Goranger', 'Kung Fu Cyborg', 'Future X-Cops', 'Kamen Rider V3', 'Kamen Rider V3 vs. the Destron Monsters', 'Cyborg She', 'Cyborg She']
#
# Películas encontradas para 'time travel': ['Time Chasers', 'Love Story 2050', 'Timeranger vs. GoGoV', 'Abby Sen', 'Dimensions', 'Millennium', 'Primer', 'The Man with Rain in His Shoes', 'The Road', 'About Time']
#
# Películas encontradas para 'space adventure': ['Space Ship Sappy', 'Moonshine', 'Galaxy Quest', 'Time Bandits', 'Looney Tunes: Back in Action', 'Gokaiger Goseiger Super Sentai 199 Hero Great Battle', 'Gold Diggers: The Secret of Bear Mountain', 'Aliens in the Attic', 'Until the End of the World (a.k.a. Bis ans Ende der Welt)', 'African Cats']
#
# Películas encontradas para 'robot': ["Daft Punk's Electroma", 'Robosapien: Rebooted', 'Tobor the Great', 'Hardware', 'Chopping Mall', 'Doraemon: Nobita and the New Steel Troops: ~Angel Wings~', 'R.O.T.O.R.', 'Robot Jox', 'Robot & Frank', 'Heartbeeps']

# %% [markdown]
# Finalemente, para hacer comprobaciones adicionales, se utiliza un buscador del índice para obtener la cantidad total de documentos presentes en el índice. Con el método doc_count(), se imprime el número de documentos almacenados en el índice.

# %%
# Validar cuántos documentos hay en el índice
with index.searcher() as searcher:
    print(f"El índice contiene {searcher.doc_count()} documentos.")
# Out:
# El índice contiene 34886 documentos.

# %% [markdown]
# ## **Parte 3: Usar Elasticsearch para Indexación y Recuperación**
# 1. Iniciar Elasticsearch con Docker.

# %% [markdown]
# - Descarga Docker Desktop desde docker.com.
# - Descargar e iniciar Elasticsearch|

# %% [markdown]
#     docker run -d --name elasticsearch -p 9200:9200 -e "discovery.type=single-node" docker.elastic.co/elasticsearch/elasticsearch:8.10.2

# %% [markdown]
# *-d: Ejecuta el contenedor en segundo plano.*
#
# *--name ela|sticsearch: Nombra al contenedor como elasticsearch.*
#
# *-p 9200:9200: Expone el puerto 9200 del contenedor a tu máquina local.*
#
# *-e "discovery.type=single-node": Configura Elasticsearch en modo de nodo único (ideal para pruebas locales).*

# %% [markdown]
# Verifica que Elasticsearch esté corriendo visitando:

# %% [markdown]
#     http://localhost:9200

# %% [markdown]
# 2. Configurar el cliente Elasticsearch en Python:
#     * Conecta Elasticsearch y crea un índice con los campos Title y Plot.

# %% [markdown]
# Instala la librería de Python para conectarte a Elasticsearch:

# %% [markdown]
#     pip install elasticsearch

# %% [markdown]
# Luego, configura el cliente en tu código:

# %%
from elasticsearch import Elasticsearch

# Conexión a Elasticsearch
es = Elasticsearch("http://localhost:9200")

# Verificar la conexión
if es.ping():
    print("Conectado a Elasticsearch")
else:
    print("No se pudo conectar a Elasticsearch")

# %% [markdown]
# 3. Indexar documentos:
#     * Inserta cada película en el índice de Elasticsearch, usando el título como identificador.

# %% [markdown]
# Define el esquema para el índice y créalo. Aquí definimos los campos Title y Plot:

# %%
# Crear un índice con el esquema especificado
index_name = "movies"
if not es.indices.exists(index=index_name):
    es.indices.create(
        index=index_name,
        body={
            "mappings": {
                "properties": {
                    "Title": {"type": "text"},
                    "Plot": {"type": "text"},
                }
            }
        },
    )
    print(f"Índice '{index_name}' creado.")
else:
    print(f"Índice '{index_name}' ya existe.")

# %% [markdown]
# Inserta cada película en el índice de Elasticsearch, utilizando el título como identificador único:

# %%
# Indexar las películas en Elasticsearch
for idx, row in data.iterrows():
    doc = {"Title": row["Title"], "Plot": row["Plot"]}
    es.index(index=index_name, id=idx, body=doc)

print(f"Se han indexado {len(data)} documentos en el índice '{index_name}'.")

# %% [markdown]
# 4. Realizar consultas:
#     * Realiza búsquedas utilizando tramas relacionadas con palabras clave como "time travel" o "genetic engineering".

# %% [markdown]
# # Función para buscar en Elasticsearch
# def search_elasticsearch(query, index):
#     response = es.search(
#         index=index,
#         body={
#             "query": {
#                 "match": {
#                     "Plot": query  # Busca en el campo 'Plot'
#                 }
#             }
#         },
#     )
#     # Extraer títulos de los resultados
#     titles = [hit["_source"]["Title"] for hit in response["hits"]["hits"]]
#     return titles
#
# # Ejemplo de consulta
# query = input("Introduce la palabra clave para la búsqueda: ")
# results = search_elasticsearch(query, index_name)
# print(f"Películas encontradas para '{query}': {results}")

# %% [markdown]
# Codigo completo del archivo .py:

# %%
from elasticsearch import Elasticsearch
import pandas as pd
import re

# Conexión a Elasticsearch
def connect_elasticsearch():
    es = Elasticsearch("http://localhost:9200")
    if es.ping():
        print("Conectado a Elasticsearch")
        return es
    else:
        print("No se pudo conectar a Elasticsearch")
        exit()

# Crear un índice con esquema
def create_index(es, index_name):
    if not es.indices.exists(index=index_name):
        es.indices.create(
            index=index_name,
            body={
                "mappings": {
                    "properties": {
                        "Title": {"type": "text"},
                        "Plot": {"type": "text"},
                    }
                }
            },
        )
        print(f"Índice '{index_name}' creado.")
    else:
        print(f"Índice '{index_name}' ya existe.")

# Normalizar texto
def normalize_text(text):
    text = text.lower()
    text = re.sub(r"[^\w\s]", "", text)
    return text

# Indexar documentos
def index_documents(es, index_name, data):
    for idx, row in data.iterrows():
        doc = {"Title": row["Title"], "Plot": row["Plot"]}
        es.index(index=index_name, id=idx, body=doc)
    print(f"Se han indexado {len(data)} documentos en el índice '{index_name}'.")

# Realizar búsqueda
def search_elasticsearch(es, query, index_name):
    response = es.search(
        index=index_name,
        body={
            "query": {
                "match": {
                    "Plot": query
                }
            }
        },
    )
    titles = [hit["_source"]["Title"] for hit in response["hits"]["hits"]]
    return titles

# Cargar datos del CSV
def load_data(file_path):
    dataset = pd.read_csv(file_path)
    data = dataset[["Title", "Plot"]].dropna()
    data["Plot"] = data["Plot"].apply(normalize_text)
    return data

# Validar documentos en el índice
def validate_documents(es, index_name):
    doc_count = es.count(index=index_name)["count"]
    print(f"El índice '{index_name}' contiene {doc_count} documentos.")

if __name__ == "__main__":
    # Configuración
    INDEX_NAME = "movies"
    FILE_PATH = "./wiki_movie_plots_deduped.csv"

    # 1. Conectar a Elasticsearch
    es = connect_elasticsearch()

    # 2. Crear índice
    create_index(es, INDEX_NAME)

    # 3. Cargar datos
    data = load_data(FILE_PATH)

    # 4. Indexar documentos
    index_documents(es, INDEX_NAME, data)

    # 5. Validar cantidad de documentos
    validate_documents(es, INDEX_NAME)

    # 6. Realizar consultas
    queries = ["time travel", "genetic engineering", "space adventure", "robot"]
    for query in queries:
        results = search_elasticsearch(es, query, INDEX_NAME)
        print(f"Resultados para '{query}': {results}")

# %% [markdown]
# ### Reflexiones:

# %% [markdown]
# ##### 1. Implementación de un índice invertido manual
#
# Al trabajar con un índice invertido manual, enfrentamos desafíos relacionados con la normalización del texto. A pesar de usar expresiones regulares para eliminar puntuación y convertir texto a minúsculas, notamos que algunas palabras compuestas o contracciones no se manejaban correctamente. Aprendimos que, al procesar datos a gran escala, es crucial optimizar la normalización y tener en cuenta las posibles variaciones en el texto para asegurar la precisión del índice.
#
# ##### 2. Uso de Whoosh para indexación y recuperación
#
# El uso de Whoosh mejoró significativamente la indexación. Sin embargo, al integrar Whoosh, tuvimos que prestar especial atención al esquema de indexación y al proceso de búsqueda, ya que las consultas no siempre eran precisas al principio. Aprendimos la importancia de ajustar bien los parámetros de tokenización y análisis para obtener resultados exactos. La experiencia nos enseñó cómo trabajar con índices optimizados en entornos de búsqueda de texto completo.
#
# ##### 3. Conexión y uso de Elasticsearch
#
# La configuración de Elasticsearch fue más compleja de lo esperado, especialmente al trabajar con Docker y configurar la conexión desde Python. A pesar de los desafíos iniciales, una vez conectados, la creación de índices y la indexación de documentos fueron rápidas. Aprendimos que la clave para un rendimiento óptimo en Elasticsearch es definir correctamente los mapeos del índice. La escalabilidad y eficiencia de Elasticsearch fueron notables, superando las soluciones anteriores, y al final, conseguimos una solución robusta y eficiente para manejar grandes volúmenes de datos.
#
# En general, la integración de Elasticsearch fue un paso decisivo que mejoró tanto la velocidad como la precisión de las búsquedas, consolidando nuestra solución de indexación.
